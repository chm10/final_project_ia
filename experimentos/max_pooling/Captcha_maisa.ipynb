# %% [markdown]
# <div align="center">
#     <h1> <b>MO416 - IC/Unicamp  </h1>
#     <h2> <b>Projeto Final - Aplicação de Aprendizado de Máquina na Decifração de Captchas </h2>
# </div>
#
# <table>
# <tr><td style="text-align:left">Christian Maekawa</td>  <td>231867</td>  </tr>
# <tr><td style="text-align:left">Giovane de Morais</td>  <td>192683</td>  </tr>
# <tr><td style="text-align:left">Maisa Silva      </td>  <td>181831</td>  </tr>
# <tr><td style="text-align:left">Matteus Vargas   </td>  <td>262885</td>  </tr>
# <tr><td style="text-align:left">Stéfani Fernandes</td>  <td>147939</td>  </tr>
# </table>

# %% [markdown]
# # 1 - Introdução
#
# A leitura de caracteres alfa-numéricos é um tarefa simples para um ser humano, porém por muitos anos esse foi um grande desafio para computadores. Nos últimos anos várias bases de dados de imagens foram utilizados em desafios para o alcance de melhor desempenho na tarefa de leitura de caracteres. Exemplos desses dataset são MNist e SVHN.
#
# Das abordagens aplicadas nesse objetivo estão as Redes Neurais Artificiais com várias camadas ocultas, esta abordagem é conhecida como Deep Learning. Das técnicas de Deep Learning amplamente usadas no processamento de imagens estão as Redes Neurais Convolucionais, que consideram a posição do pixel na imagem.
#
# As Redes Neurais Convolucionais são compostas por duas grandes etapas: extração de features pelas camadas convolucionais e classificação pelas camadas finais (Pooling e Fully-Connected). Onde as camadas de convoluções alteram as representações dos dados e aprende os filtros. E a camada de Pooling reduz a escala para a próxima camada. Sendo assim cada filtro aprendido é um extrator de atributos (features) e cada imagem resultante de um filtro é um mapa de características. As camadas pooling reduzem a quantidade de características por filtro.
#
# O objetivo desse trabalho é aplicar a abordagem de Redes Neurais Convulacionais na leitura de imagens Captchas. O dataset é impactante para o desempenho de aplicações de Aprendizado de Máquina, como nosso trabalho incluí a geração do dataset realizamos um estudo que verifica se a aplicação de critérios como permutação na geração do dataset é capaz de gerar amostras de treino que melhor representam o espaço, e assim é possível obter um

# %%
##########
#
# Imports
#
##########

import os
import cv2
import string
import itertools
import numpy as np
import matplotlib.pyplot as plt

from keras import layers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix
# Out:
# Using TensorFlow backend.

# %%
#import sys
#IN_COLAB = 'google.colab' in sys.modules
#if IN_COLAB:
#  !gdown --id "1mf0BxFivzVxDb11IHoYpfZLoNlHSvXvz"
#  !unzip -q dataset_train_random
#  !gdown --id "1aRFpq6hwCkwrsJM1wLXXrL2jxmSJ6zc7"
#  !unzip -q dataset_test
#  !gdown --id "1rXZGjMfMnVhhIGljkv66_Nvw4FXCG0YW"
#  !unzip -q dataset_train_perm
  #!gdown --id "18pvA4cs0EKfd9ajJbqYqJxi4w77bivxh"
  #!unzip -q dataset

# %% [markdown]
# # 2 - Dados
#
# Nesse trabalho geramos imagens Captcha de dimensão 60x160 com 5 caracteres, as imagens foram salvas em arquivos
# .png cujo nome é a palavra contida na imagem. Foram criados 3 datasets:
#
# - treino aleatório: nesse dataset os 5 caracteres que formam a palavra foram escolhidos aleatoriamente
#
# - treino com permutação:nesse dataset 5 caracteres foram escolhidos aleatoriamente e imagens foram geradas com todas as permutações possíveis de tamanho 5. Na sequência foram escolhidos outras 5 caracteres que não haviam sido escolhidos antecipadamente. Esse ciclo foi repetido até atingir o tamanho esperado do dataset:
#
# - teste: foram geradas imagens com 5 caracteres escolhidos aleatoriamente.
#
# Para reduzir o tempo de treino da RN realizamos um pré-processamento, redimensionando as imagens para 30x80 e transformando-as para escala de cinza.

# %%
# Símbolos presentes nos captchas
symbols = string.ascii_uppercase + "0123456789"
num_symbols = len(symbols)

print('Símbolos: ' + symbols)
print('Quantidade de símbolos: ' + str(num_symbols))

# Tamanho das imagens de entrada à RN
img_height = 30
img_width = 80
img_shape = (img_height, img_width, 1)

# Tamanho da palavra no captcha
size_word = 5
# Out:
# Símbolos: ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789
# Quantidade de símbolos: 36

# %% [markdown]
# ## 2.1 - Funções auxiliares para leitura dos dados
# Leitura das imagens e pré-processamento para dados no formato X e Y.

# %%
################################################################################################################
#
# Leitura dos nomes dos arquivos
#
#    Realiza a leitura do nome dos arquivos de captchas recebendo por parametro o diretório onde os arquivos 
#    estão armazenados.
#    Retorna a lista do nome de arquivos.
#
################################################################################################################

def read_name_files(files_dir = 'dataset'):

    files = os.listdir(files_dir)
    
    return files

# %%
################################################################################################################
#
# Leitura das imagens em lote
#
#    Realiza a leitura das imagens captchas recebendo por parametro os símbolos que formam os captchas,
#    a lista dos nomes dos arquivos e o diretório onde os arquivos estão armazenados.
#    Retorna o dataset no formato X e y.
#
################################################################################################################

def read_dataset_batch(symbols, batch_files, captcha_dir = 'dataset'):
    
    n_samples = len(batch_files)
    
    X = np.zeros((n_samples, img_height, img_width, 1))
    y = np.zeros((size_word, n_samples, num_symbols))

    i = 0;
    
    # Leitura de cada arquivo
    for name_file in batch_files:
        
        img = cv2.imread(os.path.join(captcha_dir, name_file), cv2.IMREAD_GRAYSCALE)
        word = name_file[:-4] # retira a extensão .png
        
        # Se a palavra tem 5 caracteres
        if len(word) == size_word:
            
            img = img / 255. # Coloca o valor dos pixels entre 0 e 1
            
            # Faz o reshape da imagem para a metade do tamanho da altura e comprimento, reduzindo ela em 1/4 do tamanho
            img = cv2.resize(img, (img_width, img_height), interpolation=cv2.INTER_AREA)
            img = np.reshape(img, (img.shape[0], img.shape[1], 1))
            
            # Matriz alvo, possui numero da caracteres na palavra por número de caracteres possíveis
            # Na matriz alvo se a posição corresponde a determinado símbolo o valor da célula será 1, 
            # e 0 caso contrário.
            targs = np.zeros((size_word, num_symbols))
            
            for idx_letter, simbol in enumerate(word):
                n_simbol = symbols.find(simbol)
                targs[idx_letter, n_simbol] = 1
                
            X[i] = img
            y[:, i] = targs
            
            i = i +1;
            
            # Controle de progresso
            if(i%10000 == 0):
                print(str(i) + " imagens read");

    return X, y

# %% [markdown]
# ## 2.2 - Datasets
#
# Leitura dos nomes de arquivos dos datasets de treino e leitura do dataset de teste que é único e imutável.

# %%
name_dir_random = 'dataset_train_random';
name_captcha_files_rand = read_name_files(files_dir = 'dataset_train_random')
print('Número de imagens no dataset randômico: ' + str(len(name_captcha_files_rand)))
X_train_random, y_train_random = read_dataset_batch(symbols, name_captcha_files_rand, captcha_dir = name_dir_random)
# Out:
# Número de imagens no dataset randômico: 99910
# 10000 imagens read
# 20000 imagens read
# 30000 imagens read
# 40000 imagens read
# 50000 imagens read
# 60000 imagens read
# 70000 imagens read
# 80000 imagens read
# 90000 imagens read

# %%
name_dir_perm = 'dataset_train_perm';
name_captcha_files_perm = read_name_files(files_dir = 'dataset_train_perm')
print('Número de imagens no dataset permutação: ' + str(len(name_captcha_files_perm)))
X_train_perm, y_train_perm = read_dataset_batch(symbols, name_captcha_files_perm, captcha_dir = name_dir_perm)
# Out:
# Número de imagens no dataset permutação: 100029
# 10000 imagens read
# 20000 imagens read
# 30000 imagens read
# 40000 imagens read
# 50000 imagens read
# 60000 imagens read
# 70000 imagens read
# 80000 imagens read
# 90000 imagens read
# 100000 imagens read

# %%
name_dir_test = 'dataset_test';
name_captcha_files_test = read_name_files(files_dir = name_dir_test)
print('Número de imagens no dataset teste: ' + str(len(name_captcha_files_test)))

X_test, y_test = read_dataset_batch(symbols, name_captcha_files_test, captcha_dir = name_dir_test)
# Out:
# Número de imagens no dataset teste: 19976
# 10000 imagens read

# %%
# Exemplo de imagem
fig, axs = plt.subplots(2,2,figsize=(10,10))
    
j = 0
k = 0
for i in (10, 100, 1000, 10000):        
    img = X_test[i,:,:]
    img.shape = (30,80)        
    axs[j%2][k%2].imshow(img, cmap='gray')
    axs[j%2][k%2].axis('off')
    k = (j - 1 < 1)
    j = j + 1

plt.show()

# %% [markdown]
# # 3 - Modelo
#
# Nesse trabalho implementamos Redes Neurais Convulacionais (CNN). A CNN já tem embutida em  si características que favorecem o aprendizado de imagens. Elas forçam a extração de características de forma localizada, o que explora o fato de ser benéfico a composição de características locais antes de reconhecer objetos em uma imagem.
#
# As CNNs combinam três conceitos: local receptive fields, weight sharing e spatial sub-sampling (pooling).
# Em uma aplicação típica de redes convolucionais a entrada será uma imagem. Cada unidade da camada convolucional receberá como entrada um conjunto de unidades da camada anterior, localizadas na mesma vizinhança. Esse conjunto de unidades que atua como input para a próxima camada é chamado de local receptive fields. Utilizando esse conjunto de variáveis os neurônios podem extrair características básicas da imagem como arestas ou vértices. Em camadas posteriores os neurônios estão indiretamente ligados a todos os pixels. Nessas camadas eles detectarão características mais complexas, que são composições das características mais básicas.
#
# Como a extração de características pode ser útil em toda a imagem, a convolução força as unidades a terem o mesmo conjunto de pesos (weights sharing). As unidades de uma camada são organizadas em planos chamados de feature map. As unidades em um feature map extraem a mesma característica em diversos pontos da imagem.  Uma camada convolucional podem conter diversos feature maps sendo que cada um possuirá um conjunto de pesos compartilhados e reconhecerá um padrão ou característica diferente.
#
# Uma vez que uma unidade tenha reconhecido uma característica sua posição absoluta se torna menos importante. O importante é sua posição relativa em relação aos outro padrões da imagem. Dessa forma, é relevante que a rede neural tenha uma certa resistência à traslados e distorções das entradas. Uma forma de se reduzir a precisão com que as características são inseridas em um feature map é reduzindo sua resolução, o que reduz a sensibilidade em relação a variações de posição. A forma mais comum de se implementar essa invariância é adicionando uma camada de pooling.
#
# Pooling é uma função que reduz ou resume uma  entrada utilizando alguma métrica. Algumas métricas são: pegar dentro de uma vizinhança a entrada máxima (max pooling), fazer a média das entradas (average pooling), obter a norma L2 das entradas ou tirar a média harmônica baseada na distância ao pixel central.

# %% [markdown]
# ## 3.1 - Rede Neural

# %%
################################################################################################################
#
# Modelo
#
#    Geração da rede neural com base no Keras
#
################################################################################################################

def create_net():
    
    img = layers.Input(shape=img_shape) 
    
    # Convolução
    conv1 = layers.Conv2D(16, (3, 3), padding='valid', activation='relu', use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', name='Conv_1')(img)    
    mp1 = layers.MaxPooling2D(padding='same', name='MaxPool_1')(conv1)
    
    # Convolução
    conv2 = layers.Conv2D(32, (3, 3), padding='valid', activation='relu', use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros', name='Conv_2')(mp1)
    mp2 = layers.MaxPooling2D(padding='same', name='MaxPool_2')(conv2)
    
    # Convolução
    conv3 = layers.Conv2D(32, (3, 3), padding='valid', activation='relu', use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros', name='Conv_3')(mp2)
    bn = layers.BatchNormalization()(conv3)
    
    # Camada de saída
    mp3 = layers.MaxPooling2D(padding='same', name='MaxPool_3')(bn) 
    flat = layers.Flatten()(mp3)
    
    outs = []
    for i in range(5):
        dens1 = layers.Dense(64, activation='relu')(flat)
        drop = layers.Dropout(0.5)(dens1)
        res = layers.Dense(num_symbols, name='digit%d' % i, activation='sigmoid')(drop)

        outs.append(res)
    
    model = Model(img, outs)
    model.compile('adam', loss=['categorical_crossentropy', 'categorical_crossentropy',
                                   'categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], metrics=['accuracy'])
    model.summary()
    return model

# %% [markdown]
# ## 3.2 - Funções auxiliares

# %%
################################################################################################################
#
# Variáveis Globais do Treino, tanto parametros de entrada
#
################################################################################################################

n_epoch = 500
size_batch_train = 10000
validation_split=0.2
size_batch_files = 101000

# %%
################################################################################################################
#
# Plot History
#
#    Plota os gráficos das métricas do treino, acurácia e erro do modelo e de cada digito.
#
################################################################################################################


def plot_model_history(history):
    
    # Variáveis globais que armazenam os valores unificados
    global digit_acc, val_digit_acc, loss, val_loss    
    
    # Acurácia modelo
    acc = np.sum([history.history['digit%d_accuracy' % i] for i in range(5)], axis=0)/5;
    val_acc = np.sum([history.history['val_digit%d_accuracy' % i] for i in range(5)], axis=0)/5;

    # Gráficos    
    fig, axs = plt.subplots(2,2,figsize=(20,20))
    
    # Acurácia dos Digitos    
    for i in range(5):
        axs[1][0].plot(history.history['digit' + str(i)+ '_accuracy'], label='digit%d_accuracy' % i)
        axs[1][0].plot(history.history['val_digit%d_accuracy' % i], label='val_digit%d_accuracy' % i)    
    axs[1][0].set_title('Digit Accur')
    axs[1][0].set_ylabel('Accur')
    axs[1][0].set_xlabel('Epoch')
    #axs[1][0].set_xticks(np.arange(1,len(digit_acc[0])+1),len(digit_acc[0])/10)
    axs[1][0].legend()
    
    # Erro dos Digitos    
    for i in range(5):
        axs[1][1].plot(history.history['digit' + str(i) + '_loss'], label='digit%d_loss' % i)
        axs[1][1].plot(history.history['val_digit' + str(i) + '_loss'], label='val_digit%d_loss' % i)
    axs[1][1].set_title('Digit Loss')
    axs[1][1].set_ylabel('Accur')
    axs[1][1].set_xlabel('Epoch')
    #axs[1][1].set_xticks(np.arange(1,len(digit_loss[0])+1),len(digit_loss[0])/10)
    axs[1][1].legend()

    # Acurácia do Modelo
    axs[0][0].plot(range(1,len(acc)+1),acc, label='treino')
    axs[0][0].plot(range(1,len(val_acc)+1),val_acc, label='validation')
    axs[0][0].set_title('Model Accur')
    axs[0][0].set_ylabel('Accur')
    axs[0][0].set_xlabel('Epoch')
    #axs[0][0].set_xticks(np.arange(1,len(acc)+1),len(acc)/10)
    axs[0][0].legend()
    
    # Erro do Modelo
    axs[0][1].plot(range(1,len(history.history['loss'])+1),history.history['loss'], label='treino')
    axs[0][1].plot(range(1,len(history.history['val_loss'])+1),history.history['val_loss'], label='validation')
    axs[0][1].set_title('Model Loss')
    axs[0][1].set_ylabel('Loss')
    axs[0][1].set_xlabel('Epoch')
    #axs[0][1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[0][1].legend()
    
    
    
    plt.show()

# %%
################################################################################################################
#
# Salva Pesos
#
#    Criação de função de callback para salvar os pesos da Rede Neural
#    As informações são concatenas em variáveis globais, por isso não é necessário retorno.
#    O arquivo salvo é nomeado com a época e o erro.
#
################################################################################################################

outputFolder = './output-captcha'
if not os.path.exists(outputFolder):
    os.makedirs(outputFolder)
    
filepath=outputFolder+"/weights-{epoch:02d}-{loss:.2f}.hdf5"
earlystop = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=200)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, \
                             mode='auto', period=100)
callbacks_list = [earlystop,checkpoint]

# %% [markdown]
# # 4 - Treino

# %% [markdown]
# ## 4.1 - Treino de Dataset aleatório

# %%
net_random = create_net()
history_random = net_random.fit(X_train_random, [y_train_random[0], y_train_random[1], y_train_random[2], y_train_random[3], y_train_random[4]], epochs=n_epoch, validation_split=validation_split, batch_size=size_batch_train, callbacks=callbacks_list)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 30, 80, 1)    0
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 28, 78, 16)   160         input_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_1 (MaxPooling2D)        (None, 14, 39, 16)   0           Conv_1[0][0]
# __________________________________________________________________________________________________
# Conv_2 (Conv2D)                 (None, 12, 37, 32)   4640        MaxPool_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_2 (MaxPooling2D)        (None, 6, 19, 32)    0           Conv_2[0][0]
# __________________________________________________________________________________________________
# Conv_3 (Conv2D)                 (None, 4, 17, 32)    9248        MaxPool_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4, 17, 32)    128         Conv_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_3 (MaxPooling2D)        (None, 2, 9, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 576)          0           MaxPool_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# digit0 (Dense)                  (None, 36)           2340        dropout_1[0][0]
# __________________________________________________________________________________________________
# digit1 (Dense)                  (None, 36)           2340        dropout_2[0][0]
# __________________________________________________________________________________________________
# digit2 (Dense)                  (None, 36)           2340        dropout_3[0][0]
# __________________________________________________________________________________________________
# digit3 (Dense)                  (None, 36)           2340        dropout_4[0][0]
# __________________________________________________________________________________________________
# digit4 (Dense)                  (None, 36)           2340        dropout_5[0][0]
# ==================================================================================================
# Total params: 210,516
# Trainable params: 210,452
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Train on 79928 samples, validate on 19982 samples
# Epoch 1/500
# 79928/79928 [==============================] - 16s 206us/step - loss: 17.9472 - digit0_loss: 3.5893 - digit1_loss: 3.5869 - digit2_loss: 3.5917 - digit3_loss: 3.5895 - digit4_loss: 3.5897 - digit0_accuracy: 0.0272 - digit1_accuracy: 0.0300 - digit2_accuracy: 0.0294 - digit3_accuracy: 0.0298 - digit4_accuracy: 0.0283 - val_loss: 17.9173 - val_digit0_loss: 3.5834 - val_digit1_loss: 3.5834 - val_digit2_loss: 3.5836 - val_digit3_loss: 3.5833 - val_digit4_loss: 3.5836 - val_digit0_accuracy: 0.0278 - val_digit1_accuracy: 0.0297 - val_digit2_accuracy: 0.0263 - val_digit3_accuracy: 0.0269 - val_digit4_accuracy: 0.0269
# Epoch 2/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 17.8938 - digit0_loss: 3.5799 - digit1_loss: 3.5788 - digit2_loss: 3.5791 - digit3_loss: 3.5792 - digit4_loss: 3.5767 - digit0_accuracy: 0.0318 - digit1_accuracy: 0.0342 - digit2_accuracy: 0.0318 - digit3_accuracy: 0.0327 - digit4_accuracy: 0.0341 - val_loss: 17.9167 - val_digit0_loss: 3.5834 - val_digit1_loss: 3.5832 - val_digit2_loss: 3.5833 - val_digit3_loss: 3.5832 - val_digit4_loss: 3.5835 - val_digit0_accuracy: 0.0274 - val_digit1_accuracy: 0.0297 - val_digit2_accuracy: 0.0272 - val_digit3_accuracy: 0.0280 - val_digit4_accuracy: 0.0278
# Epoch 3/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 17.8446 - digit0_loss: 3.5725 - digit1_loss: 3.5680 - digit2_loss: 3.5708 - digit3_loss: 3.5707 - digit4_loss: 3.5626 - digit0_accuracy: 0.0361 - digit1_accuracy: 0.0405 - digit2_accuracy: 0.0368 - digit3_accuracy: 0.0384 - digit4_accuracy: 0.0425 - val_loss: 17.9225 - val_digit0_loss: 3.5834 - val_digit1_loss: 3.5851 - val_digit2_loss: 3.5843 - val_digit3_loss: 3.5835 - val_digit4_loss: 3.5862 - val_digit0_accuracy: 0.0284 - val_digit1_accuracy: 0.0297 - val_digit2_accuracy: 0.0291 - val_digit3_accuracy: 0.0290 - val_digit4_accuracy: 0.0275
# Epoch 4/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 17.7360 - digit0_loss: 3.5551 - digit1_loss: 3.5446 - digit2_loss: 3.5514 - digit3_loss: 3.5525 - digit4_loss: 3.5322 - digit0_accuracy: 0.0435 - digit1_accuracy: 0.0474 - digit2_accuracy: 0.0412 - digit3_accuracy: 0.0449 - digit4_accuracy: 0.0482 - val_loss: 17.9367 - val_digit0_loss: 3.5835 - val_digit1_loss: 3.5906 - val_digit2_loss: 3.5868 - val_digit3_loss: 3.5844 - val_digit4_loss: 3.5913 - val_digit0_accuracy: 0.0272 - val_digit1_accuracy: 0.0297 - val_digit2_accuracy: 0.0291 - val_digit3_accuracy: 0.0272 - val_digit4_accuracy: 0.0275
# Epoch 5/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 17.5367 - digit0_loss: 3.5205 - digit1_loss: 3.5019 - digit2_loss: 3.5188 - digit3_loss: 3.5184 - digit4_loss: 3.4770 - digit0_accuracy: 0.0520 - digit1_accuracy: 0.0572 - digit2_accuracy: 0.0499 - digit3_accuracy: 0.0532 - digit4_accuracy: 0.0570 - val_loss: 17.9377 - val_digit0_loss: 3.5815 - val_digit1_loss: 3.5928 - val_digit2_loss: 3.5885 - val_digit3_loss: 3.5842 - val_digit4_loss: 3.5907 - val_digit0_accuracy: 0.0321 - val_digit1_accuracy: 0.0297 - val_digit2_accuracy: 0.0387 - val_digit3_accuracy: 0.0273 - val_digit4_accuracy: 0.0275
# Epoch 6/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 17.2604 - digit0_loss: 3.4666 - digit1_loss: 3.4458 - digit2_loss: 3.4746 - digit3_loss: 3.4705 - digit4_loss: 3.4026 - digit0_accuracy: 0.0616 - digit1_accuracy: 0.0655 - digit2_accuracy: 0.0583 - digit3_accuracy: 0.0626 - digit4_accuracy: 0.0695 - val_loss: 17.9317 - val_digit0_loss: 3.5771 - val_digit1_loss: 3.5885 - val_digit2_loss: 3.5894 - val_digit3_loss: 3.5855 - val_digit4_loss: 3.5912 - val_digit0_accuracy: 0.0276 - val_digit1_accuracy: 0.0269 - val_digit2_accuracy: 0.0278 - val_digit3_accuracy: 0.0296 - val_digit4_accuracy: 0.0275
# Epoch 7/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 16.9147 - digit0_loss: 3.3939 - digit1_loss: 3.3834 - digit2_loss: 3.4191 - digit3_loss: 3.4051 - digit4_loss: 3.3130 - digit0_accuracy: 0.0753 - digit1_accuracy: 0.0750 - digit2_accuracy: 0.0701 - digit3_accuracy: 0.0709 - digit4_accuracy: 0.0823 - val_loss: 17.8794 - val_digit0_loss: 3.5652 - val_digit1_loss: 3.5765 - val_digit2_loss: 3.5813 - val_digit3_loss: 3.5729 - val_digit4_loss: 3.5834 - val_digit0_accuracy: 0.0436 - val_digit1_accuracy: 0.0348 - val_digit2_accuracy: 0.0297 - val_digit3_accuracy: 0.0311 - val_digit4_accuracy: 0.0408
# Epoch 8/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 16.5616 - digit0_loss: 3.3165 - digit1_loss: 3.3146 - digit2_loss: 3.3640 - digit3_loss: 3.3404 - digit4_loss: 3.2260 - digit0_accuracy: 0.0865 - digit1_accuracy: 0.0886 - digit2_accuracy: 0.0814 - digit3_accuracy: 0.0812 - digit4_accuracy: 0.0945 - val_loss: 17.7929 - val_digit0_loss: 3.5463 - val_digit1_loss: 3.5598 - val_digit2_loss: 3.5727 - val_digit3_loss: 3.5553 - val_digit4_loss: 3.5586 - val_digit0_accuracy: 0.0513 - val_digit1_accuracy: 0.0397 - val_digit2_accuracy: 0.0476 - val_digit3_accuracy: 0.0436 - val_digit4_accuracy: 0.0405
# Epoch 9/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 16.1815 - digit0_loss: 3.2279 - digit1_loss: 3.2449 - digit2_loss: 3.3062 - digit3_loss: 3.2686 - digit4_loss: 3.1337 - digit0_accuracy: 0.0983 - digit1_accuracy: 0.0994 - digit2_accuracy: 0.0912 - digit3_accuracy: 0.0937 - digit4_accuracy: 0.1080 - val_loss: 17.6892 - val_digit0_loss: 3.5234 - val_digit1_loss: 3.5317 - val_digit2_loss: 3.5591 - val_digit3_loss: 3.5368 - val_digit4_loss: 3.5382 - val_digit0_accuracy: 0.0478 - val_digit1_accuracy: 0.0404 - val_digit2_accuracy: 0.0434 - val_digit3_accuracy: 0.0484 - val_digit4_accuracy: 0.0538
# Epoch 10/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 15.7830 - digit0_loss: 3.1328 - digit1_loss: 3.1714 - digit2_loss: 3.2449 - digit3_loss: 3.1930 - digit4_loss: 3.0408 - digit0_accuracy: 0.1115 - digit1_accuracy: 0.1130 - digit2_accuracy: 0.1034 - digit3_accuracy: 0.1061 - digit4_accuracy: 0.1213 - val_loss: 17.4521 - val_digit0_loss: 3.4857 - val_digit1_loss: 3.4750 - val_digit2_loss: 3.5148 - val_digit3_loss: 3.5010 - val_digit4_loss: 3.4756 - val_digit0_accuracy: 0.0490 - val_digit1_accuracy: 0.0691 - val_digit2_accuracy: 0.0739 - val_digit3_accuracy: 0.0470 - val_digit4_accuracy: 0.0485
# Epoch 11/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 15.3693 - digit0_loss: 3.0319 - digit1_loss: 3.0989 - digit2_loss: 3.1803 - digit3_loss: 3.1177 - digit4_loss: 2.9404 - digit0_accuracy: 0.1285 - digit1_accuracy: 0.1262 - digit2_accuracy: 0.1124 - digit3_accuracy: 0.1190 - digit4_accuracy: 0.1363 - val_loss: 17.3186 - val_digit0_loss: 3.4648 - val_digit1_loss: 3.4496 - val_digit2_loss: 3.4883 - val_digit3_loss: 3.4899 - val_digit4_loss: 3.4260 - val_digit0_accuracy: 0.0593 - val_digit1_accuracy: 0.0669 - val_digit2_accuracy: 0.0665 - val_digit3_accuracy: 0.0414 - val_digit4_accuracy: 0.0662
# Epoch 12/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 14.9629 - digit0_loss: 2.9330 - digit1_loss: 3.0328 - digit2_loss: 3.1159 - digit3_loss: 3.0462 - digit4_loss: 2.8347 - digit0_accuracy: 0.1438 - digit1_accuracy: 0.1397 - digit2_accuracy: 0.1256 - digit3_accuracy: 0.1328 - digit4_accuracy: 0.1566 - val_loss: 17.1989 - val_digit0_loss: 3.4331 - val_digit1_loss: 3.4423 - val_digit2_loss: 3.4831 - val_digit3_loss: 3.4600 - val_digit4_loss: 3.3803 - val_digit0_accuracy: 0.0747 - val_digit1_accuracy: 0.0557 - val_digit2_accuracy: 0.0536 - val_digit3_accuracy: 0.0544 - val_digit4_accuracy: 0.0613
# Epoch 13/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 14.5703 - digit0_loss: 2.8367 - digit1_loss: 2.9697 - digit2_loss: 3.0529 - digit3_loss: 2.9760 - digit4_loss: 2.7349 - digit0_accuracy: 0.1582 - digit1_accuracy: 0.1572 - digit2_accuracy: 0.1374 - digit3_accuracy: 0.1454 - digit4_accuracy: 0.1798 - val_loss: 17.1035 - val_digit0_loss: 3.4238 - val_digit1_loss: 3.4193 - val_digit2_loss: 3.4792 - val_digit3_loss: 3.4343 - val_digit4_loss: 3.3469 - val_digit0_accuracy: 0.0501 - val_digit1_accuracy: 0.0618 - val_digit2_accuracy: 0.0590 - val_digit3_accuracy: 0.0638 - val_digit4_accuracy: 0.0555
# Epoch 14/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 14.1960 - digit0_loss: 2.7452 - digit1_loss: 2.9141 - digit2_loss: 2.9914 - digit3_loss: 2.9097 - digit4_loss: 2.6354 - digit0_accuracy: 0.1724 - digit1_accuracy: 0.1660 - digit2_accuracy: 0.1494 - digit3_accuracy: 0.1576 - digit4_accuracy: 0.1977 - val_loss: 17.4853 - val_digit0_loss: 3.5022 - val_digit1_loss: 3.4985 - val_digit2_loss: 3.5838 - val_digit3_loss: 3.4949 - val_digit4_loss: 3.4059 - val_digit0_accuracy: 0.0467 - val_digit1_accuracy: 0.0552 - val_digit2_accuracy: 0.0619 - val_digit3_accuracy: 0.0479 - val_digit4_accuracy: 0.0526
# Epoch 15/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 13.8271 - digit0_loss: 2.6491 - digit1_loss: 2.8569 - digit2_loss: 2.9375 - digit3_loss: 2.8497 - digit4_loss: 2.5337 - digit0_accuracy: 0.1939 - digit1_accuracy: 0.1807 - digit2_accuracy: 0.1596 - digit3_accuracy: 0.1713 - digit4_accuracy: 0.2228 - val_loss: 16.9564 - val_digit0_loss: 3.3733 - val_digit1_loss: 3.4126 - val_digit2_loss: 3.4782 - val_digit3_loss: 3.3996 - val_digit4_loss: 3.2926 - val_digit0_accuracy: 0.0660 - val_digit1_accuracy: 0.0798 - val_digit2_accuracy: 0.0733 - val_digit3_accuracy: 0.0604 - val_digit4_accuracy: 0.0687
# Epoch 16/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 13.4700 - digit0_loss: 2.5650 - digit1_loss: 2.8065 - digit2_loss: 2.8826 - digit3_loss: 2.7896 - digit4_loss: 2.4263 - digit0_accuracy: 0.2152 - digit1_accuracy: 0.1907 - digit2_accuracy: 0.1709 - digit3_accuracy: 0.1848 - digit4_accuracy: 0.2460 - val_loss: 17.4440 - val_digit0_loss: 3.5010 - val_digit1_loss: 3.4619 - val_digit2_loss: 3.6299 - val_digit3_loss: 3.4242 - val_digit4_loss: 3.4269 - val_digit0_accuracy: 0.0644 - val_digit1_accuracy: 0.0759 - val_digit2_accuracy: 0.0579 - val_digit3_accuracy: 0.0653 - val_digit4_accuracy: 0.0877
# Epoch 17/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 13.0969 - digit0_loss: 2.4756 - digit1_loss: 2.7477 - digit2_loss: 2.8302 - digit3_loss: 2.7263 - digit4_loss: 2.3171 - digit0_accuracy: 0.2338 - digit1_accuracy: 0.2056 - digit2_accuracy: 0.1837 - digit3_accuracy: 0.2002 - digit4_accuracy: 0.2743 - val_loss: 17.2300 - val_digit0_loss: 3.4381 - val_digit1_loss: 3.4388 - val_digit2_loss: 3.5955 - val_digit3_loss: 3.3685 - val_digit4_loss: 3.3891 - val_digit0_accuracy: 0.0744 - val_digit1_accuracy: 0.0591 - val_digit2_accuracy: 0.0417 - val_digit3_accuracy: 0.0857 - val_digit4_accuracy: 0.1083
# Epoch 18/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 12.7572 - digit0_loss: 2.3897 - digit1_loss: 2.7025 - digit2_loss: 2.7789 - digit3_loss: 2.6669 - digit4_loss: 2.2191 - digit0_accuracy: 0.2531 - digit1_accuracy: 0.2180 - digit2_accuracy: 0.1989 - digit3_accuracy: 0.2160 - digit4_accuracy: 0.2970 - val_loss: 17.5035 - val_digit0_loss: 3.4881 - val_digit1_loss: 3.4516 - val_digit2_loss: 3.6314 - val_digit3_loss: 3.3705 - val_digit4_loss: 3.5619 - val_digit0_accuracy: 0.0680 - val_digit1_accuracy: 0.0703 - val_digit2_accuracy: 0.0534 - val_digit3_accuracy: 0.0919 - val_digit4_accuracy: 0.0685
# Epoch 19/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 12.4462 - digit0_loss: 2.3199 - digit1_loss: 2.6529 - digit2_loss: 2.7327 - digit3_loss: 2.6094 - digit4_loss: 2.1312 - digit0_accuracy: 0.2709 - digit1_accuracy: 0.2292 - digit2_accuracy: 0.2119 - digit3_accuracy: 0.2272 - digit4_accuracy: 0.3245 - val_loss: 17.0497 - val_digit0_loss: 3.4337 - val_digit1_loss: 3.3877 - val_digit2_loss: 3.4868 - val_digit3_loss: 3.3134 - val_digit4_loss: 3.4281 - val_digit0_accuracy: 0.0492 - val_digit1_accuracy: 0.0695 - val_digit2_accuracy: 0.0724 - val_digit3_accuracy: 0.0731 - val_digit4_accuracy: 0.0928
# Epoch 20/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 12.0879 - digit0_loss: 2.2362 - digit1_loss: 2.5965 - digit2_loss: 2.6754 - digit3_loss: 2.5531 - digit4_loss: 2.0267 - digit0_accuracy: 0.2952 - digit1_accuracy: 0.2445 - digit2_accuracy: 0.2275 - digit3_accuracy: 0.2428 - digit4_accuracy: 0.3483 - val_loss: 16.5537 - val_digit0_loss: 3.3166 - val_digit1_loss: 3.2848 - val_digit2_loss: 3.4075 - val_digit3_loss: 3.2616 - val_digit4_loss: 3.2832 - val_digit0_accuracy: 0.0651 - val_digit1_accuracy: 0.0929 - val_digit2_accuracy: 0.0805 - val_digit3_accuracy: 0.0972 - val_digit4_accuracy: 0.1209
# Epoch 21/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 11.7753 - digit0_loss: 2.1606 - digit1_loss: 2.5494 - digit2_loss: 2.6301 - digit3_loss: 2.4905 - digit4_loss: 1.9447 - digit0_accuracy: 0.3156 - digit1_accuracy: 0.2582 - digit2_accuracy: 0.2413 - digit3_accuracy: 0.2621 - digit4_accuracy: 0.3749 - val_loss: 16.8496 - val_digit0_loss: 3.3982 - val_digit1_loss: 3.3319 - val_digit2_loss: 3.4414 - val_digit3_loss: 3.2812 - val_digit4_loss: 3.3969 - val_digit0_accuracy: 0.0722 - val_digit1_accuracy: 0.0839 - val_digit2_accuracy: 0.0858 - val_digit3_accuracy: 0.0843 - val_digit4_accuracy: 0.0928
# Epoch 22/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 11.4657 - digit0_loss: 2.0831 - digit1_loss: 2.5038 - digit2_loss: 2.5821 - digit3_loss: 2.4395 - digit4_loss: 1.8570 - digit0_accuracy: 0.3396 - digit1_accuracy: 0.2722 - digit2_accuracy: 0.2538 - digit3_accuracy: 0.2782 - digit4_accuracy: 0.3998 - val_loss: 17.1258 - val_digit0_loss: 3.4891 - val_digit1_loss: 3.3536 - val_digit2_loss: 3.4569 - val_digit3_loss: 3.2978 - val_digit4_loss: 3.5283 - val_digit0_accuracy: 0.0700 - val_digit1_accuracy: 0.0840 - val_digit2_accuracy: 0.0839 - val_digit3_accuracy: 0.0802 - val_digit4_accuracy: 0.0607
# Epoch 23/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 11.1707 - digit0_loss: 2.0168 - digit1_loss: 2.4542 - digit2_loss: 2.5359 - digit3_loss: 2.3838 - digit4_loss: 1.7800 - digit0_accuracy: 0.3586 - digit1_accuracy: 0.2831 - digit2_accuracy: 0.2699 - digit3_accuracy: 0.2931 - digit4_accuracy: 0.4230 - val_loss: 17.9709 - val_digit0_loss: 3.7423 - val_digit1_loss: 3.4363 - val_digit2_loss: 3.5525 - val_digit3_loss: 3.3501 - val_digit4_loss: 3.8897 - val_digit0_accuracy: 0.0701 - val_digit1_accuracy: 0.0705 - val_digit2_accuracy: 0.0620 - val_digit3_accuracy: 0.0696 - val_digit4_accuracy: 0.0418
# Epoch 24/500
# 79928/79928 [==============================] - 4s 47us/step - loss: 10.8812 - digit0_loss: 1.9449 - digit1_loss: 2.4110 - digit2_loss: 2.4911 - digit3_loss: 2.3341 - digit4_loss: 1.6999 - digit0_accuracy: 0.3822 - digit1_accuracy: 0.2993 - digit2_accuracy: 0.2826 - digit3_accuracy: 0.3089 - digit4_accuracy: 0.4502 - val_loss: 18.7382 - val_digit0_loss: 3.9443 - val_digit1_loss: 3.5187 - val_digit2_loss: 3.6122 - val_digit3_loss: 3.4194 - val_digit4_loss: 4.2436 - val_digit0_accuracy: 0.0647 - val_digit1_accuracy: 0.0604 - val_digit2_accuracy: 0.0559 - val_digit3_accuracy: 0.0627 - val_digit4_accuracy: 0.0353
# Epoch 25/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 10.6637 - digit0_loss: 1.8920 - digit1_loss: 2.3769 - digit2_loss: 2.4570 - digit3_loss: 2.2902 - digit4_loss: 1.6476 - digit0_accuracy: 0.3959 - digit1_accuracy: 0.3099 - digit2_accuracy: 0.2930 - digit3_accuracy: 0.3224 - digit4_accuracy: 0.4706 - val_loss: 15.5149 - val_digit0_loss: 3.0655 - val_digit1_loss: 3.1028 - val_digit2_loss: 3.2096 - val_digit3_loss: 3.0863 - val_digit4_loss: 3.0506 - val_digit0_accuracy: 0.1169 - val_digit1_accuracy: 0.1383 - val_digit2_accuracy: 0.1149 - val_digit3_accuracy: 0.1570 - val_digit4_accuracy: 0.1314
# Epoch 26/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 10.4054 - digit0_loss: 1.8284 - digit1_loss: 2.3299 - digit2_loss: 2.4164 - digit3_loss: 2.2492 - digit4_loss: 1.5814 - digit0_accuracy: 0.4145 - digit1_accuracy: 0.3219 - digit2_accuracy: 0.3043 - digit3_accuracy: 0.3356 - digit4_accuracy: 0.4870 - val_loss: 16.6440 - val_digit0_loss: 3.3308 - val_digit1_loss: 3.2760 - val_digit2_loss: 3.3375 - val_digit3_loss: 3.2353 - val_digit4_loss: 3.4644 - val_digit0_accuracy: 0.0864 - val_digit1_accuracy: 0.0817 - val_digit2_accuracy: 0.0778 - val_digit3_accuracy: 0.0916 - val_digit4_accuracy: 0.0963
# Epoch 27/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 10.1537 - digit0_loss: 1.7685 - digit1_loss: 2.2877 - digit2_loss: 2.3759 - digit3_loss: 2.2000 - digit4_loss: 1.5216 - digit0_accuracy: 0.4362 - digit1_accuracy: 0.3340 - digit2_accuracy: 0.3181 - digit3_accuracy: 0.3478 - digit4_accuracy: 0.5068 - val_loss: 17.3419 - val_digit0_loss: 3.5100 - val_digit1_loss: 3.3673 - val_digit2_loss: 3.4136 - val_digit3_loss: 3.2586 - val_digit4_loss: 3.7924 - val_digit0_accuracy: 0.0766 - val_digit1_accuracy: 0.0793 - val_digit2_accuracy: 0.0598 - val_digit3_accuracy: 0.0805 - val_digit4_accuracy: 0.0770
# Epoch 28/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.9174 - digit0_loss: 1.7150 - digit1_loss: 2.2461 - digit2_loss: 2.3373 - digit3_loss: 2.1559 - digit4_loss: 1.4630 - digit0_accuracy: 0.4557 - digit1_accuracy: 0.3484 - digit2_accuracy: 0.3330 - digit3_accuracy: 0.3613 - digit4_accuracy: 0.5232 - val_loss: 17.9811 - val_digit0_loss: 3.7058 - val_digit1_loss: 3.3887 - val_digit2_loss: 3.4774 - val_digit3_loss: 3.3357 - val_digit4_loss: 4.0735 - val_digit0_accuracy: 0.0718 - val_digit1_accuracy: 0.0757 - val_digit2_accuracy: 0.0588 - val_digit3_accuracy: 0.0715 - val_digit4_accuracy: 0.0716
# Epoch 29/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.7102 - digit0_loss: 1.6683 - digit1_loss: 2.2114 - digit2_loss: 2.3002 - digit3_loss: 2.1148 - digit4_loss: 1.4156 - digit0_accuracy: 0.4688 - digit1_accuracy: 0.3606 - digit2_accuracy: 0.3414 - digit3_accuracy: 0.3749 - digit4_accuracy: 0.5405 - val_loss: 17.9061 - val_digit0_loss: 3.6890 - val_digit1_loss: 3.3538 - val_digit2_loss: 3.4504 - val_digit3_loss: 3.2965 - val_digit4_loss: 4.1163 - val_digit0_accuracy: 0.0706 - val_digit1_accuracy: 0.0766 - val_digit2_accuracy: 0.0589 - val_digit3_accuracy: 0.0752 - val_digit4_accuracy: 0.0732
# Epoch 30/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.5207 - digit0_loss: 1.6230 - digit1_loss: 2.1745 - digit2_loss: 2.2688 - digit3_loss: 2.0796 - digit4_loss: 1.3748 - digit0_accuracy: 0.4835 - digit1_accuracy: 0.3683 - digit2_accuracy: 0.3509 - digit3_accuracy: 0.3860 - digit4_accuracy: 0.5540 - val_loss: 18.4327 - val_digit0_loss: 3.8321 - val_digit1_loss: 3.3860 - val_digit2_loss: 3.4943 - val_digit3_loss: 3.3893 - val_digit4_loss: 4.3310 - val_digit0_accuracy: 0.0707 - val_digit1_accuracy: 0.0802 - val_digit2_accuracy: 0.0652 - val_digit3_accuracy: 0.0701 - val_digit4_accuracy: 0.0740
# Epoch 31/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.3429 - digit0_loss: 1.5818 - digit1_loss: 2.1463 - digit2_loss: 2.2354 - digit3_loss: 2.0452 - digit4_loss: 1.3340 - digit0_accuracy: 0.4980 - digit1_accuracy: 0.3775 - digit2_accuracy: 0.3608 - digit3_accuracy: 0.3960 - digit4_accuracy: 0.5669 - val_loss: 19.5309 - val_digit0_loss: 4.1251 - val_digit1_loss: 3.5622 - val_digit2_loss: 3.6066 - val_digit3_loss: 3.6003 - val_digit4_loss: 4.6368 - val_digit0_accuracy: 0.0647 - val_digit1_accuracy: 0.0724 - val_digit2_accuracy: 0.0655 - val_digit3_accuracy: 0.0573 - val_digit4_accuracy: 0.0705
# Epoch 32/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.1664 - digit0_loss: 1.5391 - digit1_loss: 2.1139 - digit2_loss: 2.2088 - digit3_loss: 2.0129 - digit4_loss: 1.2916 - digit0_accuracy: 0.5100 - digit1_accuracy: 0.3863 - digit2_accuracy: 0.3696 - digit3_accuracy: 0.4065 - digit4_accuracy: 0.5813 - val_loss: 19.6686 - val_digit0_loss: 4.1759 - val_digit1_loss: 3.5150 - val_digit2_loss: 3.5745 - val_digit3_loss: 3.5537 - val_digit4_loss: 4.8495 - val_digit0_accuracy: 0.0677 - val_digit1_accuracy: 0.0728 - val_digit2_accuracy: 0.0684 - val_digit3_accuracy: 0.0669 - val_digit4_accuracy: 0.0726
# Epoch 33/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.9854 - digit0_loss: 1.5003 - digit1_loss: 2.0784 - digit2_loss: 2.1821 - digit3_loss: 1.9680 - digit4_loss: 1.2565 - digit0_accuracy: 0.5247 - digit1_accuracy: 0.3973 - digit2_accuracy: 0.3792 - digit3_accuracy: 0.4174 - digit4_accuracy: 0.5917 - val_loss: 19.7189 - val_digit0_loss: 4.1685 - val_digit1_loss: 3.4792 - val_digit2_loss: 3.5404 - val_digit3_loss: 3.5596 - val_digit4_loss: 4.9712 - val_digit0_accuracy: 0.0736 - val_digit1_accuracy: 0.0765 - val_digit2_accuracy: 0.0737 - val_digit3_accuracy: 0.0665 - val_digit4_accuracy: 0.0717
# Epoch 34/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.8194 - digit0_loss: 1.4650 - digit1_loss: 2.0490 - digit2_loss: 2.1429 - digit3_loss: 1.9431 - digit4_loss: 1.2193 - digit0_accuracy: 0.5336 - digit1_accuracy: 0.4063 - digit2_accuracy: 0.3890 - digit3_accuracy: 0.4281 - digit4_accuracy: 0.6044 - val_loss: 20.3922 - val_digit0_loss: 4.3370 - val_digit1_loss: 3.5339 - val_digit2_loss: 3.6163 - val_digit3_loss: 3.6458 - val_digit4_loss: 5.2592 - val_digit0_accuracy: 0.0668 - val_digit1_accuracy: 0.0717 - val_digit2_accuracy: 0.0775 - val_digit3_accuracy: 0.0651 - val_digit4_accuracy: 0.0670
# Epoch 35/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.6710 - digit0_loss: 1.4330 - digit1_loss: 2.0152 - digit2_loss: 2.1209 - digit3_loss: 1.9128 - digit4_loss: 1.1890 - digit0_accuracy: 0.5435 - digit1_accuracy: 0.4198 - digit2_accuracy: 0.3956 - digit3_accuracy: 0.4355 - digit4_accuracy: 0.6125 - val_loss: 20.6072 - val_digit0_loss: 4.3653 - val_digit1_loss: 3.5496 - val_digit2_loss: 3.6477 - val_digit3_loss: 3.6795 - val_digit4_loss: 5.3650 - val_digit0_accuracy: 0.0691 - val_digit1_accuracy: 0.0748 - val_digit2_accuracy: 0.0800 - val_digit3_accuracy: 0.0693 - val_digit4_accuracy: 0.0683
# Epoch 36/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.5231 - digit0_loss: 1.3948 - digit1_loss: 1.9923 - digit2_loss: 2.0916 - digit3_loss: 1.8832 - digit4_loss: 1.1612 - digit0_accuracy: 0.5553 - digit1_accuracy: 0.4228 - digit2_accuracy: 0.4035 - digit3_accuracy: 0.4442 - digit4_accuracy: 0.6241 - val_loss: 21.0880 - val_digit0_loss: 4.4763 - val_digit1_loss: 3.5778 - val_digit2_loss: 3.6778 - val_digit3_loss: 3.7359 - val_digit4_loss: 5.6202 - val_digit0_accuracy: 0.0726 - val_digit1_accuracy: 0.0812 - val_digit2_accuracy: 0.0825 - val_digit3_accuracy: 0.0696 - val_digit4_accuracy: 0.0712
# Epoch 37/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.3918 - digit0_loss: 1.3651 - digit1_loss: 1.9675 - digit2_loss: 2.0668 - digit3_loss: 1.8576 - digit4_loss: 1.1349 - digit0_accuracy: 0.5681 - digit1_accuracy: 0.4323 - digit2_accuracy: 0.4111 - digit3_accuracy: 0.4507 - digit4_accuracy: 0.6288 - val_loss: 20.7343 - val_digit0_loss: 4.3989 - val_digit1_loss: 3.5570 - val_digit2_loss: 3.6477 - val_digit3_loss: 3.7207 - val_digit4_loss: 5.4100 - val_digit0_accuracy: 0.0726 - val_digit1_accuracy: 0.0845 - val_digit2_accuracy: 0.0916 - val_digit3_accuracy: 0.0723 - val_digit4_accuracy: 0.0688
# Epoch 38/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.2732 - digit0_loss: 1.3417 - digit1_loss: 1.9459 - digit2_loss: 2.0433 - digit3_loss: 1.8302 - digit4_loss: 1.1120 - digit0_accuracy: 0.5728 - digit1_accuracy: 0.4368 - digit2_accuracy: 0.4180 - digit3_accuracy: 0.4603 - digit4_accuracy: 0.6378 - val_loss: 20.9065 - val_digit0_loss: 4.3907 - val_digit1_loss: 3.5831 - val_digit2_loss: 3.6710 - val_digit3_loss: 3.7598 - val_digit4_loss: 5.5020 - val_digit0_accuracy: 0.0757 - val_digit1_accuracy: 0.0887 - val_digit2_accuracy: 0.0909 - val_digit3_accuracy: 0.0737 - val_digit4_accuracy: 0.0728
# Epoch 39/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.1689 - digit0_loss: 1.3159 - digit1_loss: 1.9185 - digit2_loss: 2.0323 - digit3_loss: 1.8091 - digit4_loss: 1.0930 - digit0_accuracy: 0.5832 - digit1_accuracy: 0.4468 - digit2_accuracy: 0.4208 - digit3_accuracy: 0.4647 - digit4_accuracy: 0.6442 - val_loss: 19.2306 - val_digit0_loss: 3.9771 - val_digit1_loss: 3.2978 - val_digit2_loss: 3.3635 - val_digit3_loss: 3.4116 - val_digit4_loss: 5.1806 - val_digit0_accuracy: 0.1011 - val_digit1_accuracy: 0.1178 - val_digit2_accuracy: 0.1124 - val_digit3_accuracy: 0.1019 - val_digit4_accuracy: 0.0835
# Epoch 40/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.0467 - digit0_loss: 1.2875 - digit1_loss: 1.8998 - digit2_loss: 2.0026 - digit3_loss: 1.7886 - digit4_loss: 1.0681 - digit0_accuracy: 0.5901 - digit1_accuracy: 0.4518 - digit2_accuracy: 0.4286 - digit3_accuracy: 0.4708 - digit4_accuracy: 0.6520 - val_loss: 20.0742 - val_digit0_loss: 4.2362 - val_digit1_loss: 3.4478 - val_digit2_loss: 3.5175 - val_digit3_loss: 3.5937 - val_digit4_loss: 5.2791 - val_digit0_accuracy: 0.0828 - val_digit1_accuracy: 0.1028 - val_digit2_accuracy: 0.1033 - val_digit3_accuracy: 0.0821 - val_digit4_accuracy: 0.0679
# Epoch 41/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.9393 - digit0_loss: 1.2636 - digit1_loss: 1.8790 - digit2_loss: 1.9799 - digit3_loss: 1.7689 - digit4_loss: 1.0479 - digit0_accuracy: 0.5992 - digit1_accuracy: 0.4576 - digit2_accuracy: 0.4358 - digit3_accuracy: 0.4783 - digit4_accuracy: 0.6595 - val_loss: 20.8817 - val_digit0_loss: 4.3576 - val_digit1_loss: 3.5046 - val_digit2_loss: 3.6041 - val_digit3_loss: 3.7326 - val_digit4_loss: 5.6829 - val_digit0_accuracy: 0.0876 - val_digit1_accuracy: 0.1064 - val_digit2_accuracy: 0.1024 - val_digit3_accuracy: 0.0826 - val_digit4_accuracy: 0.0757
# Epoch 42/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.8505 - digit0_loss: 1.2435 - digit1_loss: 1.8616 - digit2_loss: 1.9666 - digit3_loss: 1.7524 - digit4_loss: 1.0263 - digit0_accuracy: 0.6056 - digit1_accuracy: 0.4589 - digit2_accuracy: 0.4380 - digit3_accuracy: 0.4843 - digit4_accuracy: 0.6647 - val_loss: 19.1297 - val_digit0_loss: 3.9894 - val_digit1_loss: 3.2547 - val_digit2_loss: 3.3425 - val_digit3_loss: 3.3851 - val_digit4_loss: 5.1581 - val_digit0_accuracy: 0.1050 - val_digit1_accuracy: 0.1314 - val_digit2_accuracy: 0.1289 - val_digit3_accuracy: 0.1081 - val_digit4_accuracy: 0.0813
# Epoch 43/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.7520 - digit0_loss: 1.2250 - digit1_loss: 1.8437 - digit2_loss: 1.9472 - digit3_loss: 1.7263 - digit4_loss: 1.0098 - digit0_accuracy: 0.6099 - digit1_accuracy: 0.4663 - digit2_accuracy: 0.4456 - digit3_accuracy: 0.4890 - digit4_accuracy: 0.6698 - val_loss: 17.8108 - val_digit0_loss: 3.6600 - val_digit1_loss: 3.0564 - val_digit2_loss: 3.1788 - val_digit3_loss: 3.1778 - val_digit4_loss: 4.7379 - val_digit0_accuracy: 0.1264 - val_digit1_accuracy: 0.1563 - val_digit2_accuracy: 0.1456 - val_digit3_accuracy: 0.1235 - val_digit4_accuracy: 0.0896
# Epoch 44/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.6654 - digit0_loss: 1.2007 - digit1_loss: 1.8245 - digit2_loss: 1.9357 - digit3_loss: 1.7120 - digit4_loss: 0.9923 - digit0_accuracy: 0.6186 - digit1_accuracy: 0.4711 - digit2_accuracy: 0.4468 - digit3_accuracy: 0.4940 - digit4_accuracy: 0.6763 - val_loss: 16.8330 - val_digit0_loss: 3.4282 - val_digit1_loss: 2.9186 - val_digit2_loss: 3.0073 - val_digit3_loss: 2.9834 - val_digit4_loss: 4.4955 - val_digit0_accuracy: 0.1507 - val_digit1_accuracy: 0.1810 - val_digit2_accuracy: 0.1700 - val_digit3_accuracy: 0.1574 - val_digit4_accuracy: 0.1034
# Epoch 45/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.5858 - digit0_loss: 1.1825 - digit1_loss: 1.8106 - digit2_loss: 1.9116 - digit3_loss: 1.7029 - digit4_loss: 0.9782 - digit0_accuracy: 0.6222 - digit1_accuracy: 0.4749 - digit2_accuracy: 0.4542 - digit3_accuracy: 0.4956 - digit4_accuracy: 0.6788 - val_loss: 16.3178 - val_digit0_loss: 3.2906 - val_digit1_loss: 2.8259 - val_digit2_loss: 2.9411 - val_digit3_loss: 2.8752 - val_digit4_loss: 4.3850 - val_digit0_accuracy: 0.1683 - val_digit1_accuracy: 0.2009 - val_digit2_accuracy: 0.1839 - val_digit3_accuracy: 0.1779 - val_digit4_accuracy: 0.1116
# Epoch 46/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.5071 - digit0_loss: 1.1719 - digit1_loss: 1.7929 - digit2_loss: 1.8980 - digit3_loss: 1.6801 - digit4_loss: 0.9641 - digit0_accuracy: 0.6256 - digit1_accuracy: 0.4793 - digit2_accuracy: 0.4593 - digit3_accuracy: 0.5028 - digit4_accuracy: 0.6833 - val_loss: 17.5561 - val_digit0_loss: 3.5361 - val_digit1_loss: 2.9582 - val_digit2_loss: 3.0901 - val_digit3_loss: 3.0782 - val_digit4_loss: 4.8936 - val_digit0_accuracy: 0.1529 - val_digit1_accuracy: 0.1881 - val_digit2_accuracy: 0.1744 - val_digit3_accuracy: 0.1529 - val_digit4_accuracy: 0.1002
# Epoch 47/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.4153 - digit0_loss: 1.1548 - digit1_loss: 1.7728 - digit2_loss: 1.8806 - digit3_loss: 1.6634 - digit4_loss: 0.9436 - digit0_accuracy: 0.6335 - digit1_accuracy: 0.4868 - digit2_accuracy: 0.4630 - digit3_accuracy: 0.5061 - digit4_accuracy: 0.6907 - val_loss: 15.2253 - val_digit0_loss: 3.0016 - val_digit1_loss: 2.6775 - val_digit2_loss: 2.7929 - val_digit3_loss: 2.7575 - val_digit4_loss: 3.9959 - val_digit0_accuracy: 0.2089 - val_digit1_accuracy: 0.2390 - val_digit2_accuracy: 0.2227 - val_digit3_accuracy: 0.2084 - val_digit4_accuracy: 0.1410
# Epoch 48/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.3343 - digit0_loss: 1.1316 - digit1_loss: 1.7494 - digit2_loss: 1.8656 - digit3_loss: 1.6525 - digit4_loss: 0.9351 - digit0_accuracy: 0.6400 - digit1_accuracy: 0.4912 - digit2_accuracy: 0.4650 - digit3_accuracy: 0.5104 - digit4_accuracy: 0.6925 - val_loss: 14.5397 - val_digit0_loss: 2.8445 - val_digit1_loss: 2.6120 - val_digit2_loss: 2.6994 - val_digit3_loss: 2.6487 - val_digit4_loss: 3.7351 - val_digit0_accuracy: 0.2341 - val_digit1_accuracy: 0.2564 - val_digit2_accuracy: 0.2480 - val_digit3_accuracy: 0.2379 - val_digit4_accuracy: 0.1623
# Epoch 49/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.2754 - digit0_loss: 1.1162 - digit1_loss: 1.7470 - digit2_loss: 1.8567 - digit3_loss: 1.6337 - digit4_loss: 0.9219 - digit0_accuracy: 0.6447 - digit1_accuracy: 0.4904 - digit2_accuracy: 0.4706 - digit3_accuracy: 0.5159 - digit4_accuracy: 0.6980 - val_loss: 15.3141 - val_digit0_loss: 2.9765 - val_digit1_loss: 2.6430 - val_digit2_loss: 2.7643 - val_digit3_loss: 2.6677 - val_digit4_loss: 4.2627 - val_digit0_accuracy: 0.2238 - val_digit1_accuracy: 0.2509 - val_digit2_accuracy: 0.2337 - val_digit3_accuracy: 0.2338 - val_digit4_accuracy: 0.1386
# Epoch 50/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.1949 - digit0_loss: 1.1010 - digit1_loss: 1.7310 - digit2_loss: 1.8376 - digit3_loss: 1.6218 - digit4_loss: 0.9036 - digit0_accuracy: 0.6486 - digit1_accuracy: 0.4973 - digit2_accuracy: 0.4764 - digit3_accuracy: 0.5180 - digit4_accuracy: 0.7019 - val_loss: 14.4591 - val_digit0_loss: 2.7753 - val_digit1_loss: 2.5527 - val_digit2_loss: 2.6689 - val_digit3_loss: 2.5831 - val_digit4_loss: 3.8793 - val_digit0_accuracy: 0.2516 - val_digit1_accuracy: 0.2709 - val_digit2_accuracy: 0.2546 - val_digit3_accuracy: 0.2580 - val_digit4_accuracy: 0.1653
# Epoch 51/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.1347 - digit0_loss: 1.0876 - digit1_loss: 1.7127 - digit2_loss: 1.8288 - digit3_loss: 1.6113 - digit4_loss: 0.8943 - digit0_accuracy: 0.6534 - digit1_accuracy: 0.5014 - digit2_accuracy: 0.4756 - digit3_accuracy: 0.5241 - digit4_accuracy: 0.7063 - val_loss: 13.1096 - val_digit0_loss: 2.4684 - val_digit1_loss: 2.3686 - val_digit2_loss: 2.4801 - val_digit3_loss: 2.3954 - val_digit4_loss: 3.3972 - val_digit0_accuracy: 0.3030 - val_digit1_accuracy: 0.3198 - val_digit2_accuracy: 0.3051 - val_digit3_accuracy: 0.3013 - val_digit4_accuracy: 0.2113
# Epoch 52/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.0624 - digit0_loss: 1.0716 - digit1_loss: 1.7021 - digit2_loss: 1.8084 - digit3_loss: 1.6012 - digit4_loss: 0.8790 - digit0_accuracy: 0.6575 - digit1_accuracy: 0.5058 - digit2_accuracy: 0.4816 - digit3_accuracy: 0.5242 - digit4_accuracy: 0.7098 - val_loss: 12.9975 - val_digit0_loss: 2.4642 - val_digit1_loss: 2.3490 - val_digit2_loss: 2.4523 - val_digit3_loss: 2.3660 - val_digit4_loss: 3.3660 - val_digit0_accuracy: 0.3072 - val_digit1_accuracy: 0.3270 - val_digit2_accuracy: 0.3133 - val_digit3_accuracy: 0.3115 - val_digit4_accuracy: 0.2110
# Epoch 53/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.0013 - digit0_loss: 1.0520 - digit1_loss: 1.6844 - digit2_loss: 1.8005 - digit3_loss: 1.5877 - digit4_loss: 0.8768 - digit0_accuracy: 0.6641 - digit1_accuracy: 0.5090 - digit2_accuracy: 0.4841 - digit3_accuracy: 0.5289 - digit4_accuracy: 0.7120 - val_loss: 12.2270 - val_digit0_loss: 2.2535 - val_digit1_loss: 2.2385 - val_digit2_loss: 2.3338 - val_digit3_loss: 2.2298 - val_digit4_loss: 3.1714 - val_digit0_accuracy: 0.3467 - val_digit1_accuracy: 0.3578 - val_digit2_accuracy: 0.3423 - val_digit3_accuracy: 0.3466 - val_digit4_accuracy: 0.2460
# Epoch 54/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.9415 - digit0_loss: 1.0405 - digit1_loss: 1.6740 - digit2_loss: 1.7901 - digit3_loss: 1.5755 - digit4_loss: 0.8613 - digit0_accuracy: 0.6680 - digit1_accuracy: 0.5107 - digit2_accuracy: 0.4868 - digit3_accuracy: 0.5332 - digit4_accuracy: 0.7163 - val_loss: 11.6262 - val_digit0_loss: 2.1032 - val_digit1_loss: 2.1452 - val_digit2_loss: 2.2711 - val_digit3_loss: 2.1512 - val_digit4_loss: 2.9555 - val_digit0_accuracy: 0.3804 - val_digit1_accuracy: 0.3851 - val_digit2_accuracy: 0.3620 - val_digit3_accuracy: 0.3721 - val_digit4_accuracy: 0.2773
# Epoch 55/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.8851 - digit0_loss: 1.0340 - digit1_loss: 1.6628 - digit2_loss: 1.7742 - digit3_loss: 1.5629 - digit4_loss: 0.8511 - digit0_accuracy: 0.6696 - digit1_accuracy: 0.5119 - digit2_accuracy: 0.4911 - digit3_accuracy: 0.5370 - digit4_accuracy: 0.7195 - val_loss: 11.1652 - val_digit0_loss: 2.0108 - val_digit1_loss: 2.0991 - val_digit2_loss: 2.2103 - val_digit3_loss: 2.0805 - val_digit4_loss: 2.7646 - val_digit0_accuracy: 0.4050 - val_digit1_accuracy: 0.4041 - val_digit2_accuracy: 0.3824 - val_digit3_accuracy: 0.3949 - val_digit4_accuracy: 0.3039
# Epoch 56/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.8177 - digit0_loss: 1.0186 - digit1_loss: 1.6457 - digit2_loss: 1.7586 - digit3_loss: 1.5509 - digit4_loss: 0.8439 - digit0_accuracy: 0.6742 - digit1_accuracy: 0.5183 - digit2_accuracy: 0.4963 - digit3_accuracy: 0.5398 - digit4_accuracy: 0.7203 - val_loss: 10.7665 - val_digit0_loss: 1.9795 - val_digit1_loss: 2.0272 - val_digit2_loss: 2.1600 - val_digit3_loss: 2.0297 - val_digit4_loss: 2.5701 - val_digit0_accuracy: 0.4164 - val_digit1_accuracy: 0.4256 - val_digit2_accuracy: 0.3975 - val_digit3_accuracy: 0.4096 - val_digit4_accuracy: 0.3321
# Epoch 57/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.7621 - digit0_loss: 1.0032 - digit1_loss: 1.6374 - digit2_loss: 1.7554 - digit3_loss: 1.5343 - digit4_loss: 0.8318 - digit0_accuracy: 0.6773 - digit1_accuracy: 0.5218 - digit2_accuracy: 0.4960 - digit3_accuracy: 0.5425 - digit4_accuracy: 0.7247 - val_loss: 9.6058 - val_digit0_loss: 1.6885 - val_digit1_loss: 1.8985 - val_digit2_loss: 1.9846 - val_digit3_loss: 1.8591 - val_digit4_loss: 2.1750 - val_digit0_accuracy: 0.4862 - val_digit1_accuracy: 0.4636 - val_digit2_accuracy: 0.4505 - val_digit3_accuracy: 0.4665 - val_digit4_accuracy: 0.4026
# Epoch 58/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.7099 - digit0_loss: 0.9954 - digit1_loss: 1.6198 - digit2_loss: 1.7447 - digit3_loss: 1.5258 - digit4_loss: 0.8242 - digit0_accuracy: 0.6810 - digit1_accuracy: 0.5229 - digit2_accuracy: 0.4976 - digit3_accuracy: 0.5442 - digit4_accuracy: 0.7278 - val_loss: 8.9780 - val_digit0_loss: 1.5615 - val_digit1_loss: 1.8083 - val_digit2_loss: 1.9361 - val_digit3_loss: 1.7577 - val_digit4_loss: 1.9144 - val_digit0_accuracy: 0.5204 - val_digit1_accuracy: 0.5035 - val_digit2_accuracy: 0.4685 - val_digit3_accuracy: 0.5020 - val_digit4_accuracy: 0.4535
# Epoch 59/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.6396 - digit0_loss: 0.9785 - digit1_loss: 1.6041 - digit2_loss: 1.7270 - digit3_loss: 1.5156 - digit4_loss: 0.8144 - digit0_accuracy: 0.6860 - digit1_accuracy: 0.5279 - digit2_accuracy: 0.5043 - digit3_accuracy: 0.5495 - digit4_accuracy: 0.7317 - val_loss: 8.2397 - val_digit0_loss: 1.4014 - val_digit1_loss: 1.7251 - val_digit2_loss: 1.8248 - val_digit3_loss: 1.6668 - val_digit4_loss: 1.6216 - val_digit0_accuracy: 0.5682 - val_digit1_accuracy: 0.5341 - val_digit2_accuracy: 0.5100 - val_digit3_accuracy: 0.5297 - val_digit4_accuracy: 0.5208
# Epoch 60/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.5935 - digit0_loss: 0.9671 - digit1_loss: 1.6007 - digit2_loss: 1.7184 - digit3_loss: 1.5056 - digit4_loss: 0.8016 - digit0_accuracy: 0.6909 - digit1_accuracy: 0.5287 - digit2_accuracy: 0.5057 - digit3_accuracy: 0.5501 - digit4_accuracy: 0.7334 - val_loss: 7.8026 - val_digit0_loss: 1.3088 - val_digit1_loss: 1.6500 - val_digit2_loss: 1.7693 - val_digit3_loss: 1.5886 - val_digit4_loss: 1.4860 - val_digit0_accuracy: 0.5976 - val_digit1_accuracy: 0.5574 - val_digit2_accuracy: 0.5242 - val_digit3_accuracy: 0.5600 - val_digit4_accuracy: 0.5538
# Epoch 61/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.5511 - digit0_loss: 0.9631 - digit1_loss: 1.5903 - digit2_loss: 1.7093 - digit3_loss: 1.4913 - digit4_loss: 0.7971 - digit0_accuracy: 0.6910 - digit1_accuracy: 0.5326 - digit2_accuracy: 0.5118 - digit3_accuracy: 0.5543 - digit4_accuracy: 0.7362 - val_loss: 7.5863 - val_digit0_loss: 1.2271 - val_digit1_loss: 1.6139 - val_digit2_loss: 1.7113 - val_digit3_loss: 1.5688 - val_digit4_loss: 1.4652 - val_digit0_accuracy: 0.6222 - val_digit1_accuracy: 0.5637 - val_digit2_accuracy: 0.5436 - val_digit3_accuracy: 0.5615 - val_digit4_accuracy: 0.5611
# Epoch 62/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.5078 - digit0_loss: 0.9494 - digit1_loss: 1.5804 - digit2_loss: 1.7017 - digit3_loss: 1.4885 - digit4_loss: 0.7878 - digit0_accuracy: 0.6972 - digit1_accuracy: 0.5357 - digit2_accuracy: 0.5100 - digit3_accuracy: 0.5558 - digit4_accuracy: 0.7387 - val_loss: 7.6545 - val_digit0_loss: 1.2683 - val_digit1_loss: 1.6060 - val_digit2_loss: 1.7103 - val_digit3_loss: 1.5402 - val_digit4_loss: 1.5297 - val_digit0_accuracy: 0.6096 - val_digit1_accuracy: 0.5618 - val_digit2_accuracy: 0.5399 - val_digit3_accuracy: 0.5703 - val_digit4_accuracy: 0.5504
# Epoch 63/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.4611 - digit0_loss: 0.9367 - digit1_loss: 1.5749 - digit2_loss: 1.6949 - digit3_loss: 1.4741 - digit4_loss: 0.7805 - digit0_accuracy: 0.7005 - digit1_accuracy: 0.5364 - digit2_accuracy: 0.5145 - digit3_accuracy: 0.5600 - digit4_accuracy: 0.7426 - val_loss: 8.0125 - val_digit0_loss: 1.2883 - val_digit1_loss: 1.6332 - val_digit2_loss: 1.7357 - val_digit3_loss: 1.5921 - val_digit4_loss: 1.7633 - val_digit0_accuracy: 0.6021 - val_digit1_accuracy: 0.5445 - val_digit2_accuracy: 0.5209 - val_digit3_accuracy: 0.5409 - val_digit4_accuracy: 0.5102
# Epoch 64/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.4273 - digit0_loss: 0.9300 - digit1_loss: 1.5650 - digit2_loss: 1.6883 - digit3_loss: 1.4726 - digit4_loss: 0.7714 - digit0_accuracy: 0.7028 - digit1_accuracy: 0.5410 - digit2_accuracy: 0.5155 - digit3_accuracy: 0.5611 - digit4_accuracy: 0.7436 - val_loss: 8.4399 - val_digit0_loss: 1.2983 - val_digit1_loss: 1.6673 - val_digit2_loss: 1.7973 - val_digit3_loss: 1.6359 - val_digit4_loss: 2.0411 - val_digit0_accuracy: 0.5992 - val_digit1_accuracy: 0.5240 - val_digit2_accuracy: 0.4915 - val_digit3_accuracy: 0.5285 - val_digit4_accuracy: 0.4702
# Epoch 65/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.3760 - digit0_loss: 0.9174 - digit1_loss: 1.5529 - digit2_loss: 1.6770 - digit3_loss: 1.4616 - digit4_loss: 0.7670 - digit0_accuracy: 0.7083 - digit1_accuracy: 0.5426 - digit2_accuracy: 0.5172 - digit3_accuracy: 0.5650 - digit4_accuracy: 0.7440 - val_loss: 9.1829 - val_digit0_loss: 1.4097 - val_digit1_loss: 1.7436 - val_digit2_loss: 1.8443 - val_digit3_loss: 1.7507 - val_digit4_loss: 2.4346 - val_digit0_accuracy: 0.5776 - val_digit1_accuracy: 0.5021 - val_digit2_accuracy: 0.4819 - val_digit3_accuracy: 0.4929 - val_digit4_accuracy: 0.4215
# Epoch 66/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.3319 - digit0_loss: 0.9081 - digit1_loss: 1.5409 - digit2_loss: 1.6661 - digit3_loss: 1.4577 - digit4_loss: 0.7591 - digit0_accuracy: 0.7097 - digit1_accuracy: 0.5447 - digit2_accuracy: 0.5206 - digit3_accuracy: 0.5636 - digit4_accuracy: 0.7474 - val_loss: 8.8356 - val_digit0_loss: 1.3059 - val_digit1_loss: 1.6898 - val_digit2_loss: 1.8158 - val_digit3_loss: 1.7056 - val_digit4_loss: 2.3185 - val_digit0_accuracy: 0.6069 - val_digit1_accuracy: 0.5141 - val_digit2_accuracy: 0.4860 - val_digit3_accuracy: 0.5080 - val_digit4_accuracy: 0.4475
# Epoch 67/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.3012 - digit0_loss: 0.8995 - digit1_loss: 1.5376 - digit2_loss: 1.6644 - digit3_loss: 1.4468 - digit4_loss: 0.7530 - digit0_accuracy: 0.7105 - digit1_accuracy: 0.5474 - digit2_accuracy: 0.5211 - digit3_accuracy: 0.5659 - digit4_accuracy: 0.7513 - val_loss: 12.6662 - val_digit0_loss: 1.7610 - val_digit1_loss: 2.1746 - val_digit2_loss: 2.3079 - val_digit3_loss: 2.3168 - val_digit4_loss: 4.1059 - val_digit0_accuracy: 0.5157 - val_digit1_accuracy: 0.4037 - val_digit2_accuracy: 0.3825 - val_digit3_accuracy: 0.3887 - val_digit4_accuracy: 0.2875
# Epoch 68/500
# ...
# Epoch 476/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.3489 - digit0_loss: 0.3382 - digit1_loss: 0.8820 - digit2_loss: 1.0386 - digit3_loss: 0.8109 - digit4_loss: 0.2793 - digit0_accuracy: 0.8796 - digit1_accuracy: 0.7179 - digit2_accuracy: 0.6853 - digit3_accuracy: 0.7395 - digit4_accuracy: 0.8955 - val_loss: 2.2686 - val_digit0_loss: 0.2667 - val_digit1_loss: 0.5889 - val_digit2_loss: 0.6803 - val_digit3_loss: 0.5212 - val_digit4_loss: 0.2115 - val_digit0_accuracy: 0.9088 - val_digit1_accuracy: 0.8264 - val_digit2_accuracy: 0.8126 - val_digit3_accuracy: 0.8480 - val_digit4_accuracy: 0.9242
# Epoch 477/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3479 - digit0_loss: 0.3394 - digit1_loss: 0.8833 - digit2_loss: 1.0327 - digit3_loss: 0.8154 - digit4_loss: 0.2771 - digit0_accuracy: 0.8778 - digit1_accuracy: 0.7204 - digit2_accuracy: 0.6863 - digit3_accuracy: 0.7396 - digit4_accuracy: 0.8965 - val_loss: 2.2745 - val_digit0_loss: 0.2671 - val_digit1_loss: 0.5895 - val_digit2_loss: 0.6829 - val_digit3_loss: 0.5233 - val_digit4_loss: 0.2116 - val_digit0_accuracy: 0.9090 - val_digit1_accuracy: 0.8267 - val_digit2_accuracy: 0.8118 - val_digit3_accuracy: 0.8478 - val_digit4_accuracy: 0.9246
# Epoch 478/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.3658 - digit0_loss: 0.3419 - digit1_loss: 0.8870 - digit2_loss: 1.0439 - digit3_loss: 0.8145 - digit4_loss: 0.2785 - digit0_accuracy: 0.8777 - digit1_accuracy: 0.7185 - digit2_accuracy: 0.6849 - digit3_accuracy: 0.7393 - digit4_accuracy: 0.8951 - val_loss: 2.2660 - val_digit0_loss: 0.2651 - val_digit1_loss: 0.5862 - val_digit2_loss: 0.6826 - val_digit3_loss: 0.5198 - val_digit4_loss: 0.2124 - val_digit0_accuracy: 0.9087 - val_digit1_accuracy: 0.8289 - val_digit2_accuracy: 0.8102 - val_digit3_accuracy: 0.8481 - val_digit4_accuracy: 0.9237
# Epoch 479/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3644 - digit0_loss: 0.3399 - digit1_loss: 0.8884 - digit2_loss: 1.0415 - digit3_loss: 0.8183 - digit4_loss: 0.2763 - digit0_accuracy: 0.8785 - digit1_accuracy: 0.7186 - digit2_accuracy: 0.6866 - digit3_accuracy: 0.7404 - digit4_accuracy: 0.8963 - val_loss: 2.3379 - val_digit0_loss: 0.2766 - val_digit1_loss: 0.6041 - val_digit2_loss: 0.6957 - val_digit3_loss: 0.5402 - val_digit4_loss: 0.2213 - val_digit0_accuracy: 0.9074 - val_digit1_accuracy: 0.8212 - val_digit2_accuracy: 0.8058 - val_digit3_accuracy: 0.8423 - val_digit4_accuracy: 0.9207
# Epoch 480/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3689 - digit0_loss: 0.3414 - digit1_loss: 0.8882 - digit2_loss: 1.0434 - digit3_loss: 0.8172 - digit4_loss: 0.2786 - digit0_accuracy: 0.8766 - digit1_accuracy: 0.7183 - digit2_accuracy: 0.6856 - digit3_accuracy: 0.7375 - digit4_accuracy: 0.8950 - val_loss: 2.2717 - val_digit0_loss: 0.2638 - val_digit1_loss: 0.5889 - val_digit2_loss: 0.6846 - val_digit3_loss: 0.5242 - val_digit4_loss: 0.2102 - val_digit0_accuracy: 0.9103 - val_digit1_accuracy: 0.8280 - val_digit2_accuracy: 0.8121 - val_digit3_accuracy: 0.8482 - val_digit4_accuracy: 0.9248
# Epoch 481/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3563 - digit0_loss: 0.3408 - digit1_loss: 0.8878 - digit2_loss: 1.0355 - digit3_loss: 0.8177 - digit4_loss: 0.2746 - digit0_accuracy: 0.8774 - digit1_accuracy: 0.7170 - digit2_accuracy: 0.6871 - digit3_accuracy: 0.7399 - digit4_accuracy: 0.8968 - val_loss: 2.2638 - val_digit0_loss: 0.2647 - val_digit1_loss: 0.5848 - val_digit2_loss: 0.6810 - val_digit3_loss: 0.5210 - val_digit4_loss: 0.2122 - val_digit0_accuracy: 0.9100 - val_digit1_accuracy: 0.8262 - val_digit2_accuracy: 0.8102 - val_digit3_accuracy: 0.8471 - val_digit4_accuracy: 0.9253
# Epoch 482/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3652 - digit0_loss: 0.3416 - digit1_loss: 0.8894 - digit2_loss: 1.0402 - digit3_loss: 0.8180 - digit4_loss: 0.2760 - digit0_accuracy: 0.8783 - digit1_accuracy: 0.7174 - digit2_accuracy: 0.6857 - digit3_accuracy: 0.7389 - digit4_accuracy: 0.8960 - val_loss: 2.2687 - val_digit0_loss: 0.2664 - val_digit1_loss: 0.5885 - val_digit2_loss: 0.6820 - val_digit3_loss: 0.5213 - val_digit4_loss: 0.2104 - val_digit0_accuracy: 0.9079 - val_digit1_accuracy: 0.8252 - val_digit2_accuracy: 0.8103 - val_digit3_accuracy: 0.8481 - val_digit4_accuracy: 0.9244
# Epoch 483/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3359 - digit0_loss: 0.3399 - digit1_loss: 0.8844 - digit2_loss: 1.0356 - digit3_loss: 0.8021 - digit4_loss: 0.2739 - digit0_accuracy: 0.8783 - digit1_accuracy: 0.7177 - digit2_accuracy: 0.6856 - digit3_accuracy: 0.7443 - digit4_accuracy: 0.8964 - val_loss: 2.2837 - val_digit0_loss: 0.2696 - val_digit1_loss: 0.5891 - val_digit2_loss: 0.6838 - val_digit3_loss: 0.5247 - val_digit4_loss: 0.2164 - val_digit0_accuracy: 0.9087 - val_digit1_accuracy: 0.8261 - val_digit2_accuracy: 0.8118 - val_digit3_accuracy: 0.8481 - val_digit4_accuracy: 0.9223
# Epoch 484/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3509 - digit0_loss: 0.3401 - digit1_loss: 0.8828 - digit2_loss: 1.0354 - digit3_loss: 0.8167 - digit4_loss: 0.2759 - digit0_accuracy: 0.8794 - digit1_accuracy: 0.7172 - digit2_accuracy: 0.6868 - digit3_accuracy: 0.7385 - digit4_accuracy: 0.8960 - val_loss: 2.2938 - val_digit0_loss: 0.2703 - val_digit1_loss: 0.5940 - val_digit2_loss: 0.6852 - val_digit3_loss: 0.5310 - val_digit4_loss: 0.2133 - val_digit0_accuracy: 0.9086 - val_digit1_accuracy: 0.8264 - val_digit2_accuracy: 0.8093 - val_digit3_accuracy: 0.8473 - val_digit4_accuracy: 0.9232
# Epoch 485/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3387 - digit0_loss: 0.3361 - digit1_loss: 0.8804 - digit2_loss: 1.0376 - digit3_loss: 0.8110 - digit4_loss: 0.2736 - digit0_accuracy: 0.8790 - digit1_accuracy: 0.7193 - digit2_accuracy: 0.6865 - digit3_accuracy: 0.7434 - digit4_accuracy: 0.8950 - val_loss: 2.2909 - val_digit0_loss: 0.2702 - val_digit1_loss: 0.5951 - val_digit2_loss: 0.6849 - val_digit3_loss: 0.5258 - val_digit4_loss: 0.2150 - val_digit0_accuracy: 0.9086 - val_digit1_accuracy: 0.8248 - val_digit2_accuracy: 0.8109 - val_digit3_accuracy: 0.8470 - val_digit4_accuracy: 0.9236
# Epoch 486/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3366 - digit0_loss: 0.3377 - digit1_loss: 0.8774 - digit2_loss: 1.0334 - digit3_loss: 0.8132 - digit4_loss: 0.2749 - digit0_accuracy: 0.8783 - digit1_accuracy: 0.7210 - digit2_accuracy: 0.6868 - digit3_accuracy: 0.7401 - digit4_accuracy: 0.8973 - val_loss: 2.2858 - val_digit0_loss: 0.2659 - val_digit1_loss: 0.5921 - val_digit2_loss: 0.6861 - val_digit3_loss: 0.5278 - val_digit4_loss: 0.2138 - val_digit0_accuracy: 0.9094 - val_digit1_accuracy: 0.8257 - val_digit2_accuracy: 0.8103 - val_digit3_accuracy: 0.8466 - val_digit4_accuracy: 0.9228
# Epoch 487/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3516 - digit0_loss: 0.3385 - digit1_loss: 0.8863 - digit2_loss: 1.0371 - digit3_loss: 0.8153 - digit4_loss: 0.2744 - digit0_accuracy: 0.8778 - digit1_accuracy: 0.7190 - digit2_accuracy: 0.6863 - digit3_accuracy: 0.7393 - digit4_accuracy: 0.8981 - val_loss: 2.2770 - val_digit0_loss: 0.2670 - val_digit1_loss: 0.5898 - val_digit2_loss: 0.6829 - val_digit3_loss: 0.5235 - val_digit4_loss: 0.2138 - val_digit0_accuracy: 0.9091 - val_digit1_accuracy: 0.8272 - val_digit2_accuracy: 0.8111 - val_digit3_accuracy: 0.8495 - val_digit4_accuracy: 0.9226
# Epoch 488/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3447 - digit0_loss: 0.3400 - digit1_loss: 0.8803 - digit2_loss: 1.0358 - digit3_loss: 0.8107 - digit4_loss: 0.2779 - digit0_accuracy: 0.8799 - digit1_accuracy: 0.7194 - digit2_accuracy: 0.6868 - digit3_accuracy: 0.7397 - digit4_accuracy: 0.8971 - val_loss: 2.2632 - val_digit0_loss: 0.2661 - val_digit1_loss: 0.5840 - val_digit2_loss: 0.6798 - val_digit3_loss: 0.5207 - val_digit4_loss: 0.2126 - val_digit0_accuracy: 0.9095 - val_digit1_accuracy: 0.8278 - val_digit2_accuracy: 0.8123 - val_digit3_accuracy: 0.8480 - val_digit4_accuracy: 0.9242
# Epoch 489/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3439 - digit0_loss: 0.3395 - digit1_loss: 0.8837 - digit2_loss: 1.0356 - digit3_loss: 0.8113 - digit4_loss: 0.2738 - digit0_accuracy: 0.8790 - digit1_accuracy: 0.7184 - digit2_accuracy: 0.6876 - digit3_accuracy: 0.7400 - digit4_accuracy: 0.8972 - val_loss: 2.2742 - val_digit0_loss: 0.2675 - val_digit1_loss: 0.5905 - val_digit2_loss: 0.6816 - val_digit3_loss: 0.5237 - val_digit4_loss: 0.2109 - val_digit0_accuracy: 0.9088 - val_digit1_accuracy: 0.8279 - val_digit2_accuracy: 0.8124 - val_digit3_accuracy: 0.8490 - val_digit4_accuracy: 0.9236
# Epoch 490/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3465 - digit0_loss: 0.3348 - digit1_loss: 0.8840 - digit2_loss: 1.0389 - digit3_loss: 0.8114 - digit4_loss: 0.2773 - digit0_accuracy: 0.8790 - digit1_accuracy: 0.7196 - digit2_accuracy: 0.6843 - digit3_accuracy: 0.7397 - digit4_accuracy: 0.8962 - val_loss: 2.2668 - val_digit0_loss: 0.2655 - val_digit1_loss: 0.5872 - val_digit2_loss: 0.6809 - val_digit3_loss: 0.5205 - val_digit4_loss: 0.2127 - val_digit0_accuracy: 0.9095 - val_digit1_accuracy: 0.8266 - val_digit2_accuracy: 0.8148 - val_digit3_accuracy: 0.8480 - val_digit4_accuracy: 0.9247
# Epoch 491/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3504 - digit0_loss: 0.3394 - digit1_loss: 0.8866 - digit2_loss: 1.0347 - digit3_loss: 0.8156 - digit4_loss: 0.2739 - digit0_accuracy: 0.8783 - digit1_accuracy: 0.7174 - digit2_accuracy: 0.6866 - digit3_accuracy: 0.7393 - digit4_accuracy: 0.8978 - val_loss: 2.2653 - val_digit0_loss: 0.2679 - val_digit1_loss: 0.5879 - val_digit2_loss: 0.6794 - val_digit3_loss: 0.5198 - val_digit4_loss: 0.2102 - val_digit0_accuracy: 0.9090 - val_digit1_accuracy: 0.8282 - val_digit2_accuracy: 0.8116 - val_digit3_accuracy: 0.8476 - val_digit4_accuracy: 0.9253
# Epoch 492/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3359 - digit0_loss: 0.3389 - digit1_loss: 0.8799 - digit2_loss: 1.0337 - digit3_loss: 0.8101 - digit4_loss: 0.2733 - digit0_accuracy: 0.8798 - digit1_accuracy: 0.7207 - digit2_accuracy: 0.6862 - digit3_accuracy: 0.7410 - digit4_accuracy: 0.8975 - val_loss: 2.2505 - val_digit0_loss: 0.2641 - val_digit1_loss: 0.5831 - val_digit2_loss: 0.6771 - val_digit3_loss: 0.5171 - val_digit4_loss: 0.2091 - val_digit0_accuracy: 0.9090 - val_digit1_accuracy: 0.8291 - val_digit2_accuracy: 0.8119 - val_digit3_accuracy: 0.8482 - val_digit4_accuracy: 0.9253
# Epoch 493/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3240 - digit0_loss: 0.3361 - digit1_loss: 0.8809 - digit2_loss: 1.0294 - digit3_loss: 0.8059 - digit4_loss: 0.2718 - digit0_accuracy: 0.8790 - digit1_accuracy: 0.7200 - digit2_accuracy: 0.6899 - digit3_accuracy: 0.7416 - digit4_accuracy: 0.8971 - val_loss: 2.2542 - val_digit0_loss: 0.2633 - val_digit1_loss: 0.5831 - val_digit2_loss: 0.6789 - val_digit3_loss: 0.5195 - val_digit4_loss: 0.2094 - val_digit0_accuracy: 0.9105 - val_digit1_accuracy: 0.8280 - val_digit2_accuracy: 0.8121 - val_digit3_accuracy: 0.8489 - val_digit4_accuracy: 0.9247
# Epoch 494/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3331 - digit0_loss: 0.3334 - digit1_loss: 0.8788 - digit2_loss: 1.0381 - digit3_loss: 0.8095 - digit4_loss: 0.2733 - digit0_accuracy: 0.8796 - digit1_accuracy: 0.7191 - digit2_accuracy: 0.6855 - digit3_accuracy: 0.7401 - digit4_accuracy: 0.8987 - val_loss: 2.2542 - val_digit0_loss: 0.2627 - val_digit1_loss: 0.5847 - val_digit2_loss: 0.6801 - val_digit3_loss: 0.5180 - val_digit4_loss: 0.2088 - val_digit0_accuracy: 0.9115 - val_digit1_accuracy: 0.8272 - val_digit2_accuracy: 0.8128 - val_digit3_accuracy: 0.8485 - val_digit4_accuracy: 0.9253
# Epoch 495/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3260 - digit0_loss: 0.3347 - digit1_loss: 0.8780 - digit2_loss: 1.0291 - digit3_loss: 0.8100 - digit4_loss: 0.2742 - digit0_accuracy: 0.8790 - digit1_accuracy: 0.7216 - digit2_accuracy: 0.6885 - digit3_accuracy: 0.7408 - digit4_accuracy: 0.8964 - val_loss: 2.2606 - val_digit0_loss: 0.2664 - val_digit1_loss: 0.5845 - val_digit2_loss: 0.6786 - val_digit3_loss: 0.5207 - val_digit4_loss: 0.2104 - val_digit0_accuracy: 0.9099 - val_digit1_accuracy: 0.8259 - val_digit2_accuracy: 0.8127 - val_digit3_accuracy: 0.8478 - val_digit4_accuracy: 0.9230
# Epoch 496/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3316 - digit0_loss: 0.3391 - digit1_loss: 0.8800 - digit2_loss: 1.0353 - digit3_loss: 0.8049 - digit4_loss: 0.2722 - digit0_accuracy: 0.8783 - digit1_accuracy: 0.7200 - digit2_accuracy: 0.6860 - digit3_accuracy: 0.7428 - digit4_accuracy: 0.8980 - val_loss: 2.2788 - val_digit0_loss: 0.2673 - val_digit1_loss: 0.5892 - val_digit2_loss: 0.6856 - val_digit3_loss: 0.5227 - val_digit4_loss: 0.2140 - val_digit0_accuracy: 0.9106 - val_digit1_accuracy: 0.8250 - val_digit2_accuracy: 0.8102 - val_digit3_accuracy: 0.8470 - val_digit4_accuracy: 0.9235
# Epoch 497/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3303 - digit0_loss: 0.3364 - digit1_loss: 0.8776 - digit2_loss: 1.0342 - digit3_loss: 0.8080 - digit4_loss: 0.2741 - digit0_accuracy: 0.8778 - digit1_accuracy: 0.7220 - digit2_accuracy: 0.6851 - digit3_accuracy: 0.7424 - digit4_accuracy: 0.8961 - val_loss: 2.2601 - val_digit0_loss: 0.2650 - val_digit1_loss: 0.5849 - val_digit2_loss: 0.6796 - val_digit3_loss: 0.5200 - val_digit4_loss: 0.2106 - val_digit0_accuracy: 0.9097 - val_digit1_accuracy: 0.8293 - val_digit2_accuracy: 0.8120 - val_digit3_accuracy: 0.8495 - val_digit4_accuracy: 0.9239
# Epoch 498/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3349 - digit0_loss: 0.3347 - digit1_loss: 0.8841 - digit2_loss: 1.0318 - digit3_loss: 0.8087 - digit4_loss: 0.2755 - digit0_accuracy: 0.8808 - digit1_accuracy: 0.7183 - digit2_accuracy: 0.6867 - digit3_accuracy: 0.7424 - digit4_accuracy: 0.8962 - val_loss: 2.2654 - val_digit0_loss: 0.2649 - val_digit1_loss: 0.5870 - val_digit2_loss: 0.6828 - val_digit3_loss: 0.5205 - val_digit4_loss: 0.2101 - val_digit0_accuracy: 0.9114 - val_digit1_accuracy: 0.8276 - val_digit2_accuracy: 0.8112 - val_digit3_accuracy: 0.8487 - val_digit4_accuracy: 0.9250
# Epoch 499/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3221 - digit0_loss: 0.3350 - digit1_loss: 0.8755 - digit2_loss: 1.0295 - digit3_loss: 0.8079 - digit4_loss: 0.2740 - digit0_accuracy: 0.8806 - digit1_accuracy: 0.7195 - digit2_accuracy: 0.6867 - digit3_accuracy: 0.7417 - digit4_accuracy: 0.8954 - val_loss: 2.2511 - val_digit0_loss: 0.2641 - val_digit1_loss: 0.5828 - val_digit2_loss: 0.6749 - val_digit3_loss: 0.5174 - val_digit4_loss: 0.2120 - val_digit0_accuracy: 0.9103 - val_digit1_accuracy: 0.8297 - val_digit2_accuracy: 0.8152 - val_digit3_accuracy: 0.8494 - val_digit4_accuracy: 0.9230
# Epoch 500/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.3349 - digit0_loss: 0.3377 - digit1_loss: 0.8845 - digit2_loss: 1.0306 - digit3_loss: 0.8077 - digit4_loss: 0.2745 - digit0_accuracy: 0.8794 - digit1_accuracy: 0.7176 - digit2_accuracy: 0.6878 - digit3_accuracy: 0.7418 - digit4_accuracy: 0.8966 - val_loss: 2.2911 - val_digit0_loss: 0.2708 - val_digit1_loss: 0.5934 - val_digit2_loss: 0.6851 - val_digit3_loss: 0.5273 - val_digit4_loss: 0.2145 - val_digit0_accuracy: 0.9090 - val_digit1_accuracy: 0.8250 - val_digit2_accuracy: 0.8101 - val_digit3_accuracy: 0.8496 - val_digit4_accuracy: 0.9223
#
# Epoch 00500: saving model to ./output-captcha/weights-500-3.33.hdf5

# %%
plot_model_history(history_random)

# %% [markdown]
# ## 4.2 - Treino Dataset Permut

# %%
net_perm = create_net();
history_perm = net_perm.fit(X_train_perm, [y_train_perm[0], y_train_perm[1], y_train_perm[2], y_train_perm[3], y_train_perm[4]], epochs=n_epoch, validation_split=validation_split, batch_size=size_batch_train, callbacks=callbacks_list)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 30, 80, 1)    0
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 28, 78, 16)   160         input_2[0][0]
# __________________________________________________________________________________________________
# MaxPool_1 (MaxPooling2D)        (None, 14, 39, 16)   0           Conv_1[0][0]
# __________________________________________________________________________________________________
# Conv_2 (Conv2D)                 (None, 12, 37, 32)   4640        MaxPool_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_2 (MaxPooling2D)        (None, 6, 19, 32)    0           Conv_2[0][0]
# __________________________________________________________________________________________________
# Conv_3 (Conv2D)                 (None, 4, 17, 32)    9248        MaxPool_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 4, 17, 32)    128         Conv_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_3 (MaxPooling2D)        (None, 2, 9, 32)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 576)          0           MaxPool_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# digit0 (Dense)                  (None, 36)           2340        dropout_6[0][0]
# __________________________________________________________________________________________________
# digit1 (Dense)                  (None, 36)           2340        dropout_7[0][0]
# __________________________________________________________________________________________________
# digit2 (Dense)                  (None, 36)           2340        dropout_8[0][0]
# __________________________________________________________________________________________________
# digit3 (Dense)                  (None, 36)           2340        dropout_9[0][0]
# __________________________________________________________________________________________________
# digit4 (Dense)                  (None, 36)           2340        dropout_10[0][0]
# ==================================================================================================
# Total params: 210,516
# Trainable params: 210,452
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Train on 80023 samples, validate on 20006 samples
# Epoch 1/500
# 80023/80023 [==============================] - 5s 57us/step - loss: 17.9862 - digit0_loss: 3.5969 - digit1_loss: 3.5956 - digit2_loss: 3.5977 - digit3_loss: 3.5949 - digit4_loss: 3.5941 - digit0_accuracy: 0.0272 - digit1_accuracy: 0.0286 - digit2_accuracy: 0.0285 - digit3_accuracy: 0.0291 - digit4_accuracy: 0.0291 - val_loss: 17.9177 - val_digit0_loss: 3.5814 - val_digit1_loss: 3.5826 - val_digit2_loss: 3.5832 - val_digit3_loss: 3.5833 - val_digit4_loss: 3.5809 - val_digit0_accuracy: 0.0298 - val_digit1_accuracy: 0.0261 - val_digit2_accuracy: 0.0279 - val_digit3_accuracy: 0.0308 - val_digit4_accuracy: 0.0280
# Epoch 2/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.9079 - digit0_loss: 3.5807 - digit1_loss: 3.5832 - digit2_loss: 3.5829 - digit3_loss: 3.5831 - digit4_loss: 3.5772 - digit0_accuracy: 0.0301 - digit1_accuracy: 0.0310 - digit2_accuracy: 0.0298 - digit3_accuracy: 0.0328 - digit4_accuracy: 0.0339 - val_loss: 17.9176 - val_digit0_loss: 3.5787 - val_digit1_loss: 3.5855 - val_digit2_loss: 3.5844 - val_digit3_loss: 3.5828 - val_digit4_loss: 3.5794 - val_digit0_accuracy: 0.0247 - val_digit1_accuracy: 0.0294 - val_digit2_accuracy: 0.0237 - val_digit3_accuracy: 0.0309 - val_digit4_accuracy: 0.0268
# Epoch 3/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.8978 - digit0_loss: 3.5842 - digit1_loss: 3.5810 - digit2_loss: 3.5798 - digit3_loss: 3.5792 - digit4_loss: 3.5786 - digit0_accuracy: 0.0309 - digit1_accuracy: 0.0320 - digit2_accuracy: 0.0315 - digit3_accuracy: 0.0336 - digit4_accuracy: 0.0358 - val_loss: 17.9174 - val_digit0_loss: 3.5760 - val_digit1_loss: 3.5874 - val_digit2_loss: 3.5848 - val_digit3_loss: 3.5833 - val_digit4_loss: 3.5736 - val_digit0_accuracy: 0.0289 - val_digit1_accuracy: 0.0294 - val_digit2_accuracy: 0.0268 - val_digit3_accuracy: 0.0266 - val_digit4_accuracy: 0.0295
# Epoch 4/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.8804 - digit0_loss: 3.5790 - digit1_loss: 3.5760 - digit2_loss: 3.5754 - digit3_loss: 3.5794 - digit4_loss: 3.5735 - digit0_accuracy: 0.0341 - digit1_accuracy: 0.0334 - digit2_accuracy: 0.0348 - digit3_accuracy: 0.0351 - digit4_accuracy: 0.0387 - val_loss: 17.9172 - val_digit0_loss: 3.5795 - val_digit1_loss: 3.5883 - val_digit2_loss: 3.5857 - val_digit3_loss: 3.5836 - val_digit4_loss: 3.5748 - val_digit0_accuracy: 0.0289 - val_digit1_accuracy: 0.0308 - val_digit2_accuracy: 0.0289 - val_digit3_accuracy: 0.0266 - val_digit4_accuracy: 0.0387
# Epoch 5/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.8554 - digit0_loss: 3.5736 - digit1_loss: 3.5778 - digit2_loss: 3.5718 - digit3_loss: 3.5731 - digit4_loss: 3.5642 - digit0_accuracy: 0.0362 - digit1_accuracy: 0.0364 - digit2_accuracy: 0.0375 - digit3_accuracy: 0.0387 - digit4_accuracy: 0.0409 - val_loss: 17.9165 - val_digit0_loss: 3.5823 - val_digit1_loss: 3.5914 - val_digit2_loss: 3.5852 - val_digit3_loss: 3.5824 - val_digit4_loss: 3.5680 - val_digit0_accuracy: 0.0302 - val_digit1_accuracy: 0.0378 - val_digit2_accuracy: 0.0286 - val_digit3_accuracy: 0.0321 - val_digit4_accuracy: 0.0429
# Epoch 6/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.8110 - digit0_loss: 3.5679 - digit1_loss: 3.5711 - digit2_loss: 3.5673 - digit3_loss: 3.5603 - digit4_loss: 3.5478 - digit0_accuracy: 0.0379 - digit1_accuracy: 0.0393 - digit2_accuracy: 0.0399 - digit3_accuracy: 0.0438 - digit4_accuracy: 0.0483 - val_loss: 17.9205 - val_digit0_loss: 3.5888 - val_digit1_loss: 3.5970 - val_digit2_loss: 3.5891 - val_digit3_loss: 3.5804 - val_digit4_loss: 3.5647 - val_digit0_accuracy: 0.0281 - val_digit1_accuracy: 0.0312 - val_digit2_accuracy: 0.0281 - val_digit3_accuracy: 0.0267 - val_digit4_accuracy: 0.0323
# Epoch 7/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.7395 - digit0_loss: 3.5544 - digit1_loss: 3.5530 - digit2_loss: 3.5541 - digit3_loss: 3.5347 - digit4_loss: 3.5185 - digit0_accuracy: 0.0417 - digit1_accuracy: 0.0415 - digit2_accuracy: 0.0429 - digit3_accuracy: 0.0442 - digit4_accuracy: 0.0520 - val_loss: 17.9217 - val_digit0_loss: 3.5823 - val_digit1_loss: 3.5939 - val_digit2_loss: 3.5926 - val_digit3_loss: 3.5822 - val_digit4_loss: 3.5641 - val_digit0_accuracy: 0.0283 - val_digit1_accuracy: 0.0285 - val_digit2_accuracy: 0.0334 - val_digit3_accuracy: 0.0266 - val_digit4_accuracy: 0.0323
# Epoch 8/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.6437 - digit0_loss: 3.5343 - digit1_loss: 3.5409 - digit2_loss: 3.5361 - digit3_loss: 3.5331 - digit4_loss: 3.4816 - digit0_accuracy: 0.0466 - digit1_accuracy: 0.0472 - digit2_accuracy: 0.0472 - digit3_accuracy: 0.0468 - digit4_accuracy: 0.0613 - val_loss: 17.9223 - val_digit0_loss: 3.5841 - val_digit1_loss: 3.5909 - val_digit2_loss: 3.5903 - val_digit3_loss: 3.5865 - val_digit4_loss: 3.5706 - val_digit0_accuracy: 0.0283 - val_digit1_accuracy: 0.0279 - val_digit2_accuracy: 0.0265 - val_digit3_accuracy: 0.0273 - val_digit4_accuracy: 0.0304
# Epoch 9/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.5039 - digit0_loss: 3.5122 - digit1_loss: 3.5080 - digit2_loss: 3.5115 - digit3_loss: 3.5102 - digit4_loss: 3.4433 - digit0_accuracy: 0.0513 - digit1_accuracy: 0.0514 - digit2_accuracy: 0.0543 - digit3_accuracy: 0.0550 - digit4_accuracy: 0.0699 - val_loss: 17.9341 - val_digit0_loss: 3.5911 - val_digit1_loss: 3.5970 - val_digit2_loss: 3.5943 - val_digit3_loss: 3.5817 - val_digit4_loss: 3.5676 - val_digit0_accuracy: 0.0281 - val_digit1_accuracy: 0.0304 - val_digit2_accuracy: 0.0265 - val_digit3_accuracy: 0.0365 - val_digit4_accuracy: 0.0303
# Epoch 10/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.3405 - digit0_loss: 3.4739 - digit1_loss: 3.4771 - digit2_loss: 3.4811 - digit3_loss: 3.4761 - digit4_loss: 3.4046 - digit0_accuracy: 0.0585 - digit1_accuracy: 0.0605 - digit2_accuracy: 0.0604 - digit3_accuracy: 0.0641 - digit4_accuracy: 0.0795 - val_loss: 17.9142 - val_digit0_loss: 3.5793 - val_digit1_loss: 3.6011 - val_digit2_loss: 3.5926 - val_digit3_loss: 3.5855 - val_digit4_loss: 3.5613 - val_digit0_accuracy: 0.0276 - val_digit1_accuracy: 0.0336 - val_digit2_accuracy: 0.0426 - val_digit3_accuracy: 0.0315 - val_digit4_accuracy: 0.0400
# Epoch 11/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.1368 - digit0_loss: 3.4473 - digit1_loss: 3.4732 - digit2_loss: 3.4400 - digit3_loss: 3.4290 - digit4_loss: 3.3241 - digit0_accuracy: 0.0663 - digit1_accuracy: 0.0650 - digit2_accuracy: 0.0654 - digit3_accuracy: 0.0699 - digit4_accuracy: 0.0897 - val_loss: 17.8916 - val_digit0_loss: 3.5776 - val_digit1_loss: 3.6025 - val_digit2_loss: 3.5922 - val_digit3_loss: 3.5749 - val_digit4_loss: 3.5999 - val_digit0_accuracy: 0.0278 - val_digit1_accuracy: 0.0440 - val_digit2_accuracy: 0.0265 - val_digit3_accuracy: 0.0476 - val_digit4_accuracy: 0.0387
# Epoch 12/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 16.9139 - digit0_loss: 3.4139 - digit1_loss: 3.4330 - digit2_loss: 3.4070 - digit3_loss: 3.3757 - digit4_loss: 3.2478 - digit0_accuracy: 0.0722 - digit1_accuracy: 0.0709 - digit2_accuracy: 0.0723 - digit3_accuracy: 0.0762 - digit4_accuracy: 0.0964 - val_loss: 17.8741 - val_digit0_loss: 3.5786 - val_digit1_loss: 3.6091 - val_digit2_loss: 3.5997 - val_digit3_loss: 3.5619 - val_digit4_loss: 3.5989 - val_digit0_accuracy: 0.0280 - val_digit1_accuracy: 0.0413 - val_digit2_accuracy: 0.0295 - val_digit3_accuracy: 0.0465 - val_digit4_accuracy: 0.0331
# Epoch 13/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 16.6787 - digit0_loss: 3.3428 - digit1_loss: 3.3863 - digit2_loss: 3.3699 - digit3_loss: 3.3463 - digit4_loss: 3.1815 - digit0_accuracy: 0.0780 - digit1_accuracy: 0.0740 - digit2_accuracy: 0.0778 - digit3_accuracy: 0.0839 - digit4_accuracy: 0.1076 - val_loss: 17.7976 - val_digit0_loss: 3.5482 - val_digit1_loss: 3.6057 - val_digit2_loss: 3.5634 - val_digit3_loss: 3.5740 - val_digit4_loss: 3.5577 - val_digit0_accuracy: 0.0484 - val_digit1_accuracy: 0.0476 - val_digit2_accuracy: 0.0283 - val_digit3_accuracy: 0.0338 - val_digit4_accuracy: 0.0329
# Epoch 14/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 16.4310 - digit0_loss: 3.3126 - digit1_loss: 3.3509 - digit2_loss: 3.3426 - digit3_loss: 3.3021 - digit4_loss: 3.1470 - digit0_accuracy: 0.0842 - digit1_accuracy: 0.0817 - digit2_accuracy: 0.0834 - digit3_accuracy: 0.0879 - digit4_accuracy: 0.1157 - val_loss: 17.8193 - val_digit0_loss: 3.5489 - val_digit1_loss: 3.5981 - val_digit2_loss: 3.6016 - val_digit3_loss: 3.5469 - val_digit4_loss: 3.6552 - val_digit0_accuracy: 0.0383 - val_digit1_accuracy: 0.0289 - val_digit2_accuracy: 0.0407 - val_digit3_accuracy: 0.0356 - val_digit4_accuracy: 0.0436
# Epoch 15/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 16.1641 - digit0_loss: 3.2500 - digit1_loss: 3.3261 - digit2_loss: 3.3051 - digit3_loss: 3.2607 - digit4_loss: 3.0574 - digit0_accuracy: 0.0914 - digit1_accuracy: 0.0889 - digit2_accuracy: 0.0927 - digit3_accuracy: 0.0956 - digit4_accuracy: 0.1295 - val_loss: 17.6856 - val_digit0_loss: 3.5355 - val_digit1_loss: 3.5715 - val_digit2_loss: 3.5738 - val_digit3_loss: 3.5251 - val_digit4_loss: 3.6226 - val_digit0_accuracy: 0.0567 - val_digit1_accuracy: 0.0290 - val_digit2_accuracy: 0.0424 - val_digit3_accuracy: 0.0345 - val_digit4_accuracy: 0.0384
# Epoch 16/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 15.8980 - digit0_loss: 3.1979 - digit1_loss: 3.2462 - digit2_loss: 3.2549 - digit3_loss: 3.2000 - digit4_loss: 2.9742 - digit0_accuracy: 0.1020 - digit1_accuracy: 0.0934 - digit2_accuracy: 0.0982 - digit3_accuracy: 0.1025 - digit4_accuracy: 0.1399 - val_loss: 17.7876 - val_digit0_loss: 3.5524 - val_digit1_loss: 3.6059 - val_digit2_loss: 3.6054 - val_digit3_loss: 3.5194 - val_digit4_loss: 3.6957 - val_digit0_accuracy: 0.0356 - val_digit1_accuracy: 0.0289 - val_digit2_accuracy: 0.0295 - val_digit3_accuracy: 0.0316 - val_digit4_accuracy: 0.0358
# Epoch 17/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 15.6305 - digit0_loss: 3.1074 - digit1_loss: 3.2062 - digit2_loss: 3.2238 - digit3_loss: 3.1321 - digit4_loss: 2.9116 - digit0_accuracy: 0.1111 - digit1_accuracy: 0.0980 - digit2_accuracy: 0.1055 - digit3_accuracy: 0.1128 - digit4_accuracy: 0.1522 - val_loss: 17.7078 - val_digit0_loss: 3.5542 - val_digit1_loss: 3.6085 - val_digit2_loss: 3.6097 - val_digit3_loss: 3.5015 - val_digit4_loss: 3.6154 - val_digit0_accuracy: 0.0299 - val_digit1_accuracy: 0.0288 - val_digit2_accuracy: 0.0303 - val_digit3_accuracy: 0.0295 - val_digit4_accuracy: 0.0393
# Epoch 18/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 15.4158 - digit0_loss: 3.0742 - digit1_loss: 3.1709 - digit2_loss: 3.1866 - digit3_loss: 3.1198 - digit4_loss: 2.8211 - digit0_accuracy: 0.1195 - digit1_accuracy: 0.1046 - digit2_accuracy: 0.1079 - digit3_accuracy: 0.1181 - digit4_accuracy: 0.1615 - val_loss: 17.2378 - val_digit0_loss: 3.4627 - val_digit1_loss: 3.5084 - val_digit2_loss: 3.5112 - val_digit3_loss: 3.4645 - val_digit4_loss: 3.4267 - val_digit0_accuracy: 0.0718 - val_digit1_accuracy: 0.0756 - val_digit2_accuracy: 0.0614 - val_digit3_accuracy: 0.0699 - val_digit4_accuracy: 0.0546
# Epoch 19/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 15.1739 - digit0_loss: 3.0194 - digit1_loss: 3.1435 - digit2_loss: 3.1564 - digit3_loss: 3.0749 - digit4_loss: 2.7644 - digit0_accuracy: 0.1283 - digit1_accuracy: 0.1113 - digit2_accuracy: 0.1148 - digit3_accuracy: 0.1211 - digit4_accuracy: 0.1715 - val_loss: 17.1857 - val_digit0_loss: 3.4511 - val_digit1_loss: 3.5247 - val_digit2_loss: 3.4898 - val_digit3_loss: 3.4478 - val_digit4_loss: 3.4192 - val_digit0_accuracy: 0.0716 - val_digit1_accuracy: 0.0851 - val_digit2_accuracy: 0.0784 - val_digit3_accuracy: 0.0770 - val_digit4_accuracy: 0.0990
# Epoch 20/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.9438 - digit0_loss: 2.9511 - digit1_loss: 3.1371 - digit2_loss: 3.0858 - digit3_loss: 3.0384 - digit4_loss: 2.7456 - digit0_accuracy: 0.1363 - digit1_accuracy: 0.1179 - digit2_accuracy: 0.1207 - digit3_accuracy: 0.1315 - digit4_accuracy: 0.1835 - val_loss: 17.0482 - val_digit0_loss: 3.4112 - val_digit1_loss: 3.4945 - val_digit2_loss: 3.4674 - val_digit3_loss: 3.4326 - val_digit4_loss: 3.4205 - val_digit0_accuracy: 0.0788 - val_digit1_accuracy: 0.0817 - val_digit2_accuracy: 0.0546 - val_digit3_accuracy: 0.0724 - val_digit4_accuracy: 0.0582
# Epoch 21/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 14.7438 - digit0_loss: 2.9118 - digit1_loss: 3.0445 - digit2_loss: 3.1005 - digit3_loss: 3.0225 - digit4_loss: 2.6762 - digit0_accuracy: 0.1415 - digit1_accuracy: 0.1207 - digit2_accuracy: 0.1224 - digit3_accuracy: 0.1301 - digit4_accuracy: 0.1882 - val_loss: 16.7233 - val_digit0_loss: 3.3935 - val_digit1_loss: 3.4345 - val_digit2_loss: 3.3794 - val_digit3_loss: 3.4076 - val_digit4_loss: 3.2673 - val_digit0_accuracy: 0.1266 - val_digit1_accuracy: 0.0634 - val_digit2_accuracy: 0.1052 - val_digit3_accuracy: 0.1039 - val_digit4_accuracy: 0.1321
# Epoch 22/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.5425 - digit0_loss: 2.8335 - digit1_loss: 3.0448 - digit2_loss: 3.0684 - digit3_loss: 2.9583 - digit4_loss: 2.6025 - digit0_accuracy: 0.1510 - digit1_accuracy: 0.1242 - digit2_accuracy: 0.1300 - digit3_accuracy: 0.1383 - digit4_accuracy: 0.2006 - val_loss: 16.9490 - val_digit0_loss: 3.3355 - val_digit1_loss: 3.3749 - val_digit2_loss: 3.4254 - val_digit3_loss: 3.4523 - val_digit4_loss: 3.3155 - val_digit0_accuracy: 0.0639 - val_digit1_accuracy: 0.0581 - val_digit2_accuracy: 0.0397 - val_digit3_accuracy: 0.0648 - val_digit4_accuracy: 0.0534
# Epoch 23/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.3673 - digit0_loss: 2.8107 - digit1_loss: 3.0232 - digit2_loss: 3.0821 - digit3_loss: 2.9576 - digit4_loss: 2.5786 - digit0_accuracy: 0.1569 - digit1_accuracy: 0.1317 - digit2_accuracy: 0.1327 - digit3_accuracy: 0.1438 - digit4_accuracy: 0.2106 - val_loss: 16.8821 - val_digit0_loss: 3.3791 - val_digit1_loss: 3.4465 - val_digit2_loss: 3.4315 - val_digit3_loss: 3.3987 - val_digit4_loss: 3.3273 - val_digit0_accuracy: 0.1093 - val_digit1_accuracy: 0.1191 - val_digit2_accuracy: 0.0749 - val_digit3_accuracy: 0.0882 - val_digit4_accuracy: 0.1343
# Epoch 24/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 14.2172 - digit0_loss: 2.7585 - digit1_loss: 2.9961 - digit2_loss: 2.9871 - digit3_loss: 2.9206 - digit4_loss: 2.5450 - digit0_accuracy: 0.1601 - digit1_accuracy: 0.1388 - digit2_accuracy: 0.1350 - digit3_accuracy: 0.1490 - digit4_accuracy: 0.2195 - val_loss: 17.5921 - val_digit0_loss: 3.4868 - val_digit1_loss: 3.5934 - val_digit2_loss: 3.5860 - val_digit3_loss: 3.4452 - val_digit4_loss: 3.6386 - val_digit0_accuracy: 0.0580 - val_digit1_accuracy: 0.0653 - val_digit2_accuracy: 0.0714 - val_digit3_accuracy: 0.0507 - val_digit4_accuracy: 0.0471
# Epoch 25/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.3215 - digit0_loss: 2.8073 - digit1_loss: 3.0119 - digit2_loss: 3.0182 - digit3_loss: 2.9343 - digit4_loss: 2.5757 - digit0_accuracy: 0.1591 - digit1_accuracy: 0.1359 - digit2_accuracy: 0.1342 - digit3_accuracy: 0.1454 - digit4_accuracy: 0.2085 - val_loss: 17.6163 - val_digit0_loss: 3.5300 - val_digit1_loss: 3.6594 - val_digit2_loss: 3.5520 - val_digit3_loss: 3.4237 - val_digit4_loss: 3.6389 - val_digit0_accuracy: 0.0617 - val_digit1_accuracy: 0.0449 - val_digit2_accuracy: 0.0590 - val_digit3_accuracy: 0.0547 - val_digit4_accuracy: 0.0747
# Epoch 26/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.0873 - digit0_loss: 2.6953 - digit1_loss: 2.9625 - digit2_loss: 2.9758 - digit3_loss: 2.8757 - digit4_loss: 2.5121 - digit0_accuracy: 0.1705 - digit1_accuracy: 0.1405 - digit2_accuracy: 0.1423 - digit3_accuracy: 0.1538 - digit4_accuracy: 0.2193 - val_loss: 16.7209 - val_digit0_loss: 3.2930 - val_digit1_loss: 3.3555 - val_digit2_loss: 3.3646 - val_digit3_loss: 3.3332 - val_digit4_loss: 3.5079 - val_digit0_accuracy: 0.0638 - val_digit1_accuracy: 0.0501 - val_digit2_accuracy: 0.0710 - val_digit3_accuracy: 0.1238 - val_digit4_accuracy: 0.0563
# Epoch 27/500
# 80023/80023 [==============================] - 4s 46us/step - loss: 13.8921 - digit0_loss: 2.6456 - digit1_loss: 2.9206 - digit2_loss: 2.9620 - digit3_loss: 2.8637 - digit4_loss: 2.4318 - digit0_accuracy: 0.1772 - digit1_accuracy: 0.1464 - digit2_accuracy: 0.1481 - digit3_accuracy: 0.1623 - digit4_accuracy: 0.2382 - val_loss: 16.3683 - val_digit0_loss: 3.2224 - val_digit1_loss: 3.2547 - val_digit2_loss: 3.3479 - val_digit3_loss: 3.4377 - val_digit4_loss: 3.1746 - val_digit0_accuracy: 0.1014 - val_digit1_accuracy: 0.0762 - val_digit2_accuracy: 0.0904 - val_digit3_accuracy: 0.0741 - val_digit4_accuracy: 0.0917
# Epoch 28/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.7136 - digit0_loss: 2.6115 - digit1_loss: 2.9346 - digit2_loss: 2.9132 - digit3_loss: 2.8301 - digit4_loss: 2.4048 - digit0_accuracy: 0.1887 - digit1_accuracy: 0.1544 - digit2_accuracy: 0.1533 - digit3_accuracy: 0.1668 - digit4_accuracy: 0.2469 - val_loss: 16.4160 - val_digit0_loss: 3.2661 - val_digit1_loss: 3.3280 - val_digit2_loss: 3.4135 - val_digit3_loss: 3.3544 - val_digit4_loss: 3.1818 - val_digit0_accuracy: 0.1430 - val_digit1_accuracy: 0.1202 - val_digit2_accuracy: 0.1182 - val_digit3_accuracy: 0.0916 - val_digit4_accuracy: 0.2218
# Epoch 29/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.5518 - digit0_loss: 2.5824 - digit1_loss: 2.9252 - digit2_loss: 2.9154 - digit3_loss: 2.8515 - digit4_loss: 2.3953 - digit0_accuracy: 0.1951 - digit1_accuracy: 0.1598 - digit2_accuracy: 0.1586 - digit3_accuracy: 0.1715 - digit4_accuracy: 0.2571 - val_loss: 16.3351 - val_digit0_loss: 3.2568 - val_digit1_loss: 3.3233 - val_digit2_loss: 3.3976 - val_digit3_loss: 3.3195 - val_digit4_loss: 3.1994 - val_digit0_accuracy: 0.1759 - val_digit1_accuracy: 0.1512 - val_digit2_accuracy: 0.1429 - val_digit3_accuracy: 0.1152 - val_digit4_accuracy: 0.2660
# Epoch 30/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.4152 - digit0_loss: 2.5136 - digit1_loss: 2.8893 - digit2_loss: 2.8747 - digit3_loss: 2.7755 - digit4_loss: 2.3505 - digit0_accuracy: 0.2017 - digit1_accuracy: 0.1637 - digit2_accuracy: 0.1630 - digit3_accuracy: 0.1807 - digit4_accuracy: 0.2638 - val_loss: 16.6519 - val_digit0_loss: 3.1775 - val_digit1_loss: 3.2455 - val_digit2_loss: 3.3808 - val_digit3_loss: 3.4404 - val_digit4_loss: 3.2397 - val_digit0_accuracy: 0.0765 - val_digit1_accuracy: 0.0822 - val_digit2_accuracy: 0.0705 - val_digit3_accuracy: 0.0908 - val_digit4_accuracy: 0.0961
# Epoch 31/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 13.2948 - digit0_loss: 2.5153 - digit1_loss: 2.8494 - digit2_loss: 2.8934 - digit3_loss: 2.7858 - digit4_loss: 2.2707 - digit0_accuracy: 0.2094 - digit1_accuracy: 0.1618 - digit2_accuracy: 0.1662 - digit3_accuracy: 0.1838 - digit4_accuracy: 0.2743 - val_loss: 15.9852 - val_digit0_loss: 3.1433 - val_digit1_loss: 3.2375 - val_digit2_loss: 3.3108 - val_digit3_loss: 3.2390 - val_digit4_loss: 3.0786 - val_digit0_accuracy: 0.1712 - val_digit1_accuracy: 0.1338 - val_digit2_accuracy: 0.1361 - val_digit3_accuracy: 0.1513 - val_digit4_accuracy: 0.2362
# Epoch 32/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.1732 - digit0_loss: 2.5073 - digit1_loss: 2.8291 - digit2_loss: 2.8837 - digit3_loss: 2.7595 - digit4_loss: 2.2856 - digit0_accuracy: 0.2193 - digit1_accuracy: 0.1682 - digit2_accuracy: 0.1759 - digit3_accuracy: 0.1880 - digit4_accuracy: 0.2828 - val_loss: 16.0817 - val_digit0_loss: 3.1101 - val_digit1_loss: 3.1973 - val_digit2_loss: 3.2747 - val_digit3_loss: 3.3187 - val_digit4_loss: 3.1278 - val_digit0_accuracy: 0.0830 - val_digit1_accuracy: 0.0588 - val_digit2_accuracy: 0.0881 - val_digit3_accuracy: 0.0689 - val_digit4_accuracy: 0.0825
# Epoch 33/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.0497 - digit0_loss: 2.4711 - digit1_loss: 2.8176 - digit2_loss: 2.8330 - digit3_loss: 2.7275 - digit4_loss: 2.1952 - digit0_accuracy: 0.2252 - digit1_accuracy: 0.1696 - digit2_accuracy: 0.1775 - digit3_accuracy: 0.1928 - digit4_accuracy: 0.2919 - val_loss: 15.7137 - val_digit0_loss: 3.1001 - val_digit1_loss: 3.1829 - val_digit2_loss: 3.2712 - val_digit3_loss: 3.1618 - val_digit4_loss: 3.0517 - val_digit0_accuracy: 0.1593 - val_digit1_accuracy: 0.1445 - val_digit2_accuracy: 0.1673 - val_digit3_accuracy: 0.1589 - val_digit4_accuracy: 0.2581
# Epoch 34/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.9354 - digit0_loss: 2.4287 - digit1_loss: 2.7809 - digit2_loss: 2.8302 - digit3_loss: 2.7213 - digit4_loss: 2.2079 - digit0_accuracy: 0.2333 - digit1_accuracy: 0.1752 - digit2_accuracy: 0.1804 - digit3_accuracy: 0.2009 - digit4_accuracy: 0.2974 - val_loss: 15.8925 - val_digit0_loss: 3.0496 - val_digit1_loss: 3.1513 - val_digit2_loss: 3.2350 - val_digit3_loss: 3.2922 - val_digit4_loss: 3.1230 - val_digit0_accuracy: 0.0933 - val_digit1_accuracy: 0.0764 - val_digit2_accuracy: 0.0890 - val_digit3_accuracy: 0.0710 - val_digit4_accuracy: 0.0830
# Epoch 35/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.8214 - digit0_loss: 2.4016 - digit1_loss: 2.7825 - digit2_loss: 2.8761 - digit3_loss: 2.6838 - digit4_loss: 2.1609 - digit0_accuracy: 0.2373 - digit1_accuracy: 0.1822 - digit2_accuracy: 0.1848 - digit3_accuracy: 0.2065 - digit4_accuracy: 0.3107 - val_loss: 16.6589 - val_digit0_loss: 3.0724 - val_digit1_loss: 3.2409 - val_digit2_loss: 3.4129 - val_digit3_loss: 3.4889 - val_digit4_loss: 3.3183 - val_digit0_accuracy: 0.0860 - val_digit1_accuracy: 0.0713 - val_digit2_accuracy: 0.0577 - val_digit3_accuracy: 0.0764 - val_digit4_accuracy: 0.0869
# Epoch 36/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.6983 - digit0_loss: 2.3646 - digit1_loss: 2.7694 - digit2_loss: 2.8067 - digit3_loss: 2.6357 - digit4_loss: 2.1167 - digit0_accuracy: 0.2495 - digit1_accuracy: 0.1906 - digit2_accuracy: 0.1885 - digit3_accuracy: 0.2124 - digit4_accuracy: 0.3191 - val_loss: 15.8194 - val_digit0_loss: 2.9756 - val_digit1_loss: 3.1511 - val_digit2_loss: 3.2843 - val_digit3_loss: 3.2637 - val_digit4_loss: 3.1151 - val_digit0_accuracy: 0.1097 - val_digit1_accuracy: 0.0739 - val_digit2_accuracy: 0.0801 - val_digit3_accuracy: 0.0840 - val_digit4_accuracy: 0.1028
# Epoch 37/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.5731 - digit0_loss: 2.3353 - digit1_loss: 2.7488 - digit2_loss: 2.7598 - digit3_loss: 2.6200 - digit4_loss: 2.0353 - digit0_accuracy: 0.2537 - digit1_accuracy: 0.1946 - digit2_accuracy: 0.1920 - digit3_accuracy: 0.2198 - digit4_accuracy: 0.3300 - val_loss: 15.6465 - val_digit0_loss: 2.9865 - val_digit1_loss: 3.1218 - val_digit2_loss: 3.3012 - val_digit3_loss: 3.2178 - val_digit4_loss: 3.0495 - val_digit0_accuracy: 0.1109 - val_digit1_accuracy: 0.0749 - val_digit2_accuracy: 0.0674 - val_digit3_accuracy: 0.1020 - val_digit4_accuracy: 0.1138
# Epoch 38/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.4651 - digit0_loss: 2.2948 - digit1_loss: 2.7299 - digit2_loss: 2.7782 - digit3_loss: 2.6222 - digit4_loss: 2.0847 - digit0_accuracy: 0.2615 - digit1_accuracy: 0.1994 - digit2_accuracy: 0.1959 - digit3_accuracy: 0.2257 - digit4_accuracy: 0.3304 - val_loss: 15.4602 - val_digit0_loss: 2.8459 - val_digit1_loss: 3.0751 - val_digit2_loss: 3.3372 - val_digit3_loss: 3.2325 - val_digit4_loss: 3.0518 - val_digit0_accuracy: 0.1248 - val_digit1_accuracy: 0.0993 - val_digit2_accuracy: 0.0864 - val_digit3_accuracy: 0.1001 - val_digit4_accuracy: 0.1338
# Epoch 39/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.3730 - digit0_loss: 2.2594 - digit1_loss: 2.6841 - digit2_loss: 2.7364 - digit3_loss: 2.5937 - digit4_loss: 2.0396 - digit0_accuracy: 0.2707 - digit1_accuracy: 0.2012 - digit2_accuracy: 0.2013 - digit3_accuracy: 0.2292 - digit4_accuracy: 0.3407 - val_loss: 16.0749 - val_digit0_loss: 3.0145 - val_digit1_loss: 3.1254 - val_digit2_loss: 3.4077 - val_digit3_loss: 3.4878 - val_digit4_loss: 3.1823 - val_digit0_accuracy: 0.1093 - val_digit1_accuracy: 0.0954 - val_digit2_accuracy: 0.0871 - val_digit3_accuracy: 0.0866 - val_digit4_accuracy: 0.1307
# Epoch 40/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 12.2583 - digit0_loss: 2.2166 - digit1_loss: 2.6740 - digit2_loss: 2.7082 - digit3_loss: 2.5578 - digit4_loss: 2.0036 - digit0_accuracy: 0.2733 - digit1_accuracy: 0.2057 - digit2_accuracy: 0.2055 - digit3_accuracy: 0.2348 - digit4_accuracy: 0.3527 - val_loss: 21.8013 - val_digit0_loss: 4.1269 - val_digit1_loss: 3.8989 - val_digit2_loss: 4.2312 - val_digit3_loss: 4.8601 - val_digit4_loss: 4.3986 - val_digit0_accuracy: 0.0583 - val_digit1_accuracy: 0.0635 - val_digit2_accuracy: 0.0586 - val_digit3_accuracy: 0.0596 - val_digit4_accuracy: 0.0743
# Epoch 41/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 12.1400 - digit0_loss: 2.1812 - digit1_loss: 2.6884 - digit2_loss: 2.7310 - digit3_loss: 2.5721 - digit4_loss: 1.9602 - digit0_accuracy: 0.2776 - digit1_accuracy: 0.2144 - digit2_accuracy: 0.2126 - digit3_accuracy: 0.2425 - digit4_accuracy: 0.3633 - val_loss: 19.8424 - val_digit0_loss: 3.4092 - val_digit1_loss: 3.7396 - val_digit2_loss: 3.8976 - val_digit3_loss: 4.4036 - val_digit4_loss: 4.3003 - val_digit0_accuracy: 0.0679 - val_digit1_accuracy: 0.0516 - val_digit2_accuracy: 0.0441 - val_digit3_accuracy: 0.0556 - val_digit4_accuracy: 0.0541
# Epoch 42/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 12.0161 - digit0_loss: 2.2219 - digit1_loss: 2.6349 - digit2_loss: 2.6771 - digit3_loss: 2.5812 - digit4_loss: 1.9746 - digit0_accuracy: 0.2900 - digit1_accuracy: 0.2174 - digit2_accuracy: 0.2182 - digit3_accuracy: 0.2447 - digit4_accuracy: 0.3647 - val_loss: 14.5281 - val_digit0_loss: 2.8170 - val_digit1_loss: 3.0251 - val_digit2_loss: 3.1484 - val_digit3_loss: 2.8741 - val_digit4_loss: 2.9450 - val_digit0_accuracy: 0.2540 - val_digit1_accuracy: 0.1617 - val_digit2_accuracy: 0.1231 - val_digit3_accuracy: 0.2051 - val_digit4_accuracy: 0.2332
# Epoch 43/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 11.9621 - digit0_loss: 2.1618 - digit1_loss: 2.6376 - digit2_loss: 2.6711 - digit3_loss: 2.5303 - digit4_loss: 1.9185 - digit0_accuracy: 0.2996 - digit1_accuracy: 0.2186 - digit2_accuracy: 0.2172 - digit3_accuracy: 0.2507 - digit4_accuracy: 0.3705 - val_loss: 14.5777 - val_digit0_loss: 2.7009 - val_digit1_loss: 2.9521 - val_digit2_loss: 3.0649 - val_digit3_loss: 3.1074 - val_digit4_loss: 2.8685 - val_digit0_accuracy: 0.1929 - val_digit1_accuracy: 0.1285 - val_digit2_accuracy: 0.1503 - val_digit3_accuracy: 0.1226 - val_digit4_accuracy: 0.1852
# Epoch 44/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 11.8326 - digit0_loss: 2.1555 - digit1_loss: 2.6005 - digit2_loss: 2.7345 - digit3_loss: 2.5201 - digit4_loss: 1.9140 - digit0_accuracy: 0.3085 - digit1_accuracy: 0.2262 - digit2_accuracy: 0.2261 - digit3_accuracy: 0.2586 - digit4_accuracy: 0.3868 - val_loss: 17.2630 - val_digit0_loss: 2.9001 - val_digit1_loss: 3.3175 - val_digit2_loss: 3.2752 - val_digit3_loss: 3.9237 - val_digit4_loss: 3.8671 - val_digit0_accuracy: 0.1081 - val_digit1_accuracy: 0.0725 - val_digit2_accuracy: 0.0852 - val_digit3_accuracy: 0.0665 - val_digit4_accuracy: 0.0879
# Epoch 45/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.7407 - digit0_loss: 2.0862 - digit1_loss: 2.5665 - digit2_loss: 2.7119 - digit3_loss: 2.5051 - digit4_loss: 1.9657 - digit0_accuracy: 0.3118 - digit1_accuracy: 0.2307 - digit2_accuracy: 0.2315 - digit3_accuracy: 0.2618 - digit4_accuracy: 0.3922 - val_loss: 22.7330 - val_digit0_loss: 3.7291 - val_digit1_loss: 4.0633 - val_digit2_loss: 3.9572 - val_digit3_loss: 5.0865 - val_digit4_loss: 5.5043 - val_digit0_accuracy: 0.0560 - val_digit1_accuracy: 0.0502 - val_digit2_accuracy: 0.0601 - val_digit3_accuracy: 0.0473 - val_digit4_accuracy: 0.0518
# Epoch 46/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 11.6409 - digit0_loss: 2.0960 - digit1_loss: 2.5544 - digit2_loss: 2.6811 - digit3_loss: 2.4870 - digit4_loss: 1.9087 - digit0_accuracy: 0.3171 - digit1_accuracy: 0.2365 - digit2_accuracy: 0.2333 - digit3_accuracy: 0.2710 - digit4_accuracy: 0.4020 - val_loss: 19.6812 - val_digit0_loss: 3.2841 - val_digit1_loss: 3.6378 - val_digit2_loss: 3.5647 - val_digit3_loss: 4.4431 - val_digit4_loss: 4.5823 - val_digit0_accuracy: 0.0757 - val_digit1_accuracy: 0.0794 - val_digit2_accuracy: 0.0787 - val_digit3_accuracy: 0.0653 - val_digit4_accuracy: 0.0654
# Epoch 47/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.5754 - digit0_loss: 2.0905 - digit1_loss: 2.5410 - digit2_loss: 2.6612 - digit3_loss: 2.4844 - digit4_loss: 1.8065 - digit0_accuracy: 0.3288 - digit1_accuracy: 0.2443 - digit2_accuracy: 0.2387 - digit3_accuracy: 0.2717 - digit4_accuracy: 0.4063 - val_loss: 12.5916 - val_digit0_loss: 2.2585 - val_digit1_loss: 2.8035 - val_digit2_loss: 2.7182 - val_digit3_loss: 2.6905 - val_digit4_loss: 2.2544 - val_digit0_accuracy: 0.3240 - val_digit1_accuracy: 0.2352 - val_digit2_accuracy: 0.2152 - val_digit3_accuracy: 0.2275 - val_digit4_accuracy: 0.4119
# Epoch 48/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.4512 - digit0_loss: 2.0191 - digit1_loss: 2.5540 - digit2_loss: 2.6409 - digit3_loss: 2.4175 - digit4_loss: 1.7839 - digit0_accuracy: 0.3335 - digit1_accuracy: 0.2504 - digit2_accuracy: 0.2421 - digit3_accuracy: 0.2789 - digit4_accuracy: 0.4085 - val_loss: 29.8755 - val_digit0_loss: 5.4366 - val_digit1_loss: 5.1353 - val_digit2_loss: 5.1741 - val_digit3_loss: 6.0900 - val_digit4_loss: 7.7167 - val_digit0_accuracy: 0.0408 - val_digit1_accuracy: 0.0509 - val_digit2_accuracy: 0.0458 - val_digit3_accuracy: 0.0419 - val_digit4_accuracy: 0.0415
# Epoch 49/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.3498 - digit0_loss: 2.0192 - digit1_loss: 2.5437 - digit2_loss: 2.5978 - digit3_loss: 2.4008 - digit4_loss: 1.7589 - digit0_accuracy: 0.3389 - digit1_accuracy: 0.2515 - digit2_accuracy: 0.2475 - digit3_accuracy: 0.2875 - digit4_accuracy: 0.4204 - val_loss: 26.2517 - val_digit0_loss: 4.4833 - val_digit1_loss: 4.4419 - val_digit2_loss: 4.7245 - val_digit3_loss: 5.4818 - val_digit4_loss: 6.4262 - val_digit0_accuracy: 0.0681 - val_digit1_accuracy: 0.0760 - val_digit2_accuracy: 0.0804 - val_digit3_accuracy: 0.0784 - val_digit4_accuracy: 0.0574
# Epoch 50/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.2534 - digit0_loss: 1.9774 - digit1_loss: 2.4748 - digit2_loss: 2.6043 - digit3_loss: 2.4442 - digit4_loss: 1.7270 - digit0_accuracy: 0.3473 - digit1_accuracy: 0.2567 - digit2_accuracy: 0.2479 - digit3_accuracy: 0.2883 - digit4_accuracy: 0.4313 - val_loss: 12.4832 - val_digit0_loss: 2.2456 - val_digit1_loss: 2.8303 - val_digit2_loss: 2.8521 - val_digit3_loss: 2.6367 - val_digit4_loss: 2.1366 - val_digit0_accuracy: 0.3053 - val_digit1_accuracy: 0.2235 - val_digit2_accuracy: 0.1946 - val_digit3_accuracy: 0.2352 - val_digit4_accuracy: 0.4773
# Epoch 51/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.1858 - digit0_loss: 2.0047 - digit1_loss: 2.4943 - digit2_loss: 2.5567 - digit3_loss: 2.4354 - digit4_loss: 1.7399 - digit0_accuracy: 0.3562 - digit1_accuracy: 0.2609 - digit2_accuracy: 0.2516 - digit3_accuracy: 0.2909 - digit4_accuracy: 0.4381 - val_loss: 16.5753 - val_digit0_loss: 2.7519 - val_digit1_loss: 2.9919 - val_digit2_loss: 3.4407 - val_digit3_loss: 3.3908 - val_digit4_loss: 4.4693 - val_digit0_accuracy: 0.1452 - val_digit1_accuracy: 0.1236 - val_digit2_accuracy: 0.1064 - val_digit3_accuracy: 0.1234 - val_digit4_accuracy: 0.1074
# Epoch 52/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.1172 - digit0_loss: 1.9663 - digit1_loss: 2.4722 - digit2_loss: 2.5523 - digit3_loss: 2.3904 - digit4_loss: 1.6605 - digit0_accuracy: 0.3627 - digit1_accuracy: 0.2644 - digit2_accuracy: 0.2545 - digit3_accuracy: 0.2955 - digit4_accuracy: 0.4399 - val_loss: 12.0245 - val_digit0_loss: 1.9555 - val_digit1_loss: 2.6672 - val_digit2_loss: 2.8451 - val_digit3_loss: 2.5232 - val_digit4_loss: 2.5184 - val_digit0_accuracy: 0.3773 - val_digit1_accuracy: 0.2595 - val_digit2_accuracy: 0.2136 - val_digit3_accuracy: 0.2611 - val_digit4_accuracy: 0.3528
# Epoch 53/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.0499 - digit0_loss: 1.9535 - digit1_loss: 2.5057 - digit2_loss: 2.5316 - digit3_loss: 2.3951 - digit4_loss: 1.6810 - digit0_accuracy: 0.3661 - digit1_accuracy: 0.2704 - digit2_accuracy: 0.2587 - digit3_accuracy: 0.2984 - digit4_accuracy: 0.4486 - val_loss: 16.5051 - val_digit0_loss: 2.5903 - val_digit1_loss: 2.9147 - val_digit2_loss: 3.4441 - val_digit3_loss: 3.5598 - val_digit4_loss: 4.3801 - val_digit0_accuracy: 0.1892 - val_digit1_accuracy: 0.1626 - val_digit2_accuracy: 0.1146 - val_digit3_accuracy: 0.1519 - val_digit4_accuracy: 0.1387
# Epoch 54/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.9880 - digit0_loss: 1.8967 - digit1_loss: 2.4566 - digit2_loss: 2.5344 - digit3_loss: 2.3611 - digit4_loss: 1.6411 - digit0_accuracy: 0.3715 - digit1_accuracy: 0.2739 - digit2_accuracy: 0.2610 - digit3_accuracy: 0.3028 - digit4_accuracy: 0.4503 - val_loss: 14.4299 - val_digit0_loss: 2.3911 - val_digit1_loss: 2.7499 - val_digit2_loss: 3.1685 - val_digit3_loss: 3.0088 - val_digit4_loss: 3.6874 - val_digit0_accuracy: 0.2115 - val_digit1_accuracy: 0.1730 - val_digit2_accuracy: 0.1588 - val_digit3_accuracy: 0.1921 - val_digit4_accuracy: 0.1742
# Epoch 55/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.8832 - digit0_loss: 1.8942 - digit1_loss: 2.4771 - digit2_loss: 2.5218 - digit3_loss: 2.3428 - digit4_loss: 1.6584 - digit0_accuracy: 0.3808 - digit1_accuracy: 0.2744 - digit2_accuracy: 0.2681 - digit3_accuracy: 0.3078 - digit4_accuracy: 0.4603 - val_loss: 14.8048 - val_digit0_loss: 2.5045 - val_digit1_loss: 2.9191 - val_digit2_loss: 3.2013 - val_digit3_loss: 2.9852 - val_digit4_loss: 3.7617 - val_digit0_accuracy: 0.2054 - val_digit1_accuracy: 0.1492 - val_digit2_accuracy: 0.1764 - val_digit3_accuracy: 0.1978 - val_digit4_accuracy: 0.1667
# Epoch 56/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.7866 - digit0_loss: 1.8523 - digit1_loss: 2.4992 - digit2_loss: 2.5550 - digit3_loss: 2.3592 - digit4_loss: 1.6501 - digit0_accuracy: 0.3863 - digit1_accuracy: 0.2812 - digit2_accuracy: 0.2731 - digit3_accuracy: 0.3123 - digit4_accuracy: 0.4689 - val_loss: 11.7064 - val_digit0_loss: 1.9946 - val_digit1_loss: 2.6466 - val_digit2_loss: 2.6305 - val_digit3_loss: 2.3965 - val_digit4_loss: 2.1120 - val_digit0_accuracy: 0.3977 - val_digit1_accuracy: 0.2653 - val_digit2_accuracy: 0.2936 - val_digit3_accuracy: 0.3069 - val_digit4_accuracy: 0.4031
# Epoch 57/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 10.7079 - digit0_loss: 1.8390 - digit1_loss: 2.4079 - digit2_loss: 2.4328 - digit3_loss: 2.2722 - digit4_loss: 1.6137 - digit0_accuracy: 0.3937 - digit1_accuracy: 0.2867 - digit2_accuracy: 0.2769 - digit3_accuracy: 0.3177 - digit4_accuracy: 0.4716 - val_loss: 13.5778 - val_digit0_loss: 2.2189 - val_digit1_loss: 2.8441 - val_digit2_loss: 2.9404 - val_digit3_loss: 2.8291 - val_digit4_loss: 2.7864 - val_digit0_accuracy: 0.2664 - val_digit1_accuracy: 0.1977 - val_digit2_accuracy: 0.1668 - val_digit3_accuracy: 0.1863 - val_digit4_accuracy: 0.2568
# Epoch 58/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.6414 - digit0_loss: 1.8925 - digit1_loss: 2.3896 - digit2_loss: 2.4843 - digit3_loss: 2.2881 - digit4_loss: 1.5787 - digit0_accuracy: 0.3996 - digit1_accuracy: 0.2869 - digit2_accuracy: 0.2792 - digit3_accuracy: 0.3189 - digit4_accuracy: 0.4760 - val_loss: 12.1543 - val_digit0_loss: 2.1889 - val_digit1_loss: 2.8143 - val_digit2_loss: 2.7661 - val_digit3_loss: 2.4039 - val_digit4_loss: 2.3530 - val_digit0_accuracy: 0.3017 - val_digit1_accuracy: 0.2673 - val_digit2_accuracy: 0.2395 - val_digit3_accuracy: 0.2746 - val_digit4_accuracy: 0.3720
# Epoch 59/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.5871 - digit0_loss: 1.8168 - digit1_loss: 2.3618 - digit2_loss: 2.5615 - digit3_loss: 2.2276 - digit4_loss: 1.6582 - digit0_accuracy: 0.4053 - digit1_accuracy: 0.2944 - digit2_accuracy: 0.2844 - digit3_accuracy: 0.3240 - digit4_accuracy: 0.4807 - val_loss: 18.2759 - val_digit0_loss: 2.9769 - val_digit1_loss: 3.1760 - val_digit2_loss: 3.4980 - val_digit3_loss: 3.8845 - val_digit4_loss: 4.4025 - val_digit0_accuracy: 0.1626 - val_digit1_accuracy: 0.1418 - val_digit2_accuracy: 0.1267 - val_digit3_accuracy: 0.1534 - val_digit4_accuracy: 0.1505
# Epoch 60/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 10.5359 - digit0_loss: 1.8528 - digit1_loss: 2.3849 - digit2_loss: 2.4511 - digit3_loss: 2.2353 - digit4_loss: 1.5126 - digit0_accuracy: 0.4083 - digit1_accuracy: 0.2950 - digit2_accuracy: 0.2856 - digit3_accuracy: 0.3279 - digit4_accuracy: 0.4841 - val_loss: 16.0493 - val_digit0_loss: 2.8758 - val_digit1_loss: 3.3755 - val_digit2_loss: 3.4126 - val_digit3_loss: 3.3556 - val_digit4_loss: 3.2144 - val_digit0_accuracy: 0.1953 - val_digit1_accuracy: 0.1536 - val_digit2_accuracy: 0.1594 - val_digit3_accuracy: 0.1999 - val_digit4_accuracy: 0.2454
# Epoch 61/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.4392 - digit0_loss: 1.8286 - digit1_loss: 2.3771 - digit2_loss: 2.4769 - digit3_loss: 2.2691 - digit4_loss: 1.5080 - digit0_accuracy: 0.4137 - digit1_accuracy: 0.2997 - digit2_accuracy: 0.2926 - digit3_accuracy: 0.3312 - digit4_accuracy: 0.4935 - val_loss: 35.2402 - val_digit0_loss: 6.4634 - val_digit1_loss: 5.7649 - val_digit2_loss: 6.2277 - val_digit3_loss: 6.9603 - val_digit4_loss: 9.2500 - val_digit0_accuracy: 0.0584 - val_digit1_accuracy: 0.0574 - val_digit2_accuracy: 0.0580 - val_digit3_accuracy: 0.0723 - val_digit4_accuracy: 0.0662
# Epoch 62/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.6102 - digit0_loss: 1.7915 - digit1_loss: 2.3974 - digit2_loss: 2.4712 - digit3_loss: 2.2453 - digit4_loss: 1.5950 - digit0_accuracy: 0.4062 - digit1_accuracy: 0.2953 - digit2_accuracy: 0.2829 - digit3_accuracy: 0.3258 - digit4_accuracy: 0.4754 - val_loss: 58.2450 - val_digit0_loss: 12.9571 - val_digit1_loss: 11.7669 - val_digit2_loss: 12.2774 - val_digit3_loss: 10.4293 - val_digit4_loss: 13.8475 - val_digit0_accuracy: 0.0279 - val_digit1_accuracy: 0.0433 - val_digit2_accuracy: 0.0329 - val_digit3_accuracy: 0.0326 - val_digit4_accuracy: 0.0500
# Epoch 63/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.4197 - digit0_loss: 1.7942 - digit1_loss: 2.3886 - digit2_loss: 2.4647 - digit3_loss: 2.2885 - digit4_loss: 1.5392 - digit0_accuracy: 0.4212 - digit1_accuracy: 0.3014 - digit2_accuracy: 0.2879 - digit3_accuracy: 0.3346 - digit4_accuracy: 0.4964 - val_loss: 43.1540 - val_digit0_loss: 10.5674 - val_digit1_loss: 8.7727 - val_digit2_loss: 7.6435 - val_digit3_loss: 6.6786 - val_digit4_loss: 12.2296 - val_digit0_accuracy: 0.0307 - val_digit1_accuracy: 0.0279 - val_digit2_accuracy: 0.0463 - val_digit3_accuracy: 0.0328 - val_digit4_accuracy: 0.0560
# Epoch 64/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.2871 - digit0_loss: 1.7559 - digit1_loss: 2.3491 - digit2_loss: 2.4383 - digit3_loss: 2.2050 - digit4_loss: 1.5037 - digit0_accuracy: 0.4291 - digit1_accuracy: 0.3077 - digit2_accuracy: 0.2950 - digit3_accuracy: 0.3445 - digit4_accuracy: 0.5075 - val_loss: 24.0466 - val_digit0_loss: 5.1137 - val_digit1_loss: 5.5095 - val_digit2_loss: 4.3043 - val_digit3_loss: 3.8162 - val_digit4_loss: 7.8591 - val_digit0_accuracy: 0.1195 - val_digit1_accuracy: 0.0568 - val_digit2_accuracy: 0.1216 - val_digit3_accuracy: 0.1035 - val_digit4_accuracy: 0.0723
# Epoch 65/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.1958 - digit0_loss: 1.6972 - digit1_loss: 2.3438 - digit2_loss: 2.4441 - digit3_loss: 2.2322 - digit4_loss: 1.4684 - digit0_accuracy: 0.4375 - digit1_accuracy: 0.3143 - digit2_accuracy: 0.3018 - digit3_accuracy: 0.3447 - digit4_accuracy: 0.5120 - val_loss: 18.6156 - val_digit0_loss: 3.5189 - val_digit1_loss: 4.5208 - val_digit2_loss: 3.8414 - val_digit3_loss: 3.2305 - val_digit4_loss: 5.6523 - val_digit0_accuracy: 0.1916 - val_digit1_accuracy: 0.1049 - val_digit2_accuracy: 0.1740 - val_digit3_accuracy: 0.1674 - val_digit4_accuracy: 0.1441
# Epoch 66/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.1335 - digit0_loss: 1.6917 - digit1_loss: 2.3117 - digit2_loss: 2.4389 - digit3_loss: 2.1913 - digit4_loss: 1.4892 - digit0_accuracy: 0.4399 - digit1_accuracy: 0.3178 - digit2_accuracy: 0.3023 - digit3_accuracy: 0.3486 - digit4_accuracy: 0.5145 - val_loss: 26.3272 - val_digit0_loss: 5.6176 - val_digit1_loss: 6.1553 - val_digit2_loss: 4.9613 - val_digit3_loss: 4.3357 - val_digit4_loss: 7.6976 - val_digit0_accuracy: 0.1266 - val_digit1_accuracy: 0.0724 - val_digit2_accuracy: 0.0829 - val_digit3_accuracy: 0.0935 - val_digit4_accuracy: 0.1212
# Epoch 67/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 10.0672 - digit0_loss: 1.7016 - digit1_loss: 2.3511 - digit2_loss: 2.3751 - digit3_loss: 2.1602 - digit4_loss: 1.4634 - digit0_accuracy: 0.4430 - digit1_accuracy: 0.3193 - digit2_accuracy: 0.3065 - digit3_accuracy: 0.3538 - digit4_accuracy: 0.5189 - val_loss: 26.1549 - val_digit0_loss: 5.8422 - val_digit1_loss: 5.9952 - val_digit2_loss: 4.8916 - val_digit3_loss: 4.5386 - val_digit4_loss: 7.2830 - val_digit0_accuracy: 0.1241 - val_digit1_accuracy: 0.0638 - val_digit2_accuracy: 0.0835 - val_digit3_accuracy: 0.1081 - val_digit4_accuracy: 0.1403
# Epoch 68/500
# ...
# Epoch 476/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7328 - digit0_loss: 0.7840 - digit1_loss: 1.3955 - digit2_loss: 1.5881 - digit3_loss: 1.3324 - digit4_loss: 0.6834 - digit0_accuracy: 0.7434 - digit1_accuracy: 0.5700 - digit2_accuracy: 0.5433 - digit3_accuracy: 0.5945 - digit4_accuracy: 0.7765 - val_loss: 8.3956 - val_digit0_loss: 1.3788 - val_digit1_loss: 2.0360 - val_digit2_loss: 1.7801 - val_digit3_loss: 1.7591 - val_digit4_loss: 2.0549 - val_digit0_accuracy: 0.6605 - val_digit1_accuracy: 0.5645 - val_digit2_accuracy: 0.5455 - val_digit3_accuracy: 0.5773 - val_digit4_accuracy: 0.5924
# Epoch 477/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 5.7861 - digit0_loss: 0.7754 - digit1_loss: 1.4716 - digit2_loss: 1.5783 - digit3_loss: 1.3236 - digit4_loss: 0.6738 - digit0_accuracy: 0.7361 - digit1_accuracy: 0.5717 - digit2_accuracy: 0.5382 - digit3_accuracy: 0.5905 - digit4_accuracy: 0.7726 - val_loss: 5.8468 - val_digit0_loss: 0.7845 - val_digit1_loss: 1.7050 - val_digit2_loss: 1.4033 - val_digit3_loss: 1.2698 - val_digit4_loss: 0.9866 - val_digit0_accuracy: 0.7426 - val_digit1_accuracy: 0.6166 - val_digit2_accuracy: 0.5882 - val_digit3_accuracy: 0.6387 - val_digit4_accuracy: 0.7292
# Epoch 478/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7594 - digit0_loss: 0.7505 - digit1_loss: 1.4351 - digit2_loss: 1.5907 - digit3_loss: 1.3470 - digit4_loss: 0.6383 - digit0_accuracy: 0.7380 - digit1_accuracy: 0.5705 - digit2_accuracy: 0.5413 - digit3_accuracy: 0.5914 - digit4_accuracy: 0.7779 - val_loss: 4.9747 - val_digit0_loss: 0.6181 - val_digit1_loss: 1.5479 - val_digit2_loss: 1.2951 - val_digit3_loss: 1.1749 - val_digit4_loss: 0.6664 - val_digit0_accuracy: 0.8026 - val_digit1_accuracy: 0.6514 - val_digit2_accuracy: 0.6353 - val_digit3_accuracy: 0.6835 - val_digit4_accuracy: 0.7909
# Epoch 479/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 5.7733 - digit0_loss: 0.7371 - digit1_loss: 1.3943 - digit2_loss: 1.5416 - digit3_loss: 1.3123 - digit4_loss: 0.6558 - digit0_accuracy: 0.7384 - digit1_accuracy: 0.5653 - digit2_accuracy: 0.5356 - digit3_accuracy: 0.5902 - digit4_accuracy: 0.7740 - val_loss: 5.2392 - val_digit0_loss: 0.6886 - val_digit1_loss: 1.5307 - val_digit2_loss: 1.3846 - val_digit3_loss: 1.2035 - val_digit4_loss: 0.8605 - val_digit0_accuracy: 0.7920 - val_digit1_accuracy: 0.6433 - val_digit2_accuracy: 0.6212 - val_digit3_accuracy: 0.6677 - val_digit4_accuracy: 0.7655
# Epoch 480/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7837 - digit0_loss: 0.7415 - digit1_loss: 1.4882 - digit2_loss: 1.6019 - digit3_loss: 1.2874 - digit4_loss: 0.6707 - digit0_accuracy: 0.7395 - digit1_accuracy: 0.5655 - digit2_accuracy: 0.5402 - digit3_accuracy: 0.5889 - digit4_accuracy: 0.7743 - val_loss: 5.1916 - val_digit0_loss: 0.9053 - val_digit1_loss: 1.5395 - val_digit2_loss: 1.4076 - val_digit3_loss: 1.0308 - val_digit4_loss: 0.9956 - val_digit0_accuracy: 0.7316 - val_digit1_accuracy: 0.6515 - val_digit2_accuracy: 0.6254 - val_digit3_accuracy: 0.6725 - val_digit4_accuracy: 0.7610
# Epoch 481/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7686 - digit0_loss: 0.8296 - digit1_loss: 1.3902 - digit2_loss: 1.5706 - digit3_loss: 1.3700 - digit4_loss: 0.6729 - digit0_accuracy: 0.7371 - digit1_accuracy: 0.5648 - digit2_accuracy: 0.5452 - digit3_accuracy: 0.5909 - digit4_accuracy: 0.7726 - val_loss: 5.9643 - val_digit0_loss: 0.8623 - val_digit1_loss: 1.3933 - val_digit2_loss: 1.4379 - val_digit3_loss: 1.2002 - val_digit4_loss: 1.4791 - val_digit0_accuracy: 0.7291 - val_digit1_accuracy: 0.6292 - val_digit2_accuracy: 0.6130 - val_digit3_accuracy: 0.6350 - val_digit4_accuracy: 0.6905
# Epoch 482/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7377 - digit0_loss: 0.7763 - digit1_loss: 1.4506 - digit2_loss: 1.5533 - digit3_loss: 1.4016 - digit4_loss: 0.6283 - digit0_accuracy: 0.7382 - digit1_accuracy: 0.5657 - digit2_accuracy: 0.5417 - digit3_accuracy: 0.5929 - digit4_accuracy: 0.7787 - val_loss: 5.4154 - val_digit0_loss: 0.7676 - val_digit1_loss: 1.4333 - val_digit2_loss: 1.3532 - val_digit3_loss: 1.1788 - val_digit4_loss: 0.9968 - val_digit0_accuracy: 0.7494 - val_digit1_accuracy: 0.6572 - val_digit2_accuracy: 0.6327 - val_digit3_accuracy: 0.6516 - val_digit4_accuracy: 0.7344
# Epoch 483/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 5.7219 - digit0_loss: 0.7532 - digit1_loss: 1.4207 - digit2_loss: 1.5025 - digit3_loss: 1.3149 - digit4_loss: 0.6339 - digit0_accuracy: 0.7363 - digit1_accuracy: 0.5700 - digit2_accuracy: 0.5418 - digit3_accuracy: 0.5931 - digit4_accuracy: 0.7805 - val_loss: 6.6775 - val_digit0_loss: 0.9426 - val_digit1_loss: 1.6446 - val_digit2_loss: 1.5098 - val_digit3_loss: 1.3281 - val_digit4_loss: 1.7187 - val_digit0_accuracy: 0.7120 - val_digit1_accuracy: 0.6111 - val_digit2_accuracy: 0.5923 - val_digit3_accuracy: 0.6166 - val_digit4_accuracy: 0.6539
# Epoch 484/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7304 - digit0_loss: 0.7631 - digit1_loss: 1.4281 - digit2_loss: 1.5333 - digit3_loss: 1.3990 - digit4_loss: 0.6342 - digit0_accuracy: 0.7385 - digit1_accuracy: 0.5672 - digit2_accuracy: 0.5426 - digit3_accuracy: 0.5948 - digit4_accuracy: 0.7801 - val_loss: 5.8397 - val_digit0_loss: 0.9261 - val_digit1_loss: 1.5055 - val_digit2_loss: 1.4361 - val_digit3_loss: 1.2542 - val_digit4_loss: 1.1696 - val_digit0_accuracy: 0.7351 - val_digit1_accuracy: 0.6346 - val_digit2_accuracy: 0.6241 - val_digit3_accuracy: 0.6419 - val_digit4_accuracy: 0.7197
# Epoch 485/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7235 - digit0_loss: 0.7648 - digit1_loss: 1.4346 - digit2_loss: 1.5814 - digit3_loss: 1.3289 - digit4_loss: 0.6134 - digit0_accuracy: 0.7391 - digit1_accuracy: 0.5683 - digit2_accuracy: 0.5438 - digit3_accuracy: 0.5911 - digit4_accuracy: 0.7765 - val_loss: 4.8134 - val_digit0_loss: 0.6903 - val_digit1_loss: 1.3245 - val_digit2_loss: 1.3171 - val_digit3_loss: 1.0213 - val_digit4_loss: 0.8933 - val_digit0_accuracy: 0.7834 - val_digit1_accuracy: 0.6772 - val_digit2_accuracy: 0.6503 - val_digit3_accuracy: 0.6832 - val_digit4_accuracy: 0.7858
# Epoch 486/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7005 - digit0_loss: 0.7454 - digit1_loss: 1.4506 - digit2_loss: 1.5545 - digit3_loss: 1.3485 - digit4_loss: 0.6264 - digit0_accuracy: 0.7411 - digit1_accuracy: 0.5700 - digit2_accuracy: 0.5429 - digit3_accuracy: 0.5923 - digit4_accuracy: 0.7814 - val_loss: 9.6512 - val_digit0_loss: 1.7339 - val_digit1_loss: 1.8135 - val_digit2_loss: 1.7794 - val_digit3_loss: 1.8961 - val_digit4_loss: 3.2975 - val_digit0_accuracy: 0.5932 - val_digit1_accuracy: 0.5675 - val_digit2_accuracy: 0.5299 - val_digit3_accuracy: 0.5346 - val_digit4_accuracy: 0.5425
# Epoch 487/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7254 - digit0_loss: 0.7921 - digit1_loss: 1.4316 - digit2_loss: 1.5588 - digit3_loss: 1.2977 - digit4_loss: 0.6484 - digit0_accuracy: 0.7405 - digit1_accuracy: 0.5629 - digit2_accuracy: 0.5422 - digit3_accuracy: 0.5907 - digit4_accuracy: 0.7814 - val_loss: 4.6494 - val_digit0_loss: 0.6286 - val_digit1_loss: 1.2586 - val_digit2_loss: 1.3537 - val_digit3_loss: 1.0058 - val_digit4_loss: 0.6439 - val_digit0_accuracy: 0.7916 - val_digit1_accuracy: 0.6720 - val_digit2_accuracy: 0.6553 - val_digit3_accuracy: 0.6879 - val_digit4_accuracy: 0.7971
# Epoch 488/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7089 - digit0_loss: 0.7746 - digit1_loss: 1.4038 - digit2_loss: 1.5493 - digit3_loss: 1.2903 - digit4_loss: 0.6289 - digit0_accuracy: 0.7373 - digit1_accuracy: 0.5657 - digit2_accuracy: 0.5448 - digit3_accuracy: 0.5912 - digit4_accuracy: 0.7816 - val_loss: 5.1411 - val_digit0_loss: 0.7215 - val_digit1_loss: 1.2730 - val_digit2_loss: 1.4431 - val_digit3_loss: 1.0651 - val_digit4_loss: 0.8933 - val_digit0_accuracy: 0.7506 - val_digit1_accuracy: 0.6485 - val_digit2_accuracy: 0.6355 - val_digit3_accuracy: 0.6578 - val_digit4_accuracy: 0.7572
# Epoch 489/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.6886 - digit0_loss: 0.7552 - digit1_loss: 1.3718 - digit2_loss: 1.6134 - digit3_loss: 1.3439 - digit4_loss: 0.6162 - digit0_accuracy: 0.7406 - digit1_accuracy: 0.5711 - digit2_accuracy: 0.5408 - digit3_accuracy: 0.5962 - digit4_accuracy: 0.7799 - val_loss: 4.3916 - val_digit0_loss: 0.5414 - val_digit1_loss: 1.2938 - val_digit2_loss: 1.2765 - val_digit3_loss: 0.9858 - val_digit4_loss: 0.6360 - val_digit0_accuracy: 0.8094 - val_digit1_accuracy: 0.6872 - val_digit2_accuracy: 0.6681 - val_digit3_accuracy: 0.6989 - val_digit4_accuracy: 0.8259
# Epoch 490/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7165 - digit0_loss: 0.7771 - digit1_loss: 1.3906 - digit2_loss: 1.5053 - digit3_loss: 1.2810 - digit4_loss: 0.6061 - digit0_accuracy: 0.7381 - digit1_accuracy: 0.5674 - digit2_accuracy: 0.5420 - digit3_accuracy: 0.5963 - digit4_accuracy: 0.7780 - val_loss: 5.0071 - val_digit0_loss: 0.7625 - val_digit1_loss: 1.4246 - val_digit2_loss: 1.3222 - val_digit3_loss: 1.1572 - val_digit4_loss: 0.9954 - val_digit0_accuracy: 0.7637 - val_digit1_accuracy: 0.6590 - val_digit2_accuracy: 0.6600 - val_digit3_accuracy: 0.6771 - val_digit4_accuracy: 0.7641
# Epoch 491/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.6820 - digit0_loss: 0.7687 - digit1_loss: 1.3936 - digit2_loss: 1.5612 - digit3_loss: 1.3374 - digit4_loss: 0.6619 - digit0_accuracy: 0.7413 - digit1_accuracy: 0.5721 - digit2_accuracy: 0.5446 - digit3_accuracy: 0.5956 - digit4_accuracy: 0.7808 - val_loss: 4.6585 - val_digit0_loss: 0.6488 - val_digit1_loss: 1.4036 - val_digit2_loss: 1.2760 - val_digit3_loss: 1.0558 - val_digit4_loss: 0.8533 - val_digit0_accuracy: 0.7943 - val_digit1_accuracy: 0.6688 - val_digit2_accuracy: 0.6668 - val_digit3_accuracy: 0.6876 - val_digit4_accuracy: 0.7889
# Epoch 492/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.6808 - digit0_loss: 0.7777 - digit1_loss: 1.4342 - digit2_loss: 1.5453 - digit3_loss: 1.3034 - digit4_loss: 0.6466 - digit0_accuracy: 0.7408 - digit1_accuracy: 0.5685 - digit2_accuracy: 0.5511 - digit3_accuracy: 0.5971 - digit4_accuracy: 0.7808 - val_loss: 4.5741 - val_digit0_loss: 0.5885 - val_digit1_loss: 1.4059 - val_digit2_loss: 1.2263 - val_digit3_loss: 0.9969 - val_digit4_loss: 0.8006 - val_digit0_accuracy: 0.8050 - val_digit1_accuracy: 0.6633 - val_digit2_accuracy: 0.6550 - val_digit3_accuracy: 0.6921 - val_digit4_accuracy: 0.8026
# Epoch 493/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.6699 - digit0_loss: 0.7878 - digit1_loss: 1.3818 - digit2_loss: 1.5367 - digit3_loss: 1.2603 - digit4_loss: 0.6141 - digit0_accuracy: 0.7389 - digit1_accuracy: 0.5691 - digit2_accuracy: 0.5464 - digit3_accuracy: 0.5970 - digit4_accuracy: 0.7826 - val_loss: 4.6137 - val_digit0_loss: 0.5962 - val_digit1_loss: 1.4103 - val_digit2_loss: 1.2212 - val_digit3_loss: 0.9907 - val_digit4_loss: 0.7949 - val_digit0_accuracy: 0.8097 - val_digit1_accuracy: 0.6662 - val_digit2_accuracy: 0.6530 - val_digit3_accuracy: 0.6901 - val_digit4_accuracy: 0.7977
# Epoch 494/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.6840 - digit0_loss: 0.7950 - digit1_loss: 1.4088 - digit2_loss: 1.6023 - digit3_loss: 1.2886 - digit4_loss: 0.6192 - digit0_accuracy: 0.7402 - digit1_accuracy: 0.5676 - digit2_accuracy: 0.5447 - digit3_accuracy: 0.5983 - digit4_accuracy: 0.7826 - val_loss: 5.2306 - val_digit0_loss: 0.7556 - val_digit1_loss: 1.4984 - val_digit2_loss: 1.3191 - val_digit3_loss: 1.1013 - val_digit4_loss: 0.8599 - val_digit0_accuracy: 0.7657 - val_digit1_accuracy: 0.6348 - val_digit2_accuracy: 0.6304 - val_digit3_accuracy: 0.6598 - val_digit4_accuracy: 0.7686
# Epoch 495/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7027 - digit0_loss: 0.8870 - digit1_loss: 1.3928 - digit2_loss: 1.4921 - digit3_loss: 1.2644 - digit4_loss: 0.6303 - digit0_accuracy: 0.7336 - digit1_accuracy: 0.5663 - digit2_accuracy: 0.5459 - digit3_accuracy: 0.5957 - digit4_accuracy: 0.7811 - val_loss: 4.8447 - val_digit0_loss: 0.5801 - val_digit1_loss: 1.3765 - val_digit2_loss: 1.2783 - val_digit3_loss: 1.0046 - val_digit4_loss: 0.8535 - val_digit0_accuracy: 0.7939 - val_digit1_accuracy: 0.6671 - val_digit2_accuracy: 0.6479 - val_digit3_accuracy: 0.6913 - val_digit4_accuracy: 0.7790
# Epoch 496/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 5.6914 - digit0_loss: 0.7653 - digit1_loss: 1.4925 - digit2_loss: 1.6511 - digit3_loss: 1.3284 - digit4_loss: 0.6087 - digit0_accuracy: 0.7390 - digit1_accuracy: 0.5662 - digit2_accuracy: 0.5475 - digit3_accuracy: 0.5968 - digit4_accuracy: 0.7799 - val_loss: 4.9726 - val_digit0_loss: 0.6308 - val_digit1_loss: 1.4872 - val_digit2_loss: 1.2998 - val_digit3_loss: 0.9937 - val_digit4_loss: 1.0601 - val_digit0_accuracy: 0.7692 - val_digit1_accuracy: 0.6326 - val_digit2_accuracy: 0.6154 - val_digit3_accuracy: 0.6776 - val_digit4_accuracy: 0.7814
# Epoch 497/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.6654 - digit0_loss: 0.8010 - digit1_loss: 1.4600 - digit2_loss: 1.5513 - digit3_loss: 1.3141 - digit4_loss: 0.6407 - digit0_accuracy: 0.7406 - digit1_accuracy: 0.5695 - digit2_accuracy: 0.5468 - digit3_accuracy: 0.6004 - digit4_accuracy: 0.7838 - val_loss: 4.7358 - val_digit0_loss: 0.6327 - val_digit1_loss: 1.5699 - val_digit2_loss: 1.2706 - val_digit3_loss: 0.9657 - val_digit4_loss: 0.8001 - val_digit0_accuracy: 0.7809 - val_digit1_accuracy: 0.6290 - val_digit2_accuracy: 0.6272 - val_digit3_accuracy: 0.6880 - val_digit4_accuracy: 0.8073
# Epoch 498/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.6954 - digit0_loss: 0.7348 - digit1_loss: 1.3692 - digit2_loss: 1.5343 - digit3_loss: 1.4157 - digit4_loss: 0.6389 - digit0_accuracy: 0.7384 - digit1_accuracy: 0.5674 - digit2_accuracy: 0.5445 - digit3_accuracy: 0.5960 - digit4_accuracy: 0.7833 - val_loss: 5.4088 - val_digit0_loss: 0.7942 - val_digit1_loss: 1.5835 - val_digit2_loss: 1.3059 - val_digit3_loss: 1.1335 - val_digit4_loss: 1.1499 - val_digit0_accuracy: 0.7433 - val_digit1_accuracy: 0.6328 - val_digit2_accuracy: 0.6290 - val_digit3_accuracy: 0.6788 - val_digit4_accuracy: 0.7534
# Epoch 499/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.7319 - digit0_loss: 0.7781 - digit1_loss: 1.4463 - digit2_loss: 1.5507 - digit3_loss: 1.2864 - digit4_loss: 0.6471 - digit0_accuracy: 0.7397 - digit1_accuracy: 0.5665 - digit2_accuracy: 0.5394 - digit3_accuracy: 0.5930 - digit4_accuracy: 0.7789 - val_loss: 4.6426 - val_digit0_loss: 0.6443 - val_digit1_loss: 1.3257 - val_digit2_loss: 1.3700 - val_digit3_loss: 1.0592 - val_digit4_loss: 0.7690 - val_digit0_accuracy: 0.7838 - val_digit1_accuracy: 0.6719 - val_digit2_accuracy: 0.6597 - val_digit3_accuracy: 0.6890 - val_digit4_accuracy: 0.8117
# Epoch 500/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 5.6603 - digit0_loss: 0.7696 - digit1_loss: 1.3474 - digit2_loss: 1.5043 - digit3_loss: 1.2589 - digit4_loss: 0.6129 - digit0_accuracy: 0.7449 - digit1_accuracy: 0.5731 - digit2_accuracy: 0.5505 - digit3_accuracy: 0.5970 - digit4_accuracy: 0.7836 - val_loss: 4.8817 - val_digit0_loss: 0.6254 - val_digit1_loss: 1.3902 - val_digit2_loss: 1.2365 - val_digit3_loss: 1.0665 - val_digit4_loss: 0.9573 - val_digit0_accuracy: 0.7747 - val_digit1_accuracy: 0.6585 - val_digit2_accuracy: 0.6486 - val_digit3_accuracy: 0.6844 - val_digit4_accuracy: 0.7788
#
# Epoch 00500: saving model to ./output-captcha/weights-500-5.66.hdf5

# %%
plot_model_history(history_perm)

# %% [markdown]
# # 5 - Teste

# %% [markdown]
# ## 5.1 - Funções auxiliares

# %%
################################################################################################################
#
# Predição
#
#    Função que recebe um modelo e uma imagem captcha e retorna a string contida nela conforme determinado pelo
#    modelo.
#
################################################################################################################

def predict(net, img):
    
    word_predicted = np.array(net.predict(img[np.newaxis, :, :, np.newaxis]))
    word_predicted = np.reshape(word_predicted, (size_word, num_symbols))
    
    capt = ''
    for symbol in word_predicted:
        idx_symbol = np.argmax(symbol)
        capt += symbols[idx_symbol]
    
    return capt

# %%
################################################################################################################
#
# Plota Matriz de Confusão
#
#    Plota a Matriz de confunsão das classes reais vs as preditas
#
################################################################################################################

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
        
    #print(cm)

    plt.figure(figsize = (15,15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    
    plt.xticks(tick_marks, classes, rotation=45)    
    plt.yticks(tick_marks, classes)

    plt.tick_params(axis='both', which='major')
    plt.tick_params(axis='both', which='minor')
    
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
################################################################################################################
#
# Métricas
#
#    Plota a Matriz de confunsão e retorna as métricas de acurácia.
#
################################################################################################################

def metrics(x, y, model):
    
    # Estatísticas
    # index 5 = matriz total, de todos os digitos.
    confusion_digit_predict = [[] for _ in range(6)]
    confusion_digit_true = [[] for _ in range(6)]

    y_d = np.array(y)    
    y_d = np.argmax(y, axis=2);    
    d_num_correct = [0, 0, 0, 0, 0]
    #print(x.shape);
    #print(x[0].shape);
    for i in range(x.shape[0]):
        capt = predict(model, x[i,:,:,0])        
        
        for j in range(size_word):
            d_num_correct[j] = d_num_correct[j] + np.sum(capt[j] == symbols[y_d[j][i]])
            confusion_digit_predict[j].extend(capt[j]);
            confusion_digit_true[j].extend(symbols[y_d[j][i]]);
            #Geral
            confusion_digit_predict[5].extend(capt[j]);
            confusion_digit_true[5].extend(symbols[y_d[j][i]]);
    
    # Plota matizes de confusion:
    for j in range(size_word):
        plot_confusion_matrix(confusion_matrix(confusion_digit_predict[j], confusion_digit_true[j]), symbols, title='Confusion matrix D'+str(j))
    
    # Matrix geral
    plot_confusion_matrix(confusion_matrix(confusion_digit_predict[5], confusion_digit_true[5]), symbols, title='Confusion matrix Geral')
    
    num_samples = x.shape[0];
    num_caracteres = len(capt)*num_samples;
    num_correct = np.sum(d_num_correct);
    
    d_accuracy = np.array(d_num_correct)/num_samples
    accuracy = float(num_correct)/num_caracteres
    
    #plot_confusion_matrix(confusion_matrix(true_class, predicted_class), className)
    
    return accuracy, d_accuracy

# %%
################################################################################################################
#
# Amostras de Predição
#
################################################################################################################
def predict_sample(net):
    
    fig, axs = plt.subplots(2,2,figsize=(10,10))
    
    j = 0
    k = 0
    for i in (10, 100, 1000, 10000):        
        img = X_test[i,:,:]
        img.shape = (30,80)    
        axs[j%2][k%3].imshow(img, cmap='gray')
        
        word = predict(net,img)
        axs[j%2][k%2].set_title(word)
        
        k = (j - 1 < 1)
        j = j + 1
    
    plt.axis('off')    
    plt.show()

# %% [markdown]
# ## 5.2 - Experimentos

# %% [markdown]
# ### 5.2.1 - Modelo randômico

# %%
################################################################################################################
#
# Avalia modelo randomico
#
################################################################################################################

net_random.evaluate(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]])
# Out:
# 19976/19976 [==============================] - 3s 149us/step
# [2.2936786856706686,
#  0.2742781341075897,
#  0.5791442394256592,
#  0.6858770847320557,
#  0.5316243171691895,
#  0.22131623327732086,
#  0.9133960604667664,
#  0.833149790763855,
#  0.8103724718093872,
#  0.8457148671150208,
#  0.9233580231666565]

# %%
accuracy, d_accuracy = metrics(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]], net_random)

# %%
print ("Accuracy on test data is: %0.2f, acc_d1= %0.2f, acc_d2= %0.2f, acc_d3= %0.2f, acc_d4= %0.2f, acc_d5= %0.2f"%(accuracy, d_accuracy[0], d_accuracy[1], d_accuracy[2], d_accuracy[3], d_accuracy[4]))
# Out:
# Accuracy on test data is: 0.87, acc_d1= 0.91, acc_d2= 0.83, acc_d3= 0.81, acc_d4= 0.85, acc_d5= 0.92

# %%
# Exemplo de predição
predict_sample(net_random);

# %%
# Saída por camada
# Get Output Layers
# MaxPool_1
#layer_name = 'MaxPool_1'
def plot_layers_output(model):
  layer_name = ['Conv_1','Conv_2','Conv_3']
  fig = plt.figure(figsize=(30,60))

  num_filtros = 5;
  idx_plot = 0
  for layer in layer_name:
      
      intermediate_layer_model = Model(inputs=model.input, outputs=model.get_layer(layer).output)
      features = intermediate_output = intermediate_layer_model.predict(img[np.newaxis, :, :, np.newaxis])
      num_filtros = features.shape[3]
      for i in range(num_filtros):
      
          ax = fig.add_subplot(20, 5, idx_plot+1, xticks=[], yticks=[])   
          ax.set_title(layer + '_' + str(i))
          plt.imshow(features[0,:,:,i], cmap="gray")
          idx_plot = idx_plot + 1
      
  plt.show()

# %%
plot_layers_output(net_random)

# %% [markdown]
# ### 5.2.2 - Modelo permutação

# %%
################################################################################################################
#
# Avalia modelo Permutação
#
################################################################################################################

net_perm.evaluate(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]])
# Out:
# 19976/19976 [==============================] - 3s 145us/step
# [4.912904190262843,
#  0.7025106549263,
#  1.1579240560531616,
#  1.2525972127914429,
#  1.0592502355575562,
#  0.7386168241500854,
#  0.7720764875411987,
#  0.6548358201980591,
#  0.6411694288253784,
#  0.6854725480079651,
#  0.7763816714286804]

# %%
accuracy, d_accuracy = metrics(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]], net_perm)

# %%
print ("Accuracy on test data is: %0.2f, acc_d1= %0.2f, acc_d2= %0.2f, acc_d3= %0.2f, acc_d4= %0.2f, acc_d5= %0.2f"%(accuracy, d_accuracy[0], d_accuracy[1], d_accuracy[2], d_accuracy[3], d_accuracy[4]))
# Out:
# Accuracy on test data is: 0.71, acc_d1= 0.77, acc_d2= 0.65, acc_d3= 0.64, acc_d4= 0.69, acc_d5= 0.78

# %%
# Exemplo de predição
predict_sample(net_perm);

# %%
plot_layers_output(net_perm)
