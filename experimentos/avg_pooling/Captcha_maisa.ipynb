# %% [markdown]
# <div align="center">
#     <h1> <b>MO416 - IC/Unicamp  </h1>
#     <h2> <b>Projeto Final - Aplicação de Aprendizado de Máquina na Decifração de Captchas </h2>
# </div>
#
# <table>
# <tr><td style="text-align:left">Christian Maekawa</td>  <td>231867</td>  </tr>
# <tr><td style="text-align:left">Giovane de Morais</td>  <td>192683</td>  </tr>
# <tr><td style="text-align:left">Maisa Silva      </td>  <td>181831</td>  </tr>
# <tr><td style="text-align:left">Matteus Vargas   </td>  <td>262885</td>  </tr>
# <tr><td style="text-align:left">Stéfani Fernandes</td>  <td>147939</td>  </tr>
# </table>

# %% [markdown]
# # 1 - Introdução
#
# A leitura de caracteres alfa-numéricos é um tarefa simples para um ser humano, porém por muitos anos esse foi um grande desafio para computadores. Nos últimos anos várias bases de dados de imagens foram utilizados em desafios para o alcance de melhor desempenho na tarefa de leitura de caracteres. Exemplos desses dataset são MNist e SVHN.
#
# Das abordagens aplicadas nesse objetivo estão as Redes Neurais Artificiais com várias camadas ocultas, esta abordagem é conhecida como Deep Learning. Das técnicas de Deep Learning amplamente usadas no processamento de imagens estão as Redes Neurais Convolucionais, que consideram a posição do pixel na imagem.
#
# As Redes Neurais Convolucionais são compostas por duas grandes etapas: extração de features pelas camadas convolucionais e classificação pelas camadas finais (Pooling e Fully-Connected). Onde as camadas de convoluções alteram as representações dos dados e aprende os filtros. E a camada de Pooling reduz a escala para a próxima camada. Sendo assim cada filtro aprendido é um extrator de atributos (features) e cada imagem resultante de um filtro é um mapa de características. As camadas pooling reduzem a quantidade de características por filtro.
#
# O objetivo desse trabalho é aplicar a abordagem de Redes Neurais Convulacionais na leitura de imagens Captchas. O dataset é impactante para o desempenho de aplicações de Aprendizado de Máquina, como nosso trabalho incluí a geração do dataset realizamos um estudo que verifica se a aplicação de critérios como permutação na geração do dataset é capaz de gerar amostras de treino que melhor representam o espaço, e assim é possível obter um

# %%
##########
#
# Imports
#
##########

import os
import cv2
import string
import itertools
import numpy as np
import matplotlib.pyplot as plt

from keras import layers
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix
# Out:
# Using TensorFlow backend.

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
  # !gdown --id "1mf0BxFivzVxDb11IHoYpfZLoNlHSvXvz"
  # !unzip -q dataset_train_random
  # !gdown --id "1aRFpq6hwCkwrsJM1wLXXrL2jxmSJ6zc7"
  # !unzip -q dataset_test
  # !gdown --id "1rXZGjMfMnVhhIGljkv66_Nvw4FXCG0YW"
  # !unzip -q dataset_train_perm
  #!gdown --id "18pvA4cs0EKfd9ajJbqYqJxi4w77bivxh"
  #!unzip -q dataset
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1mf0BxFivzVxDb11IHoYpfZLoNlHSvXvz
# To: /content/dataset_train_random.zip
# 891MB [00:08, 109MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1aRFpq6hwCkwrsJM1wLXXrL2jxmSJ6zc7
# To: /content/dataset_test.zip
# 178MB [00:01, 130MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rXZGjMfMnVhhIGljkv66_Nvw4FXCG0YW
# To: /content/dataset_train_perm.zip
# 891MB [00:20, 43.1MB/s]

# %% [markdown]
# # 2 - Dados
#
# Nesse trabalho geramos imagens Captcha de dimensão 60x160 com 5 caracteres, as imagens foram salvas em arquivos
# .png cujo nome é a palavra contida na imagem. Foram criados 3 datasets:
#
# - treino aleatório: nesse dataset os 5 caracteres que formam a palavra foram escolhidos aleatoriamente
#
# - treino com permutação:nesse dataset 5 caracteres foram escolhidos aleatoriamente e imagens foram geradas com todas as permutações possíveis de tamanho 5. Na sequência foram escolhidos outras 5 caracteres que não haviam sido escolhidos antecipadamente. Esse ciclo foi repetido até atingir o tamanho esperado do dataset:
#
# - teste: foram geradas imagens com 5 caracteres escolhidos aleatoriamente.
#
# Para reduzir o tempo de treino da RN realizamos um pré-processamento, redimensionando as imagens para 30x80 e transformando-as para escala de cinza.

# %%
# Símbolos presentes nos captchas
symbols = string.ascii_uppercase + "0123456789"
num_symbols = len(symbols)

print('Símbolos: ' + symbols)
print('Quantidade de símbolos: ' + str(num_symbols))

# Tamanho das imagens de entrada à RN
img_height = 30
img_width = 80
img_shape = (img_height, img_width, 1)

# Tamanho da palavra no captcha
size_word = 5
# Out:
# Símbolos: ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789
# Quantidade de símbolos: 36

# %% [markdown]
# ## 2.1 - Funções auxiliares para leitura dos dados
# Leitura das imagens e pré-processamento para dados no formato X e Y.

# %%
################################################################################################################
#
# Leitura dos nomes dos arquivos
#
#    Realiza a leitura do nome dos arquivos de captchas recebendo por parametro o diretório onde os arquivos 
#    estão armazenados.
#    Retorna a lista do nome de arquivos.
#
################################################################################################################

def read_name_files(files_dir = 'dataset'):

    files = os.listdir(files_dir)
    
    return files

# %%
################################################################################################################
#
# Leitura das imagens em lote
#
#    Realiza a leitura das imagens captchas recebendo por parametro os símbolos que formam os captchas,
#    a lista dos nomes dos arquivos e o diretório onde os arquivos estão armazenados.
#    Retorna o dataset no formato X e y.
#
################################################################################################################

def read_dataset_batch(symbols, batch_files, captcha_dir = 'dataset'):
    
    n_samples = len(batch_files)
    
    X = np.zeros((n_samples, img_height, img_width, 1))
    y = np.zeros((size_word, n_samples, num_symbols))

    i = 0;
    
    # Leitura de cada arquivo
    for name_file in batch_files:
        
        img = cv2.imread(os.path.join(captcha_dir, name_file), cv2.IMREAD_GRAYSCALE)
        word = name_file[:-4] # retira a extensão .png
        
        # Se a palavra tem 5 caracteres
        if len(word) == size_word:
            
            img = img / 255. # Coloca o valor dos pixels entre 0 e 1
            
            # Faz o reshape da imagem para a metade do tamanho da altura e comprimento, reduzindo ela em 1/4 do tamanho
            img = cv2.resize(img, (img_width, img_height), interpolation=cv2.INTER_AREA)
            img = np.reshape(img, (img.shape[0], img.shape[1], 1))
            
            # Matriz alvo, possui numero da caracteres na palavra por número de caracteres possíveis
            # Na matriz alvo se a posição corresponde a determinado símbolo o valor da célula será 1, 
            # e 0 caso contrário.
            targs = np.zeros((size_word, num_symbols))
            
            for idx_letter, simbol in enumerate(word):
                n_simbol = symbols.find(simbol)
                targs[idx_letter, n_simbol] = 1
                
            X[i] = img
            y[:, i] = targs
            
            i = i +1;
            
            # Controle de progresso
            if(i%10000 == 0):
                print(str(i) + " imagens read");

    return X, y

# %% [markdown]
# ## 2.2 - Datasets
#
# Leitura dos nomes de arquivos dos datasets de treino e leitura do dataset de teste que é único e imutável.

# %%
name_dir_random = 'dataset_train_random';
name_captcha_files_rand = read_name_files(files_dir = 'dataset_train_random')
print('Número de imagens no dataset randômico: ' + str(len(name_captcha_files_rand)))
X_train_random, y_train_random = read_dataset_batch(symbols, name_captcha_files_rand, captcha_dir = name_dir_random)
# Out:
# Número de imagens no dataset randômico: 99910
# 10000 imagens read
# 20000 imagens read
# 30000 imagens read
# 40000 imagens read
# 50000 imagens read
# 60000 imagens read
# 70000 imagens read
# 80000 imagens read
# 90000 imagens read

# %%
name_dir_perm = 'dataset_train_perm';
name_captcha_files_perm = read_name_files(files_dir = 'dataset_train_perm')
print('Número de imagens no dataset permutação: ' + str(len(name_captcha_files_perm)))
X_train_perm, y_train_perm = read_dataset_batch(symbols, name_captcha_files_perm, captcha_dir = name_dir_perm)
# Out:
# Número de imagens no dataset permutação: 100029
# 10000 imagens read
# 20000 imagens read
# 30000 imagens read
# 40000 imagens read
# 50000 imagens read
# 60000 imagens read
# 70000 imagens read
# 80000 imagens read
# 90000 imagens read
# 100000 imagens read

# %%
name_dir_test = 'dataset_test';
name_captcha_files_test = read_name_files(files_dir = name_dir_test)
print('Número de imagens no dataset teste: ' + str(len(name_captcha_files_test)))

X_test, y_test = read_dataset_batch(symbols, name_captcha_files_test, captcha_dir = name_dir_test)
# Out:
# Número de imagens no dataset teste: 19976
# 10000 imagens read

# %%
# Exemplo de imagem
fig, axs = plt.subplots(2,2,figsize=(10,10))
    
j = 0
k = 0
for i in (10, 100, 1000, 10000):        
    img = X_test[i,:,:]
    img.shape = (30,80)        
    axs[j%2][k%2].imshow(img, cmap='gray')
    axs[j%2][k%2].axis('off')
    k = (j - 1 < 1)
    j = j + 1

plt.show()

# %% [markdown]
# # 3 - Modelo
#
# Nesse trabalho implementamos Redes Neurais Convulacionais (CNN). A CNN já tem embutida em  si características que favorecem o aprendizado de imagens. Elas forçam a extração de características de forma localizada, o que explora o fato de ser benéfico a composição de características locais antes de reconhecer objetos em uma imagem.
#
# As CNNs combinam três conceitos: local receptive fields, weight sharing e spatial sub-sampling (pooling).
# Em uma aplicação típica de redes convolucionais a entrada será uma imagem. Cada unidade da camada convolucional receberá como entrada um conjunto de unidades da camada anterior, localizadas na mesma vizinhança. Esse conjunto de unidades que atua como input para a próxima camada é chamado de local receptive fields. Utilizando esse conjunto de variáveis os neurônios podem extrair características básicas da imagem como arestas ou vértices. Em camadas posteriores os neurônios estão indiretamente ligados a todos os pixels. Nessas camadas eles detectarão características mais complexas, que são composições das características mais básicas.
#
# Como a extração de características pode ser útil em toda a imagem, a convolução força as unidades a terem o mesmo conjunto de pesos (weights sharing). As unidades de uma camada são organizadas em planos chamados de feature map. As unidades em um feature map extraem a mesma característica em diversos pontos da imagem.  Uma camada convolucional podem conter diversos feature maps sendo que cada um possuirá um conjunto de pesos compartilhados e reconhecerá um padrão ou característica diferente.
#
# Uma vez que uma unidade tenha reconhecido uma característica sua posição absoluta se torna menos importante. O importante é sua posição relativa em relação aos outro padrões da imagem. Dessa forma, é relevante que a rede neural tenha uma certa resistência à traslados e distorções das entradas. Uma forma de se reduzir a precisão com que as características são inseridas em um feature map é reduzindo sua resolução, o que reduz a sensibilidade em relação a variações de posição. A forma mais comum de se implementar essa invariância é adicionando uma camada de pooling.
#
# Pooling é uma função que reduz ou resume uma  entrada utilizando alguma métrica. Algumas métricas são: pegar dentro de uma vizinhança a entrada máxima (max pooling), fazer a média das entradas (average pooling), obter a norma L2 das entradas ou tirar a média harmônica baseada na distância ao pixel central.

# %% [markdown]
# ## 3.1 - Rede Neural

# %%
################################################################################################################
#
# Modelo
#
#    Geração da rede neural com base no Keras
#
################################################################################################################

def create_net():
    
    img = layers.Input(shape=img_shape) 
    
    # Convolução
    conv1 = layers.Conv2D(16, (3, 3), padding='valid', activation='relu', use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', name='Conv_1')(img)    
    mp1 = layers.AveragePooling2D(padding='same', name='MaxPool_1')(conv1)
    
    # Convolução
    conv2 = layers.Conv2D(32, (3, 3), padding='valid', activation='relu', use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros', name='Conv_2')(mp1)
    mp2 = layers.AveragePooling2D(padding='same', name='MaxPool_2')(conv2)
    
    # Convolução
    conv3 = layers.Conv2D(32, (3, 3), padding='valid', activation='relu', use_bias=True, kernel_initializer='glorot_uniform',bias_initializer='zeros', name='Conv_3')(mp2)
    bn = layers.BatchNormalization()(conv3)
    
    # Camada de saída
    mp3 = layers.MaxPooling2D(padding='same', name='MaxPool_3')(bn) 
    flat = layers.Flatten()(mp3)
    
    outs = []
    for i in range(5):
        dens1 = layers.Dense(64, activation='relu')(flat)
        drop = layers.Dropout(0.5)(dens1)
        res = layers.Dense(num_symbols, name='digit%d' % i, activation='sigmoid')(drop)

        outs.append(res)
    
    model = Model(img, outs)
    model.compile('adam', loss=['categorical_crossentropy', 'categorical_crossentropy',
                                   'categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], metrics=['accuracy'])
    model.summary()
    return model

# %% [markdown]
# ## 3.2 - Funções auxiliares

# %%
################################################################################################################
#
# Variáveis Globais do Treino, tanto parametros de entrada
#
################################################################################################################

n_epoch = 500
size_batch_train = 10000
validation_split=0.2
size_batch_files = 101000

# %%
################################################################################################################
#
# Plot History
#
#    Plota os gráficos das métricas do treino, acurácia e erro do modelo e de cada digito.
#
################################################################################################################


def plot_model_history(history):
    
    # Variáveis globais que armazenam os valores unificados
    global digit_acc, val_digit_acc, loss, val_loss    
    
    # Acurácia modelo
    acc = np.sum([history.history['digit%d_accuracy' % i] for i in range(5)], axis=0)/5;
    val_acc = np.sum([history.history['val_digit%d_accuracy' % i] for i in range(5)], axis=0)/5;

    # Gráficos    
    fig, axs = plt.subplots(2,2,figsize=(20,20))
    
    # Acurácia dos Digitos    
    for i in range(5):
        axs[1][0].plot(history.history['digit' + str(i)+ '_accuracy'], label='digit%d_accuracy' % i)
        axs[1][0].plot(history.history['val_digit%d_accuracy' % i], label='val_digit%d_accuracy' % i)    
    axs[1][0].set_title('Digit Accur')
    axs[1][0].set_ylabel('Accur')
    axs[1][0].set_xlabel('Epoch')
    #axs[1][0].set_xticks(np.arange(1,len(digit_acc[0])+1),len(digit_acc[0])/10)
    axs[1][0].legend()
    
    # Erro dos Digitos    
    for i in range(5):
        axs[1][1].plot(history.history['digit' + str(i) + '_loss'], label='digit%d_loss' % i)
        axs[1][1].plot(history.history['val_digit' + str(i) + '_loss'], label='val_digit%d_loss' % i)
    axs[1][1].set_title('Digit Loss')
    axs[1][1].set_ylabel('Accur')
    axs[1][1].set_xlabel('Epoch')
    #axs[1][1].set_xticks(np.arange(1,len(digit_loss[0])+1),len(digit_loss[0])/10)
    axs[1][1].legend()

    # Acurácia do Modelo
    axs[0][0].plot(range(1,len(acc)+1),acc, label='treino')
    axs[0][0].plot(range(1,len(val_acc)+1),val_acc, label='validation')
    axs[0][0].set_title('Model Accur')
    axs[0][0].set_ylabel('Accur')
    axs[0][0].set_xlabel('Epoch')
    #axs[0][0].set_xticks(np.arange(1,len(acc)+1),len(acc)/10)
    axs[0][0].legend()
    
    # Erro do Modelo
    axs[0][1].plot(range(1,len(history.history['loss'])+1),history.history['loss'], label='treino')
    axs[0][1].plot(range(1,len(history.history['val_loss'])+1),history.history['val_loss'], label='validation')
    axs[0][1].set_title('Model Loss')
    axs[0][1].set_ylabel('Loss')
    axs[0][1].set_xlabel('Epoch')
    #axs[0][1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[0][1].legend()
    
    
    
    plt.show()

# %%
################################################################################################################
#
# Salva Pesos
#
#    Criação de função de callback para salvar os pesos da Rede Neural
#    As informações são concatenas em variáveis globais, por isso não é necessário retorno.
#    O arquivo salvo é nomeado com a época e o erro.
#
################################################################################################################

outputFolder = './output-captcha'
if not os.path.exists(outputFolder):
    os.makedirs(outputFolder)
    
filepath=outputFolder+"/weights-{epoch:02d}-{loss:.2f}.hdf5"
earlystop = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=200)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, \
                             mode='auto', period=100)
callbacks_list = [earlystop,checkpoint]

# %% [markdown]
# # 4 - Treino

# %% [markdown]
# ## 4.1 - Treino de Dataset aleatório

# %%
net_random = create_net()
history_random = net_random.fit(X_train_random, [y_train_random[0], y_train_random[1], y_train_random[2], y_train_random[3], y_train_random[4]], epochs=n_epoch, validation_split=validation_split, batch_size=size_batch_train, callbacks=callbacks_list)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 30, 80, 1)    0
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 28, 78, 16)   160         input_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_1 (AveragePooling2D)    (None, 14, 39, 16)   0           Conv_1[0][0]
# __________________________________________________________________________________________________
# Conv_2 (Conv2D)                 (None, 12, 37, 32)   4640        MaxPool_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_2 (AveragePooling2D)    (None, 6, 19, 32)    0           Conv_2[0][0]
# __________________________________________________________________________________________________
# Conv_3 (Conv2D)                 (None, 4, 17, 32)    9248        MaxPool_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4, 17, 32)    128         Conv_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_3 (MaxPooling2D)        (None, 2, 9, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 576)          0           MaxPool_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           36928       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# digit0 (Dense)                  (None, 36)           2340        dropout_1[0][0]
# __________________________________________________________________________________________________
# digit1 (Dense)                  (None, 36)           2340        dropout_2[0][0]
# __________________________________________________________________________________________________
# digit2 (Dense)                  (None, 36)           2340        dropout_3[0][0]
# __________________________________________________________________________________________________
# digit3 (Dense)                  (None, 36)           2340        dropout_4[0][0]
# __________________________________________________________________________________________________
# digit4 (Dense)                  (None, 36)           2340        dropout_5[0][0]
# ==================================================================================================
# Total params: 210,516
# Trainable params: 210,452
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Train on 79928 samples, validate on 19982 samples
# Epoch 1/500
# 79928/79928 [==============================] - 19s 232us/step - loss: 17.9252 - digit0_loss: 3.5853 - digit1_loss: 3.5859 - digit2_loss: 3.5844 - digit3_loss: 3.5845 - digit4_loss: 3.5849 - digit0_accuracy: 0.0292 - digit1_accuracy: 0.0286 - digit2_accuracy: 0.0297 - digit3_accuracy: 0.0298 - digit4_accuracy: 0.0293 - val_loss: 17.9170 - val_digit0_loss: 3.5835 - val_digit1_loss: 3.5835 - val_digit2_loss: 3.5833 - val_digit3_loss: 3.5833 - val_digit4_loss: 3.5834 - val_digit0_accuracy: 0.0248 - val_digit1_accuracy: 0.0293 - val_digit2_accuracy: 0.0286 - val_digit3_accuracy: 0.0278 - val_digit4_accuracy: 0.0278
# Epoch 2/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 17.8860 - digit0_loss: 3.5793 - digit1_loss: 3.5781 - digit2_loss: 3.5760 - digit3_loss: 3.5757 - digit4_loss: 3.5768 - digit0_accuracy: 0.0336 - digit1_accuracy: 0.0329 - digit2_accuracy: 0.0347 - digit3_accuracy: 0.0361 - digit4_accuracy: 0.0337 - val_loss: 17.9157 - val_digit0_loss: 3.5832 - val_digit1_loss: 3.5833 - val_digit2_loss: 3.5832 - val_digit3_loss: 3.5829 - val_digit4_loss: 3.5831 - val_digit0_accuracy: 0.0286 - val_digit1_accuracy: 0.0289 - val_digit2_accuracy: 0.0292 - val_digit3_accuracy: 0.0331 - val_digit4_accuracy: 0.0289
# Epoch 3/500
# 79928/79928 [==============================] - 3s 43us/step - loss: 17.8248 - digit0_loss: 3.5708 - digit1_loss: 3.5679 - digit2_loss: 3.5629 - digit3_loss: 3.5611 - digit4_loss: 3.5619 - digit0_accuracy: 0.0393 - digit1_accuracy: 0.0387 - digit2_accuracy: 0.0411 - digit3_accuracy: 0.0402 - digit4_accuracy: 0.0432 - val_loss: 17.9155 - val_digit0_loss: 3.5831 - val_digit1_loss: 3.5831 - val_digit2_loss: 3.5839 - val_digit3_loss: 3.5830 - val_digit4_loss: 3.5823 - val_digit0_accuracy: 0.0260 - val_digit1_accuracy: 0.0289 - val_digit2_accuracy: 0.0277 - val_digit3_accuracy: 0.0302 - val_digit4_accuracy: 0.0403
# Epoch 4/500
# 79928/79928 [==============================] - 3s 44us/step - loss: 17.6896 - digit0_loss: 3.5512 - digit1_loss: 3.5428 - digit2_loss: 3.5356 - digit3_loss: 3.5315 - digit4_loss: 3.5284 - digit0_accuracy: 0.0469 - digit1_accuracy: 0.0475 - digit2_accuracy: 0.0465 - digit3_accuracy: 0.0474 - digit4_accuracy: 0.0530 - val_loss: 17.9108 - val_digit0_loss: 3.5824 - val_digit1_loss: 3.5837 - val_digit2_loss: 3.5831 - val_digit3_loss: 3.5826 - val_digit4_loss: 3.5790 - val_digit0_accuracy: 0.0264 - val_digit1_accuracy: 0.0288 - val_digit2_accuracy: 0.0274 - val_digit3_accuracy: 0.0350 - val_digit4_accuracy: 0.0405
# Epoch 5/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 17.4647 - digit0_loss: 3.5157 - digit1_loss: 3.5079 - digit2_loss: 3.4896 - digit3_loss: 3.4882 - digit4_loss: 3.4631 - digit0_accuracy: 0.0553 - digit1_accuracy: 0.0552 - digit2_accuracy: 0.0562 - digit3_accuracy: 0.0572 - digit4_accuracy: 0.0693 - val_loss: 17.8881 - val_digit0_loss: 3.5792 - val_digit1_loss: 3.5824 - val_digit2_loss: 3.5762 - val_digit3_loss: 3.5756 - val_digit4_loss: 3.5746 - val_digit0_accuracy: 0.0273 - val_digit1_accuracy: 0.0334 - val_digit2_accuracy: 0.0369 - val_digit3_accuracy: 0.0272 - val_digit4_accuracy: 0.0268
# Epoch 6/500
# 79928/79928 [==============================] - 3s 44us/step - loss: 17.1670 - digit0_loss: 3.4592 - digit1_loss: 3.4616 - digit2_loss: 3.4351 - digit3_loss: 3.4350 - digit4_loss: 3.3760 - digit0_accuracy: 0.0654 - digit1_accuracy: 0.0633 - digit2_accuracy: 0.0679 - digit3_accuracy: 0.0654 - digit4_accuracy: 0.0813 - val_loss: 17.8490 - val_digit0_loss: 3.5695 - val_digit1_loss: 3.5714 - val_digit2_loss: 3.5713 - val_digit3_loss: 3.5652 - val_digit4_loss: 3.5715 - val_digit0_accuracy: 0.0285 - val_digit1_accuracy: 0.0288 - val_digit2_accuracy: 0.0351 - val_digit3_accuracy: 0.0295 - val_digit4_accuracy: 0.0284
# Epoch 7/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 16.8379 - digit0_loss: 3.3927 - digit1_loss: 3.4088 - digit2_loss: 3.3796 - digit3_loss: 3.3793 - digit4_loss: 3.2774 - digit0_accuracy: 0.0762 - digit1_accuracy: 0.0733 - digit2_accuracy: 0.0781 - digit3_accuracy: 0.0745 - digit4_accuracy: 0.0946 - val_loss: 17.7916 - val_digit0_loss: 3.5573 - val_digit1_loss: 3.5581 - val_digit2_loss: 3.5608 - val_digit3_loss: 3.5514 - val_digit4_loss: 3.5640 - val_digit0_accuracy: 0.0292 - val_digit1_accuracy: 0.0343 - val_digit2_accuracy: 0.0420 - val_digit3_accuracy: 0.0323 - val_digit4_accuracy: 0.0284
# Epoch 8/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 16.5122 - digit0_loss: 3.3196 - digit1_loss: 3.3576 - digit2_loss: 3.3308 - digit3_loss: 3.3246 - digit4_loss: 3.1795 - digit0_accuracy: 0.0857 - digit1_accuracy: 0.0806 - digit2_accuracy: 0.0854 - digit3_accuracy: 0.0835 - digit4_accuracy: 0.1110 - val_loss: 17.7606 - val_digit0_loss: 3.5391 - val_digit1_loss: 3.5494 - val_digit2_loss: 3.5596 - val_digit3_loss: 3.5464 - val_digit4_loss: 3.5661 - val_digit0_accuracy: 0.0382 - val_digit1_accuracy: 0.0278 - val_digit2_accuracy: 0.0319 - val_digit3_accuracy: 0.0368 - val_digit4_accuracy: 0.0348
# Epoch 9/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 16.1711 - digit0_loss: 3.2379 - digit1_loss: 3.3048 - digit2_loss: 3.2786 - digit3_loss: 3.2709 - digit4_loss: 3.0788 - digit0_accuracy: 0.0989 - digit1_accuracy: 0.0902 - digit2_accuracy: 0.0958 - digit3_accuracy: 0.0934 - digit4_accuracy: 0.1288 - val_loss: 17.7179 - val_digit0_loss: 3.5219 - val_digit1_loss: 3.5358 - val_digit2_loss: 3.5576 - val_digit3_loss: 3.5337 - val_digit4_loss: 3.5688 - val_digit0_accuracy: 0.0600 - val_digit1_accuracy: 0.0318 - val_digit2_accuracy: 0.0403 - val_digit3_accuracy: 0.0294 - val_digit4_accuracy: 0.0267
# Epoch 10/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 15.8289 - digit0_loss: 3.1537 - digit1_loss: 3.2537 - digit2_loss: 3.2268 - digit3_loss: 3.2162 - digit4_loss: 2.9784 - digit0_accuracy: 0.1125 - digit1_accuracy: 0.0996 - digit2_accuracy: 0.1042 - digit3_accuracy: 0.1014 - digit4_accuracy: 0.1438 - val_loss: 17.6599 - val_digit0_loss: 3.5037 - val_digit1_loss: 3.5263 - val_digit2_loss: 3.5468 - val_digit3_loss: 3.5240 - val_digit4_loss: 3.5591 - val_digit0_accuracy: 0.0479 - val_digit1_accuracy: 0.0329 - val_digit2_accuracy: 0.0430 - val_digit3_accuracy: 0.0331 - val_digit4_accuracy: 0.0382
# Epoch 11/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 15.4815 - digit0_loss: 3.0718 - digit1_loss: 3.1987 - digit2_loss: 3.1770 - digit3_loss: 3.1589 - digit4_loss: 2.8749 - digit0_accuracy: 0.1273 - digit1_accuracy: 0.1104 - digit2_accuracy: 0.1176 - digit3_accuracy: 0.1127 - digit4_accuracy: 0.1653 - val_loss: 17.6132 - val_digit0_loss: 3.4909 - val_digit1_loss: 3.5109 - val_digit2_loss: 3.5396 - val_digit3_loss: 3.5109 - val_digit4_loss: 3.5609 - val_digit0_accuracy: 0.0436 - val_digit1_accuracy: 0.0385 - val_digit2_accuracy: 0.0311 - val_digit3_accuracy: 0.0452 - val_digit4_accuracy: 0.0310
# Epoch 12/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 15.1297 - digit0_loss: 2.9869 - digit1_loss: 3.1424 - digit2_loss: 3.1231 - digit3_loss: 3.0977 - digit4_loss: 2.7795 - digit0_accuracy: 0.1423 - digit1_accuracy: 0.1215 - digit2_accuracy: 0.1279 - digit3_accuracy: 0.1237 - digit4_accuracy: 0.1816 - val_loss: 17.5772 - val_digit0_loss: 3.4911 - val_digit1_loss: 3.5095 - val_digit2_loss: 3.5388 - val_digit3_loss: 3.5013 - val_digit4_loss: 3.5364 - val_digit0_accuracy: 0.0297 - val_digit1_accuracy: 0.0398 - val_digit2_accuracy: 0.0454 - val_digit3_accuracy: 0.0534 - val_digit4_accuracy: 0.0419
# Epoch 13/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 14.7742 - digit0_loss: 2.9035 - digit1_loss: 3.0883 - digit2_loss: 3.0671 - digit3_loss: 3.0387 - digit4_loss: 2.6765 - digit0_accuracy: 0.1559 - digit1_accuracy: 0.1338 - digit2_accuracy: 0.1418 - digit3_accuracy: 0.1395 - digit4_accuracy: 0.2052 - val_loss: 17.5355 - val_digit0_loss: 3.4644 - val_digit1_loss: 3.4996 - val_digit2_loss: 3.5416 - val_digit3_loss: 3.4935 - val_digit4_loss: 3.5364 - val_digit0_accuracy: 0.0340 - val_digit1_accuracy: 0.0486 - val_digit2_accuracy: 0.0496 - val_digit3_accuracy: 0.0544 - val_digit4_accuracy: 0.0358
# Epoch 14/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 14.4034 - digit0_loss: 2.8157 - digit1_loss: 3.0304 - digit2_loss: 3.0141 - digit3_loss: 2.9713 - digit4_loss: 2.5717 - digit0_accuracy: 0.1759 - digit1_accuracy: 0.1484 - digit2_accuracy: 0.1546 - digit3_accuracy: 0.1490 - digit4_accuracy: 0.2295 - val_loss: 17.4211 - val_digit0_loss: 3.4485 - val_digit1_loss: 3.4923 - val_digit2_loss: 3.5200 - val_digit3_loss: 3.4731 - val_digit4_loss: 3.4872 - val_digit0_accuracy: 0.0645 - val_digit1_accuracy: 0.0611 - val_digit2_accuracy: 0.0620 - val_digit3_accuracy: 0.0460 - val_digit4_accuracy: 0.0346
# Epoch 15/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 14.0124 - digit0_loss: 2.7207 - digit1_loss: 2.9689 - digit2_loss: 2.9512 - digit3_loss: 2.9006 - digit4_loss: 2.4709 - digit0_accuracy: 0.1967 - digit1_accuracy: 0.1620 - digit2_accuracy: 0.1677 - digit3_accuracy: 0.1644 - digit4_accuracy: 0.2512 - val_loss: 17.4847 - val_digit0_loss: 3.4774 - val_digit1_loss: 3.5179 - val_digit2_loss: 3.5252 - val_digit3_loss: 3.4858 - val_digit4_loss: 3.4784 - val_digit0_accuracy: 0.0597 - val_digit1_accuracy: 0.0589 - val_digit2_accuracy: 0.0622 - val_digit3_accuracy: 0.0367 - val_digit4_accuracy: 0.0559
# Epoch 16/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 13.6251 - digit0_loss: 2.6295 - digit1_loss: 2.9075 - digit2_loss: 2.8979 - digit3_loss: 2.8334 - digit4_loss: 2.3566 - digit0_accuracy: 0.2156 - digit1_accuracy: 0.1757 - digit2_accuracy: 0.1832 - digit3_accuracy: 0.1793 - digit4_accuracy: 0.2758 - val_loss: 17.4360 - val_digit0_loss: 3.4607 - val_digit1_loss: 3.4906 - val_digit2_loss: 3.5131 - val_digit3_loss: 3.4746 - val_digit4_loss: 3.4970 - val_digit0_accuracy: 0.0663 - val_digit1_accuracy: 0.0542 - val_digit2_accuracy: 0.0751 - val_digit3_accuracy: 0.0357 - val_digit4_accuracy: 0.0603
# Epoch 17/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 13.2550 - digit0_loss: 2.5371 - digit1_loss: 2.8460 - digit2_loss: 2.8437 - digit3_loss: 2.7724 - digit4_loss: 2.2556 - digit0_accuracy: 0.2332 - digit1_accuracy: 0.1921 - digit2_accuracy: 0.1956 - digit3_accuracy: 0.1953 - digit4_accuracy: 0.3028 - val_loss: 17.4074 - val_digit0_loss: 3.4436 - val_digit1_loss: 3.4938 - val_digit2_loss: 3.5113 - val_digit3_loss: 3.4605 - val_digit4_loss: 3.4981 - val_digit0_accuracy: 0.0647 - val_digit1_accuracy: 0.0429 - val_digit2_accuracy: 0.0653 - val_digit3_accuracy: 0.0363 - val_digit4_accuracy: 0.0720
# Epoch 18/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 12.8752 - digit0_loss: 2.4475 - digit1_loss: 2.7825 - digit2_loss: 2.7821 - digit3_loss: 2.7039 - digit4_loss: 2.1589 - digit0_accuracy: 0.2579 - digit1_accuracy: 0.2061 - digit2_accuracy: 0.2121 - digit3_accuracy: 0.2101 - digit4_accuracy: 0.3262 - val_loss: 17.3795 - val_digit0_loss: 3.4253 - val_digit1_loss: 3.5000 - val_digit2_loss: 3.5085 - val_digit3_loss: 3.4588 - val_digit4_loss: 3.4870 - val_digit0_accuracy: 0.0566 - val_digit1_accuracy: 0.0456 - val_digit2_accuracy: 0.0706 - val_digit3_accuracy: 0.0411 - val_digit4_accuracy: 0.0805
# Epoch 19/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 12.5406 - digit0_loss: 2.3697 - digit1_loss: 2.7283 - digit2_loss: 2.7287 - digit3_loss: 2.6407 - digit4_loss: 2.0730 - digit0_accuracy: 0.2750 - digit1_accuracy: 0.2181 - digit2_accuracy: 0.2220 - digit3_accuracy: 0.2259 - digit4_accuracy: 0.3511 - val_loss: 17.5287 - val_digit0_loss: 3.4521 - val_digit1_loss: 3.5175 - val_digit2_loss: 3.5491 - val_digit3_loss: 3.4748 - val_digit4_loss: 3.5352 - val_digit0_accuracy: 0.0379 - val_digit1_accuracy: 0.0358 - val_digit2_accuracy: 0.0588 - val_digit3_accuracy: 0.0308 - val_digit4_accuracy: 0.0894
# Epoch 20/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 12.2031 - digit0_loss: 2.2866 - digit1_loss: 2.6687 - digit2_loss: 2.6771 - digit3_loss: 2.5801 - digit4_loss: 1.9905 - digit0_accuracy: 0.2956 - digit1_accuracy: 0.2332 - digit2_accuracy: 0.2364 - digit3_accuracy: 0.2425 - digit4_accuracy: 0.3742 - val_loss: 17.3667 - val_digit0_loss: 3.4473 - val_digit1_loss: 3.4853 - val_digit2_loss: 3.5053 - val_digit3_loss: 3.4509 - val_digit4_loss: 3.4779 - val_digit0_accuracy: 0.0468 - val_digit1_accuracy: 0.0409 - val_digit2_accuracy: 0.0682 - val_digit3_accuracy: 0.0346 - val_digit4_accuracy: 0.1029
# Epoch 21/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 11.8686 - digit0_loss: 2.2026 - digit1_loss: 2.6161 - digit2_loss: 2.6331 - digit3_loss: 2.5201 - digit4_loss: 1.8965 - digit0_accuracy: 0.3204 - digit1_accuracy: 0.2465 - digit2_accuracy: 0.2475 - digit3_accuracy: 0.2600 - digit4_accuracy: 0.3987 - val_loss: 17.3978 - val_digit0_loss: 3.4595 - val_digit1_loss: 3.5068 - val_digit2_loss: 3.5050 - val_digit3_loss: 3.4501 - val_digit4_loss: 3.4764 - val_digit0_accuracy: 0.0389 - val_digit1_accuracy: 0.0353 - val_digit2_accuracy: 0.0585 - val_digit3_accuracy: 0.0302 - val_digit4_accuracy: 0.0920
# Epoch 22/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 11.5685 - digit0_loss: 2.1284 - digit1_loss: 2.5643 - digit2_loss: 2.5898 - digit3_loss: 2.4642 - digit4_loss: 1.8217 - digit0_accuracy: 0.3409 - digit1_accuracy: 0.2637 - digit2_accuracy: 0.2620 - digit3_accuracy: 0.2738 - digit4_accuracy: 0.4215 - val_loss: 17.4304 - val_digit0_loss: 3.4989 - val_digit1_loss: 3.5153 - val_digit2_loss: 3.5039 - val_digit3_loss: 3.4491 - val_digit4_loss: 3.4633 - val_digit0_accuracy: 0.0429 - val_digit1_accuracy: 0.0598 - val_digit2_accuracy: 0.0713 - val_digit3_accuracy: 0.0490 - val_digit4_accuracy: 0.0960
# Epoch 23/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 11.2979 - digit0_loss: 2.0610 - digit1_loss: 2.5163 - digit2_loss: 2.5424 - digit3_loss: 2.4133 - digit4_loss: 1.7648 - digit0_accuracy: 0.3604 - digit1_accuracy: 0.2751 - digit2_accuracy: 0.2722 - digit3_accuracy: 0.2899 - digit4_accuracy: 0.4389 - val_loss: 16.9896 - val_digit0_loss: 3.3951 - val_digit1_loss: 3.4149 - val_digit2_loss: 3.4410 - val_digit3_loss: 3.3800 - val_digit4_loss: 3.3586 - val_digit0_accuracy: 0.0492 - val_digit1_accuracy: 0.0643 - val_digit2_accuracy: 0.0733 - val_digit3_accuracy: 0.0408 - val_digit4_accuracy: 0.0876
# Epoch 24/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 11.0728 - digit0_loss: 2.0004 - digit1_loss: 2.4760 - digit2_loss: 2.5092 - digit3_loss: 2.3698 - digit4_loss: 1.7173 - digit0_accuracy: 0.3786 - digit1_accuracy: 0.2867 - digit2_accuracy: 0.2852 - digit3_accuracy: 0.3039 - digit4_accuracy: 0.4554 - val_loss: 16.5871 - val_digit0_loss: 3.2285 - val_digit1_loss: 3.3750 - val_digit2_loss: 3.3813 - val_digit3_loss: 3.3208 - val_digit4_loss: 3.2815 - val_digit0_accuracy: 0.0932 - val_digit1_accuracy: 0.0825 - val_digit2_accuracy: 0.0846 - val_digit3_accuracy: 0.1050 - val_digit4_accuracy: 0.1171
# Epoch 25/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 10.8345 - digit0_loss: 1.9424 - digit1_loss: 2.4380 - digit2_loss: 2.4753 - digit3_loss: 2.3234 - digit4_loss: 1.6552 - digit0_accuracy: 0.3964 - digit1_accuracy: 0.2988 - digit2_accuracy: 0.2911 - digit3_accuracy: 0.3150 - digit4_accuracy: 0.4725 - val_loss: 16.4008 - val_digit0_loss: 3.1693 - val_digit1_loss: 3.3297 - val_digit2_loss: 3.3857 - val_digit3_loss: 3.2533 - val_digit4_loss: 3.2628 - val_digit0_accuracy: 0.0850 - val_digit1_accuracy: 0.0855 - val_digit2_accuracy: 0.0916 - val_digit3_accuracy: 0.1056 - val_digit4_accuracy: 0.1160
# Epoch 26/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 10.5688 - digit0_loss: 1.8721 - digit1_loss: 2.3917 - digit2_loss: 2.4347 - digit3_loss: 2.2776 - digit4_loss: 1.5926 - digit0_accuracy: 0.4172 - digit1_accuracy: 0.3135 - digit2_accuracy: 0.3066 - digit3_accuracy: 0.3318 - digit4_accuracy: 0.4921 - val_loss: 16.6142 - val_digit0_loss: 3.2164 - val_digit1_loss: 3.3958 - val_digit2_loss: 3.4124 - val_digit3_loss: 3.2727 - val_digit4_loss: 3.3170 - val_digit0_accuracy: 0.0691 - val_digit1_accuracy: 0.0775 - val_digit2_accuracy: 0.0890 - val_digit3_accuracy: 0.0886 - val_digit4_accuracy: 0.1045
# Epoch 27/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 10.3325 - digit0_loss: 1.8142 - digit1_loss: 2.3541 - digit2_loss: 2.3980 - digit3_loss: 2.2334 - digit4_loss: 1.5326 - digit0_accuracy: 0.4337 - digit1_accuracy: 0.3221 - digit2_accuracy: 0.3191 - digit3_accuracy: 0.3451 - digit4_accuracy: 0.5097 - val_loss: 16.2997 - val_digit0_loss: 3.0830 - val_digit1_loss: 3.3759 - val_digit2_loss: 3.3589 - val_digit3_loss: 3.2269 - val_digit4_loss: 3.2550 - val_digit0_accuracy: 0.1057 - val_digit1_accuracy: 0.0941 - val_digit2_accuracy: 0.0838 - val_digit3_accuracy: 0.1082 - val_digit4_accuracy: 0.1036
# Epoch 28/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 10.1380 - digit0_loss: 1.7702 - digit1_loss: 2.3142 - digit2_loss: 2.3645 - digit3_loss: 2.1988 - digit4_loss: 1.4903 - digit0_accuracy: 0.4509 - digit1_accuracy: 0.3350 - digit2_accuracy: 0.3279 - digit3_accuracy: 0.3557 - digit4_accuracy: 0.5243 - val_loss: 16.1517 - val_digit0_loss: 3.0617 - val_digit1_loss: 3.3414 - val_digit2_loss: 3.3126 - val_digit3_loss: 3.2106 - val_digit4_loss: 3.2254 - val_digit0_accuracy: 0.1064 - val_digit1_accuracy: 0.0958 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.1044 - val_digit4_accuracy: 0.1045
# Epoch 29/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.9301 - digit0_loss: 1.7169 - digit1_loss: 2.2799 - digit2_loss: 2.3328 - digit3_loss: 2.1571 - digit4_loss: 1.4433 - digit0_accuracy: 0.4689 - digit1_accuracy: 0.3473 - digit2_accuracy: 0.3378 - digit3_accuracy: 0.3698 - digit4_accuracy: 0.5403 - val_loss: 15.9618 - val_digit0_loss: 3.0185 - val_digit1_loss: 3.2979 - val_digit2_loss: 3.2818 - val_digit3_loss: 3.1810 - val_digit4_loss: 3.1826 - val_digit0_accuracy: 0.1163 - val_digit1_accuracy: 0.0919 - val_digit2_accuracy: 0.1094 - val_digit3_accuracy: 0.0993 - val_digit4_accuracy: 0.1027
# Epoch 30/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.7453 - digit0_loss: 1.6719 - digit1_loss: 2.2484 - digit2_loss: 2.3012 - digit3_loss: 2.1208 - digit4_loss: 1.4029 - digit0_accuracy: 0.4822 - digit1_accuracy: 0.3583 - digit2_accuracy: 0.3457 - digit3_accuracy: 0.3770 - digit4_accuracy: 0.5546 - val_loss: 15.8304 - val_digit0_loss: 3.0007 - val_digit1_loss: 3.2837 - val_digit2_loss: 3.2395 - val_digit3_loss: 3.1476 - val_digit4_loss: 3.1589 - val_digit0_accuracy: 0.1228 - val_digit1_accuracy: 0.0987 - val_digit2_accuracy: 0.1187 - val_digit3_accuracy: 0.1042 - val_digit4_accuracy: 0.0991
# Epoch 31/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.5770 - digit0_loss: 1.6301 - digit1_loss: 2.2163 - digit2_loss: 2.2722 - digit3_loss: 2.0911 - digit4_loss: 1.3673 - digit0_accuracy: 0.4987 - digit1_accuracy: 0.3678 - digit2_accuracy: 0.3595 - digit3_accuracy: 0.3895 - digit4_accuracy: 0.5644 - val_loss: 15.6588 - val_digit0_loss: 2.9513 - val_digit1_loss: 3.2733 - val_digit2_loss: 3.2108 - val_digit3_loss: 3.1194 - val_digit4_loss: 3.1040 - val_digit0_accuracy: 0.1342 - val_digit1_accuracy: 0.1047 - val_digit2_accuracy: 0.1244 - val_digit3_accuracy: 0.1208 - val_digit4_accuracy: 0.1146
# Epoch 32/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.4286 - digit0_loss: 1.5957 - digit1_loss: 2.1819 - digit2_loss: 2.2483 - digit3_loss: 2.0648 - digit4_loss: 1.3379 - digit0_accuracy: 0.5063 - digit1_accuracy: 0.3761 - digit2_accuracy: 0.3636 - digit3_accuracy: 0.3994 - digit4_accuracy: 0.5747 - val_loss: 15.0218 - val_digit0_loss: 2.8170 - val_digit1_loss: 3.1314 - val_digit2_loss: 3.1168 - val_digit3_loss: 3.0162 - val_digit4_loss: 2.9404 - val_digit0_accuracy: 0.1765 - val_digit1_accuracy: 0.1274 - val_digit2_accuracy: 0.1417 - val_digit3_accuracy: 0.1425 - val_digit4_accuracy: 0.1392
# Epoch 33/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.2710 - digit0_loss: 1.5615 - digit1_loss: 2.1549 - digit2_loss: 2.2250 - digit3_loss: 2.0258 - digit4_loss: 1.3037 - digit0_accuracy: 0.5170 - digit1_accuracy: 0.3837 - digit2_accuracy: 0.3714 - digit3_accuracy: 0.4088 - digit4_accuracy: 0.5842 - val_loss: 15.2000 - val_digit0_loss: 2.8324 - val_digit1_loss: 3.1709 - val_digit2_loss: 3.1407 - val_digit3_loss: 3.0387 - val_digit4_loss: 3.0172 - val_digit0_accuracy: 0.1709 - val_digit1_accuracy: 0.1205 - val_digit2_accuracy: 0.1370 - val_digit3_accuracy: 0.1393 - val_digit4_accuracy: 0.1247
# Epoch 34/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.1636 - digit0_loss: 1.5328 - digit1_loss: 2.1337 - digit2_loss: 2.2057 - digit3_loss: 2.0079 - digit4_loss: 1.2834 - digit0_accuracy: 0.5275 - digit1_accuracy: 0.3925 - digit2_accuracy: 0.3780 - digit3_accuracy: 0.4152 - digit4_accuracy: 0.5934 - val_loss: 15.1725 - val_digit0_loss: 2.8472 - val_digit1_loss: 3.1177 - val_digit2_loss: 3.1263 - val_digit3_loss: 3.0487 - val_digit4_loss: 3.0326 - val_digit0_accuracy: 0.1613 - val_digit1_accuracy: 0.1320 - val_digit2_accuracy: 0.1555 - val_digit3_accuracy: 0.1260 - val_digit4_accuracy: 0.1033
# Epoch 35/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 9.0394 - digit0_loss: 1.5070 - digit1_loss: 2.1088 - digit2_loss: 2.1864 - digit3_loss: 1.9813 - digit4_loss: 1.2559 - digit0_accuracy: 0.5351 - digit1_accuracy: 0.3982 - digit2_accuracy: 0.3853 - digit3_accuracy: 0.4243 - digit4_accuracy: 0.6023 - val_loss: 13.8177 - val_digit0_loss: 2.5619 - val_digit1_loss: 2.9384 - val_digit2_loss: 2.9122 - val_digit3_loss: 2.8267 - val_digit4_loss: 2.5787 - val_digit0_accuracy: 0.2704 - val_digit1_accuracy: 0.1720 - val_digit2_accuracy: 0.2051 - val_digit3_accuracy: 0.2099 - val_digit4_accuracy: 0.2363
# Epoch 36/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.8944 - digit0_loss: 1.4707 - digit1_loss: 2.0819 - digit2_loss: 2.1613 - digit3_loss: 1.9580 - digit4_loss: 1.2224 - digit0_accuracy: 0.5462 - digit1_accuracy: 0.4048 - digit2_accuracy: 0.3915 - digit3_accuracy: 0.4313 - digit4_accuracy: 0.6117 - val_loss: 14.5234 - val_digit0_loss: 2.6816 - val_digit1_loss: 3.0639 - val_digit2_loss: 3.0437 - val_digit3_loss: 2.9528 - val_digit4_loss: 2.7814 - val_digit0_accuracy: 0.2281 - val_digit1_accuracy: 0.1576 - val_digit2_accuracy: 0.1731 - val_digit3_accuracy: 0.1658 - val_digit4_accuracy: 0.1791
# Epoch 37/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.7613 - digit0_loss: 1.4457 - digit1_loss: 2.0564 - digit2_loss: 2.1373 - digit3_loss: 1.9307 - digit4_loss: 1.1912 - digit0_accuracy: 0.5514 - digit1_accuracy: 0.4169 - digit2_accuracy: 0.3975 - digit3_accuracy: 0.4407 - digit4_accuracy: 0.6191 - val_loss: 14.2402 - val_digit0_loss: 2.6221 - val_digit1_loss: 3.0196 - val_digit2_loss: 3.0151 - val_digit3_loss: 2.9008 - val_digit4_loss: 2.6826 - val_digit0_accuracy: 0.2540 - val_digit1_accuracy: 0.1597 - val_digit2_accuracy: 0.1658 - val_digit3_accuracy: 0.1708 - val_digit4_accuracy: 0.2029
# Epoch 38/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.6420 - digit0_loss: 1.4165 - digit1_loss: 2.0322 - digit2_loss: 2.1167 - digit3_loss: 1.9054 - digit4_loss: 1.1711 - digit0_accuracy: 0.5616 - digit1_accuracy: 0.4213 - digit2_accuracy: 0.4024 - digit3_accuracy: 0.4461 - digit4_accuracy: 0.6257 - val_loss: 14.5590 - val_digit0_loss: 2.6438 - val_digit1_loss: 3.0987 - val_digit2_loss: 3.0474 - val_digit3_loss: 2.9698 - val_digit4_loss: 2.7993 - val_digit0_accuracy: 0.2457 - val_digit1_accuracy: 0.1584 - val_digit2_accuracy: 0.1641 - val_digit3_accuracy: 0.1639 - val_digit4_accuracy: 0.1885
# Epoch 39/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.5347 - digit0_loss: 1.3890 - digit1_loss: 2.0102 - digit2_loss: 2.1007 - digit3_loss: 1.8863 - digit4_loss: 1.1485 - digit0_accuracy: 0.5705 - digit1_accuracy: 0.4247 - digit2_accuracy: 0.4074 - digit3_accuracy: 0.4536 - digit4_accuracy: 0.6330 - val_loss: 14.6512 - val_digit0_loss: 2.6295 - val_digit1_loss: 3.1072 - val_digit2_loss: 3.1066 - val_digit3_loss: 2.9830 - val_digit4_loss: 2.8249 - val_digit0_accuracy: 0.2600 - val_digit1_accuracy: 0.1530 - val_digit2_accuracy: 0.1443 - val_digit3_accuracy: 0.1540 - val_digit4_accuracy: 0.1888
# Epoch 40/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.4283 - digit0_loss: 1.3666 - digit1_loss: 1.9796 - digit2_loss: 2.0863 - digit3_loss: 1.8678 - digit4_loss: 1.1280 - digit0_accuracy: 0.5777 - digit1_accuracy: 0.4343 - digit2_accuracy: 0.4137 - digit3_accuracy: 0.4573 - digit4_accuracy: 0.6427 - val_loss: 15.8166 - val_digit0_loss: 2.8862 - val_digit1_loss: 3.2612 - val_digit2_loss: 3.2703 - val_digit3_loss: 3.1935 - val_digit4_loss: 3.2054 - val_digit0_accuracy: 0.2129 - val_digit1_accuracy: 0.1344 - val_digit2_accuracy: 0.1314 - val_digit3_accuracy: 0.1315 - val_digit4_accuracy: 0.1279
# Epoch 41/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.3209 - digit0_loss: 1.3405 - digit1_loss: 1.9617 - digit2_loss: 2.0613 - digit3_loss: 1.8492 - digit4_loss: 1.1083 - digit0_accuracy: 0.5859 - digit1_accuracy: 0.4381 - digit2_accuracy: 0.4181 - digit3_accuracy: 0.4646 - digit4_accuracy: 0.6465 - val_loss: 16.2752 - val_digit0_loss: 2.9308 - val_digit1_loss: 3.3749 - val_digit2_loss: 3.3545 - val_digit3_loss: 3.3287 - val_digit4_loss: 3.2863 - val_digit0_accuracy: 0.2038 - val_digit1_accuracy: 0.1198 - val_digit2_accuracy: 0.1205 - val_digit3_accuracy: 0.1169 - val_digit4_accuracy: 0.1351
# Epoch 42/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.2397 - digit0_loss: 1.3277 - digit1_loss: 1.9433 - digit2_loss: 2.0465 - digit3_loss: 1.8282 - digit4_loss: 1.0939 - digit0_accuracy: 0.5891 - digit1_accuracy: 0.4452 - digit2_accuracy: 0.4232 - digit3_accuracy: 0.4694 - digit4_accuracy: 0.6520 - val_loss: 18.2623 - val_digit0_loss: 3.1979 - val_digit1_loss: 3.8309 - val_digit2_loss: 3.7007 - val_digit3_loss: 3.7341 - val_digit4_loss: 3.7987 - val_digit0_accuracy: 0.1803 - val_digit1_accuracy: 0.1046 - val_digit2_accuracy: 0.0976 - val_digit3_accuracy: 0.1005 - val_digit4_accuracy: 0.1178
# Epoch 43/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.1470 - digit0_loss: 1.3052 - digit1_loss: 1.9198 - digit2_loss: 2.0345 - digit3_loss: 1.8106 - digit4_loss: 1.0770 - digit0_accuracy: 0.5969 - digit1_accuracy: 0.4532 - digit2_accuracy: 0.4299 - digit3_accuracy: 0.4740 - digit4_accuracy: 0.6559 - val_loss: 20.5528 - val_digit0_loss: 3.5995 - val_digit1_loss: 4.2550 - val_digit2_loss: 4.0491 - val_digit3_loss: 4.1864 - val_digit4_loss: 4.4629 - val_digit0_accuracy: 0.1502 - val_digit1_accuracy: 0.0940 - val_digit2_accuracy: 0.0780 - val_digit3_accuracy: 0.0884 - val_digit4_accuracy: 0.0952
# Epoch 44/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.0892 - digit0_loss: 1.2908 - digit1_loss: 1.9123 - digit2_loss: 2.0189 - digit3_loss: 1.7977 - digit4_loss: 1.0694 - digit0_accuracy: 0.6015 - digit1_accuracy: 0.4510 - digit2_accuracy: 0.4352 - digit3_accuracy: 0.4773 - digit4_accuracy: 0.6601 - val_loss: 14.9080 - val_digit0_loss: 2.5141 - val_digit1_loss: 3.2269 - val_digit2_loss: 3.1897 - val_digit3_loss: 3.0565 - val_digit4_loss: 2.9208 - val_digit0_accuracy: 0.2863 - val_digit1_accuracy: 0.1548 - val_digit2_accuracy: 0.1403 - val_digit3_accuracy: 0.1694 - val_digit4_accuracy: 0.2007
# Epoch 45/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 8.0091 - digit0_loss: 1.2744 - digit1_loss: 1.8933 - digit2_loss: 2.0020 - digit3_loss: 1.7852 - digit4_loss: 1.0541 - digit0_accuracy: 0.6047 - digit1_accuracy: 0.4567 - digit2_accuracy: 0.4330 - digit3_accuracy: 0.4813 - digit4_accuracy: 0.6651 - val_loss: 16.3038 - val_digit0_loss: 2.7156 - val_digit1_loss: 3.5318 - val_digit2_loss: 3.4066 - val_digit3_loss: 3.3096 - val_digit4_loss: 3.3401 - val_digit0_accuracy: 0.2448 - val_digit1_accuracy: 0.1245 - val_digit2_accuracy: 0.1159 - val_digit3_accuracy: 0.1498 - val_digit4_accuracy: 0.1658
# Epoch 46/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.9213 - digit0_loss: 1.2538 - digit1_loss: 1.8793 - digit2_loss: 1.9886 - digit3_loss: 1.7672 - digit4_loss: 1.0325 - digit0_accuracy: 0.6111 - digit1_accuracy: 0.4600 - digit2_accuracy: 0.4400 - digit3_accuracy: 0.4849 - digit4_accuracy: 0.6682 - val_loss: 10.3393 - val_digit0_loss: 1.7680 - val_digit1_loss: 2.2677 - val_digit2_loss: 2.4240 - val_digit3_loss: 2.1395 - val_digit4_loss: 1.7400 - val_digit0_accuracy: 0.5557 - val_digit1_accuracy: 0.4325 - val_digit2_accuracy: 0.3575 - val_digit3_accuracy: 0.4533 - val_digit4_accuracy: 0.5246
# Epoch 47/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.8364 - digit0_loss: 1.2349 - digit1_loss: 1.8630 - digit2_loss: 1.9747 - digit3_loss: 1.7493 - digit4_loss: 1.0144 - digit0_accuracy: 0.6181 - digit1_accuracy: 0.4658 - digit2_accuracy: 0.4440 - digit3_accuracy: 0.4903 - digit4_accuracy: 0.6757 - val_loss: 9.9017 - val_digit0_loss: 1.6689 - val_digit1_loss: 2.2096 - val_digit2_loss: 2.3410 - val_digit3_loss: 2.1107 - val_digit4_loss: 1.5714 - val_digit0_accuracy: 0.5952 - val_digit1_accuracy: 0.4685 - val_digit2_accuracy: 0.4056 - val_digit3_accuracy: 0.4686 - val_digit4_accuracy: 0.5849
# Epoch 48/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.7461 - digit0_loss: 1.2131 - digit1_loss: 1.8376 - digit2_loss: 1.9566 - digit3_loss: 1.7367 - digit4_loss: 1.0021 - digit0_accuracy: 0.6234 - digit1_accuracy: 0.4732 - digit2_accuracy: 0.4481 - digit3_accuracy: 0.4927 - digit4_accuracy: 0.6798 - val_loss: 10.3618 - val_digit0_loss: 1.7365 - val_digit1_loss: 2.2424 - val_digit2_loss: 2.4197 - val_digit3_loss: 2.1942 - val_digit4_loss: 1.7689 - val_digit0_accuracy: 0.5414 - val_digit1_accuracy: 0.4011 - val_digit2_accuracy: 0.3327 - val_digit3_accuracy: 0.3916 - val_digit4_accuracy: 0.4927
# Epoch 49/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.6627 - digit0_loss: 1.1995 - digit1_loss: 1.8238 - digit2_loss: 1.9408 - digit3_loss: 1.7184 - digit4_loss: 0.9802 - digit0_accuracy: 0.6285 - digit1_accuracy: 0.4763 - digit2_accuracy: 0.4518 - digit3_accuracy: 0.4974 - digit4_accuracy: 0.6864 - val_loss: 11.0600 - val_digit0_loss: 1.8743 - val_digit1_loss: 2.3304 - val_digit2_loss: 2.5295 - val_digit3_loss: 2.3395 - val_digit4_loss: 1.9864 - val_digit0_accuracy: 0.4674 - val_digit1_accuracy: 0.3428 - val_digit2_accuracy: 0.2749 - val_digit3_accuracy: 0.3264 - val_digit4_accuracy: 0.4392
# Epoch 50/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.6074 - digit0_loss: 1.1874 - digit1_loss: 1.8084 - digit2_loss: 1.9320 - digit3_loss: 1.7062 - digit4_loss: 0.9734 - digit0_accuracy: 0.6308 - digit1_accuracy: 0.4809 - digit2_accuracy: 0.4567 - digit3_accuracy: 0.5026 - digit4_accuracy: 0.6879 - val_loss: 11.3083 - val_digit0_loss: 2.0361 - val_digit1_loss: 2.3815 - val_digit2_loss: 2.4794 - val_digit3_loss: 2.3219 - val_digit4_loss: 2.0895 - val_digit0_accuracy: 0.3829 - val_digit1_accuracy: 0.3445 - val_digit2_accuracy: 0.3291 - val_digit3_accuracy: 0.3405 - val_digit4_accuracy: 0.3504
# Epoch 51/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 7.5454 - digit0_loss: 1.1681 - digit1_loss: 1.7994 - digit2_loss: 1.9206 - digit3_loss: 1.6981 - digit4_loss: 0.9592 - digit0_accuracy: 0.6349 - digit1_accuracy: 0.4831 - digit2_accuracy: 0.4585 - digit3_accuracy: 0.5034 - digit4_accuracy: 0.6904 - val_loss: 11.7344 - val_digit0_loss: 2.1674 - val_digit1_loss: 2.4751 - val_digit2_loss: 2.5492 - val_digit3_loss: 2.3687 - val_digit4_loss: 2.1738 - val_digit0_accuracy: 0.3512 - val_digit1_accuracy: 0.3190 - val_digit2_accuracy: 0.3081 - val_digit3_accuracy: 0.3247 - val_digit4_accuracy: 0.3362
# Epoch 52/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 7.5027 - digit0_loss: 1.1618 - digit1_loss: 1.7891 - digit2_loss: 1.9102 - digit3_loss: 1.6871 - digit4_loss: 0.9545 - digit0_accuracy: 0.6379 - digit1_accuracy: 0.4852 - digit2_accuracy: 0.4602 - digit3_accuracy: 0.5087 - digit4_accuracy: 0.6946 - val_loss: 12.7835 - val_digit0_loss: 2.4022 - val_digit1_loss: 2.5927 - val_digit2_loss: 2.6351 - val_digit3_loss: 2.4970 - val_digit4_loss: 2.6566 - val_digit0_accuracy: 0.3054 - val_digit1_accuracy: 0.2853 - val_digit2_accuracy: 0.2847 - val_digit3_accuracy: 0.2889 - val_digit4_accuracy: 0.2487
# Epoch 53/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.4136 - digit0_loss: 1.1389 - digit1_loss: 1.7677 - digit2_loss: 1.8965 - digit3_loss: 1.6737 - digit4_loss: 0.9367 - digit0_accuracy: 0.6472 - digit1_accuracy: 0.4888 - digit2_accuracy: 0.4652 - digit3_accuracy: 0.5115 - digit4_accuracy: 0.6980 - val_loss: 11.5545 - val_digit0_loss: 2.1952 - val_digit1_loss: 2.4457 - val_digit2_loss: 2.4466 - val_digit3_loss: 2.2995 - val_digit4_loss: 2.1675 - val_digit0_accuracy: 0.3531 - val_digit1_accuracy: 0.3049 - val_digit2_accuracy: 0.3299 - val_digit3_accuracy: 0.3384 - val_digit4_accuracy: 0.3534
# Epoch 54/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.3340 - digit0_loss: 1.1254 - digit1_loss: 1.7532 - digit2_loss: 1.8777 - digit3_loss: 1.6559 - digit4_loss: 0.9218 - digit0_accuracy: 0.6475 - digit1_accuracy: 0.4953 - digit2_accuracy: 0.4673 - digit3_accuracy: 0.5168 - digit4_accuracy: 0.7028 - val_loss: 12.8984 - val_digit0_loss: 2.4789 - val_digit1_loss: 2.5815 - val_digit2_loss: 2.5664 - val_digit3_loss: 2.5189 - val_digit4_loss: 2.7527 - val_digit0_accuracy: 0.2944 - val_digit1_accuracy: 0.2791 - val_digit2_accuracy: 0.2882 - val_digit3_accuracy: 0.2801 - val_digit4_accuracy: 0.2460
# Epoch 55/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.2762 - digit0_loss: 1.1107 - digit1_loss: 1.7400 - digit2_loss: 1.8692 - digit3_loss: 1.6443 - digit4_loss: 0.9121 - digit0_accuracy: 0.6547 - digit1_accuracy: 0.4970 - digit2_accuracy: 0.4728 - digit3_accuracy: 0.5186 - digit4_accuracy: 0.7053 - val_loss: 12.5460 - val_digit0_loss: 2.4976 - val_digit1_loss: 2.4069 - val_digit2_loss: 2.4870 - val_digit3_loss: 2.4221 - val_digit4_loss: 2.7322 - val_digit0_accuracy: 0.3065 - val_digit1_accuracy: 0.3183 - val_digit2_accuracy: 0.3027 - val_digit3_accuracy: 0.3035 - val_digit4_accuracy: 0.2597
# Epoch 56/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.1953 - digit0_loss: 1.0917 - digit1_loss: 1.7214 - digit2_loss: 1.8555 - digit3_loss: 1.6285 - digit4_loss: 0.8983 - digit0_accuracy: 0.6586 - digit1_accuracy: 0.5015 - digit2_accuracy: 0.4751 - digit3_accuracy: 0.5256 - digit4_accuracy: 0.7109 - val_loss: 12.9437 - val_digit0_loss: 2.5029 - val_digit1_loss: 2.4929 - val_digit2_loss: 2.4989 - val_digit3_loss: 2.5342 - val_digit4_loss: 2.9148 - val_digit0_accuracy: 0.3153 - val_digit1_accuracy: 0.3126 - val_digit2_accuracy: 0.3098 - val_digit3_accuracy: 0.2924 - val_digit4_accuracy: 0.2524
# Epoch 57/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 7.1476 - digit0_loss: 1.0838 - digit1_loss: 1.7156 - digit2_loss: 1.8447 - digit3_loss: 1.6176 - digit4_loss: 0.8859 - digit0_accuracy: 0.6634 - digit1_accuracy: 0.5055 - digit2_accuracy: 0.4783 - digit3_accuracy: 0.5251 - digit4_accuracy: 0.7146 - val_loss: 12.4681 - val_digit0_loss: 2.3693 - val_digit1_loss: 2.3744 - val_digit2_loss: 2.3919 - val_digit3_loss: 2.4046 - val_digit4_loss: 2.9278 - val_digit0_accuracy: 0.3536 - val_digit1_accuracy: 0.3431 - val_digit2_accuracy: 0.3335 - val_digit3_accuracy: 0.3325 - val_digit4_accuracy: 0.2846
# Epoch 58/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 7.0897 - digit0_loss: 1.0714 - digit1_loss: 1.6992 - digit2_loss: 1.8334 - digit3_loss: 1.6101 - digit4_loss: 0.8755 - digit0_accuracy: 0.6630 - digit1_accuracy: 0.5089 - digit2_accuracy: 0.4784 - digit3_accuracy: 0.5268 - digit4_accuracy: 0.7167 - val_loss: 12.5846 - val_digit0_loss: 2.3313 - val_digit1_loss: 2.4917 - val_digit2_loss: 2.4964 - val_digit3_loss: 2.4943 - val_digit4_loss: 2.7709 - val_digit0_accuracy: 0.3638 - val_digit1_accuracy: 0.3113 - val_digit2_accuracy: 0.3276 - val_digit3_accuracy: 0.3159 - val_digit4_accuracy: 0.2996
# Epoch 59/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.0580 - digit0_loss: 1.0667 - digit1_loss: 1.6961 - digit2_loss: 1.8219 - digit3_loss: 1.5965 - digit4_loss: 0.8767 - digit0_accuracy: 0.6664 - digit1_accuracy: 0.5109 - digit2_accuracy: 0.4841 - digit3_accuracy: 0.5310 - digit4_accuracy: 0.7169 - val_loss: 12.3136 - val_digit0_loss: 2.3719 - val_digit1_loss: 2.3430 - val_digit2_loss: 2.3994 - val_digit3_loss: 2.3797 - val_digit4_loss: 2.8196 - val_digit0_accuracy: 0.3545 - val_digit1_accuracy: 0.3492 - val_digit2_accuracy: 0.3365 - val_digit3_accuracy: 0.3367 - val_digit4_accuracy: 0.3021
# Epoch 60/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 7.0307 - digit0_loss: 1.0621 - digit1_loss: 1.6888 - digit2_loss: 1.8155 - digit3_loss: 1.5952 - digit4_loss: 0.8690 - digit0_accuracy: 0.6680 - digit1_accuracy: 0.5111 - digit2_accuracy: 0.4858 - digit3_accuracy: 0.5295 - digit4_accuracy: 0.7180 - val_loss: 11.2348 - val_digit0_loss: 2.0427 - val_digit1_loss: 2.2890 - val_digit2_loss: 2.2858 - val_digit3_loss: 2.2141 - val_digit4_loss: 2.4031 - val_digit0_accuracy: 0.4077 - val_digit1_accuracy: 0.3694 - val_digit2_accuracy: 0.3817 - val_digit3_accuracy: 0.3696 - val_digit4_accuracy: 0.3355
# Epoch 61/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.9688 - digit0_loss: 1.0462 - digit1_loss: 1.6745 - digit2_loss: 1.8089 - digit3_loss: 1.5812 - digit4_loss: 0.8580 - digit0_accuracy: 0.6714 - digit1_accuracy: 0.5147 - digit2_accuracy: 0.4887 - digit3_accuracy: 0.5364 - digit4_accuracy: 0.7226 - val_loss: 11.1257 - val_digit0_loss: 1.7385 - val_digit1_loss: 2.4957 - val_digit2_loss: 2.4520 - val_digit3_loss: 2.3613 - val_digit4_loss: 2.0783 - val_digit0_accuracy: 0.4853 - val_digit1_accuracy: 0.3223 - val_digit2_accuracy: 0.3455 - val_digit3_accuracy: 0.3412 - val_digit4_accuracy: 0.4030
# Epoch 62/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.9130 - digit0_loss: 1.0374 - digit1_loss: 1.6619 - digit2_loss: 1.7960 - digit3_loss: 1.5695 - digit4_loss: 0.8481 - digit0_accuracy: 0.6749 - digit1_accuracy: 0.5190 - digit2_accuracy: 0.4863 - digit3_accuracy: 0.5397 - digit4_accuracy: 0.7265 - val_loss: 9.1870 - val_digit0_loss: 1.4989 - val_digit1_loss: 1.9686 - val_digit2_loss: 2.1650 - val_digit3_loss: 1.9020 - val_digit4_loss: 1.6525 - val_digit0_accuracy: 0.5610 - val_digit1_accuracy: 0.4613 - val_digit2_accuracy: 0.4212 - val_digit3_accuracy: 0.4664 - val_digit4_accuracy: 0.4970
# Epoch 63/500
# 79928/79928 [==============================] - 4s 46us/step - loss: 6.9011 - digit0_loss: 1.0298 - digit1_loss: 1.6642 - digit2_loss: 1.7897 - digit3_loss: 1.5676 - digit4_loss: 0.8497 - digit0_accuracy: 0.6768 - digit1_accuracy: 0.5147 - digit2_accuracy: 0.4892 - digit3_accuracy: 0.5398 - digit4_accuracy: 0.7237 - val_loss: 9.1106 - val_digit0_loss: 1.5089 - val_digit1_loss: 1.9375 - val_digit2_loss: 2.1089 - val_digit3_loss: 1.9193 - val_digit4_loss: 1.6359 - val_digit0_accuracy: 0.5462 - val_digit1_accuracy: 0.4721 - val_digit2_accuracy: 0.4293 - val_digit3_accuracy: 0.4569 - val_digit4_accuracy: 0.5057
# Epoch 64/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 6.8822 - digit0_loss: 1.0284 - digit1_loss: 1.6579 - digit2_loss: 1.7870 - digit3_loss: 1.5606 - digit4_loss: 0.8484 - digit0_accuracy: 0.6772 - digit1_accuracy: 0.5175 - digit2_accuracy: 0.4918 - digit3_accuracy: 0.5380 - digit4_accuracy: 0.7239 - val_loss: 7.8272 - val_digit0_loss: 1.2245 - val_digit1_loss: 1.7424 - val_digit2_loss: 1.9367 - val_digit3_loss: 1.6913 - val_digit4_loss: 1.2324 - val_digit0_accuracy: 0.6474 - val_digit1_accuracy: 0.5336 - val_digit2_accuracy: 0.4830 - val_digit3_accuracy: 0.5349 - val_digit4_accuracy: 0.6201
# Epoch 65/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 6.8049 - digit0_loss: 1.0114 - digit1_loss: 1.6401 - digit2_loss: 1.7729 - digit3_loss: 1.5479 - digit4_loss: 0.8326 - digit0_accuracy: 0.6843 - digit1_accuracy: 0.5240 - digit2_accuracy: 0.4967 - digit3_accuracy: 0.5427 - digit4_accuracy: 0.7300 - val_loss: 7.1947 - val_digit0_loss: 1.1421 - val_digit1_loss: 1.6302 - val_digit2_loss: 1.7916 - val_digit3_loss: 1.5391 - val_digit4_loss: 1.0917 - val_digit0_accuracy: 0.6734 - val_digit1_accuracy: 0.5742 - val_digit2_accuracy: 0.5241 - val_digit3_accuracy: 0.5777 - val_digit4_accuracy: 0.6638
# Epoch 66/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 6.7445 - digit0_loss: 1.0018 - digit1_loss: 1.6295 - digit2_loss: 1.7590 - digit3_loss: 1.5362 - digit4_loss: 0.8179 - digit0_accuracy: 0.6855 - digit1_accuracy: 0.5269 - digit2_accuracy: 0.5008 - digit3_accuracy: 0.5485 - digit4_accuracy: 0.7347 - val_loss: 7.5318 - val_digit0_loss: 1.2321 - val_digit1_loss: 1.6621 - val_digit2_loss: 1.8061 - val_digit3_loss: 1.5765 - val_digit4_loss: 1.2550 - val_digit0_accuracy: 0.6390 - val_digit1_accuracy: 0.5557 - val_digit2_accuracy: 0.5219 - val_digit3_accuracy: 0.5604 - val_digit4_accuracy: 0.6112
# Epoch 67/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 6.6715 - digit0_loss: 0.9828 - digit1_loss: 1.6163 - digit2_loss: 1.7450 - digit3_loss: 1.5213 - digit4_loss: 0.8061 - digit0_accuracy: 0.6904 - digit1_accuracy: 0.5298 - digit2_accuracy: 0.5022 - digit3_accuracy: 0.5514 - digit4_accuracy: 0.7377 - val_loss: 8.1914 - val_digit0_loss: 1.3282 - val_digit1_loss: 1.6852 - val_digit2_loss: 1.8710 - val_digit3_loss: 1.7103 - val_digit4_loss: 1.5967 - val_digit0_accuracy: 0.6045 - val_digit1_accuracy: 0.5390 - val_digit2_accuracy: 0.4858 - val_digit3_accuracy: 0.5172 - val_digit4_accuracy: 0.5300
# Epoch 68/500
# ...
# Epoch 476/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.8029 - digit0_loss: 0.4294 - digit1_loss: 0.9803 - digit2_loss: 1.1342 - digit3_loss: 0.9165 - digit4_loss: 0.3425 - digit0_accuracy: 0.8526 - digit1_accuracy: 0.6941 - digit2_accuracy: 0.6612 - digit3_accuracy: 0.7125 - digit4_accuracy: 0.8761 - val_loss: 2.5904 - val_digit0_loss: 0.3221 - val_digit1_loss: 0.6536 - val_digit2_loss: 0.7583 - val_digit3_loss: 0.6026 - val_digit4_loss: 0.2537 - val_digit0_accuracy: 0.8970 - val_digit1_accuracy: 0.8133 - val_digit2_accuracy: 0.7937 - val_digit3_accuracy: 0.8243 - val_digit4_accuracy: 0.9133
# Epoch 477/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.8076 - digit0_loss: 0.4286 - digit1_loss: 0.9833 - digit2_loss: 1.1368 - digit3_loss: 0.9169 - digit4_loss: 0.3421 - digit0_accuracy: 0.8538 - digit1_accuracy: 0.6933 - digit2_accuracy: 0.6606 - digit3_accuracy: 0.7099 - digit4_accuracy: 0.8766 - val_loss: 2.5787 - val_digit0_loss: 0.3210 - val_digit1_loss: 0.6568 - val_digit2_loss: 0.7584 - val_digit3_loss: 0.6002 - val_digit4_loss: 0.2424 - val_digit0_accuracy: 0.8980 - val_digit1_accuracy: 0.8124 - val_digit2_accuracy: 0.7934 - val_digit3_accuracy: 0.8236 - val_digit4_accuracy: 0.9168
# Epoch 478/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.8039 - digit0_loss: 0.4312 - digit1_loss: 0.9780 - digit2_loss: 1.1372 - digit3_loss: 0.9149 - digit4_loss: 0.3426 - digit0_accuracy: 0.8537 - digit1_accuracy: 0.6942 - digit2_accuracy: 0.6593 - digit3_accuracy: 0.7116 - digit4_accuracy: 0.8756 - val_loss: 2.6441 - val_digit0_loss: 0.3284 - val_digit1_loss: 0.6620 - val_digit2_loss: 0.7676 - val_digit3_loss: 0.6179 - val_digit4_loss: 0.2681 - val_digit0_accuracy: 0.8944 - val_digit1_accuracy: 0.8098 - val_digit2_accuracy: 0.7891 - val_digit3_accuracy: 0.8151 - val_digit4_accuracy: 0.9069
# Epoch 479/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.8149 - digit0_loss: 0.4324 - digit1_loss: 0.9871 - digit2_loss: 1.1359 - digit3_loss: 0.9152 - digit4_loss: 0.3443 - digit0_accuracy: 0.8520 - digit1_accuracy: 0.6928 - digit2_accuracy: 0.6632 - digit3_accuracy: 0.7124 - digit4_accuracy: 0.8753 - val_loss: 2.5381 - val_digit0_loss: 0.3127 - val_digit1_loss: 0.6483 - val_digit2_loss: 0.7473 - val_digit3_loss: 0.5903 - val_digit4_loss: 0.2395 - val_digit0_accuracy: 0.9011 - val_digit1_accuracy: 0.8133 - val_digit2_accuracy: 0.7939 - val_digit3_accuracy: 0.8266 - val_digit4_accuracy: 0.9176
# Epoch 480/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.8088 - digit0_loss: 0.4299 - digit1_loss: 0.9839 - digit2_loss: 1.1390 - digit3_loss: 0.9136 - digit4_loss: 0.3424 - digit0_accuracy: 0.8535 - digit1_accuracy: 0.6930 - digit2_accuracy: 0.6616 - digit3_accuracy: 0.7134 - digit4_accuracy: 0.8763 - val_loss: 2.5551 - val_digit0_loss: 0.3113 - val_digit1_loss: 0.6511 - val_digit2_loss: 0.7543 - val_digit3_loss: 0.5975 - val_digit4_loss: 0.2409 - val_digit0_accuracy: 0.9010 - val_digit1_accuracy: 0.8171 - val_digit2_accuracy: 0.7974 - val_digit3_accuracy: 0.8246 - val_digit4_accuracy: 0.9167
# Epoch 481/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.8147 - digit0_loss: 0.4281 - digit1_loss: 0.9858 - digit2_loss: 1.1463 - digit3_loss: 0.9131 - digit4_loss: 0.3415 - digit0_accuracy: 0.8544 - digit1_accuracy: 0.6924 - digit2_accuracy: 0.6583 - digit3_accuracy: 0.7118 - digit4_accuracy: 0.8773 - val_loss: 2.7788 - val_digit0_loss: 0.3562 - val_digit1_loss: 0.6911 - val_digit2_loss: 0.8023 - val_digit3_loss: 0.6429 - val_digit4_loss: 0.2864 - val_digit0_accuracy: 0.8867 - val_digit1_accuracy: 0.8037 - val_digit2_accuracy: 0.7811 - val_digit3_accuracy: 0.8089 - val_digit4_accuracy: 0.9006
# Epoch 482/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.8072 - digit0_loss: 0.4293 - digit1_loss: 0.9835 - digit2_loss: 1.1364 - digit3_loss: 0.9149 - digit4_loss: 0.3432 - digit0_accuracy: 0.8541 - digit1_accuracy: 0.6933 - digit2_accuracy: 0.6613 - digit3_accuracy: 0.7113 - digit4_accuracy: 0.8772 - val_loss: 2.5991 - val_digit0_loss: 0.3230 - val_digit1_loss: 0.6589 - val_digit2_loss: 0.7635 - val_digit3_loss: 0.6050 - val_digit4_loss: 0.2487 - val_digit0_accuracy: 0.8972 - val_digit1_accuracy: 0.8132 - val_digit2_accuracy: 0.7936 - val_digit3_accuracy: 0.8243 - val_digit4_accuracy: 0.9136
# Epoch 483/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.8085 - digit0_loss: 0.4301 - digit1_loss: 0.9784 - digit2_loss: 1.1475 - digit3_loss: 0.9110 - digit4_loss: 0.3415 - digit0_accuracy: 0.8534 - digit1_accuracy: 0.6936 - digit2_accuracy: 0.6601 - digit3_accuracy: 0.7130 - digit4_accuracy: 0.8755 - val_loss: 2.6101 - val_digit0_loss: 0.3232 - val_digit1_loss: 0.6568 - val_digit2_loss: 0.7640 - val_digit3_loss: 0.6067 - val_digit4_loss: 0.2595 - val_digit0_accuracy: 0.8987 - val_digit1_accuracy: 0.8143 - val_digit2_accuracy: 0.7913 - val_digit3_accuracy: 0.8234 - val_digit4_accuracy: 0.9108
# Epoch 484/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.8070 - digit0_loss: 0.4285 - digit1_loss: 0.9833 - digit2_loss: 1.1392 - digit3_loss: 0.9133 - digit4_loss: 0.3427 - digit0_accuracy: 0.8526 - digit1_accuracy: 0.6947 - digit2_accuracy: 0.6617 - digit3_accuracy: 0.7105 - digit4_accuracy: 0.8774 - val_loss: 2.5889 - val_digit0_loss: 0.3173 - val_digit1_loss: 0.6536 - val_digit2_loss: 0.7648 - val_digit3_loss: 0.5998 - val_digit4_loss: 0.2534 - val_digit0_accuracy: 0.8984 - val_digit1_accuracy: 0.8133 - val_digit2_accuracy: 0.7953 - val_digit3_accuracy: 0.8226 - val_digit4_accuracy: 0.9118
# Epoch 485/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.8092 - digit0_loss: 0.4272 - digit1_loss: 0.9839 - digit2_loss: 1.1447 - digit3_loss: 0.9127 - digit4_loss: 0.3408 - digit0_accuracy: 0.8549 - digit1_accuracy: 0.6924 - digit2_accuracy: 0.6610 - digit3_accuracy: 0.7124 - digit4_accuracy: 0.8778 - val_loss: 2.5835 - val_digit0_loss: 0.3226 - val_digit1_loss: 0.6544 - val_digit2_loss: 0.7524 - val_digit3_loss: 0.5963 - val_digit4_loss: 0.2578 - val_digit0_accuracy: 0.8971 - val_digit1_accuracy: 0.8115 - val_digit2_accuracy: 0.7938 - val_digit3_accuracy: 0.8241 - val_digit4_accuracy: 0.9128
# Epoch 486/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.7982 - digit0_loss: 0.4256 - digit1_loss: 0.9826 - digit2_loss: 1.1366 - digit3_loss: 0.9100 - digit4_loss: 0.3433 - digit0_accuracy: 0.8561 - digit1_accuracy: 0.6914 - digit2_accuracy: 0.6620 - digit3_accuracy: 0.7135 - digit4_accuracy: 0.8773 - val_loss: 2.7718 - val_digit0_loss: 0.3578 - val_digit1_loss: 0.6863 - val_digit2_loss: 0.7982 - val_digit3_loss: 0.6426 - val_digit4_loss: 0.2869 - val_digit0_accuracy: 0.8843 - val_digit1_accuracy: 0.8044 - val_digit2_accuracy: 0.7794 - val_digit3_accuracy: 0.8078 - val_digit4_accuracy: 0.9017
# Epoch 487/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7965 - digit0_loss: 0.4274 - digit1_loss: 0.9832 - digit2_loss: 1.1320 - digit3_loss: 0.9141 - digit4_loss: 0.3398 - digit0_accuracy: 0.8538 - digit1_accuracy: 0.6914 - digit2_accuracy: 0.6625 - digit3_accuracy: 0.7127 - digit4_accuracy: 0.8781 - val_loss: 2.7030 - val_digit0_loss: 0.3491 - val_digit1_loss: 0.6804 - val_digit2_loss: 0.7737 - val_digit3_loss: 0.6215 - val_digit4_loss: 0.2782 - val_digit0_accuracy: 0.8872 - val_digit1_accuracy: 0.8037 - val_digit2_accuracy: 0.7853 - val_digit3_accuracy: 0.8146 - val_digit4_accuracy: 0.9051
# Epoch 488/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7807 - digit0_loss: 0.4209 - digit1_loss: 0.9787 - digit2_loss: 1.1362 - digit3_loss: 0.9052 - digit4_loss: 0.3398 - digit0_accuracy: 0.8569 - digit1_accuracy: 0.6967 - digit2_accuracy: 0.6616 - digit3_accuracy: 0.7152 - digit4_accuracy: 0.8776 - val_loss: 2.5551 - val_digit0_loss: 0.3151 - val_digit1_loss: 0.6462 - val_digit2_loss: 0.7485 - val_digit3_loss: 0.5959 - val_digit4_loss: 0.2494 - val_digit0_accuracy: 0.8993 - val_digit1_accuracy: 0.8129 - val_digit2_accuracy: 0.7946 - val_digit3_accuracy: 0.8240 - val_digit4_accuracy: 0.9127
# Epoch 489/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7897 - digit0_loss: 0.4308 - digit1_loss: 0.9796 - digit2_loss: 1.1283 - digit3_loss: 0.9129 - digit4_loss: 0.3382 - digit0_accuracy: 0.8531 - digit1_accuracy: 0.6953 - digit2_accuracy: 0.6627 - digit3_accuracy: 0.7123 - digit4_accuracy: 0.8770 - val_loss: 2.5846 - val_digit0_loss: 0.3254 - val_digit1_loss: 0.6507 - val_digit2_loss: 0.7525 - val_digit3_loss: 0.6005 - val_digit4_loss: 0.2555 - val_digit0_accuracy: 0.8954 - val_digit1_accuracy: 0.8111 - val_digit2_accuracy: 0.7922 - val_digit3_accuracy: 0.8199 - val_digit4_accuracy: 0.9131
# Epoch 490/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7984 - digit0_loss: 0.4329 - digit1_loss: 0.9813 - digit2_loss: 1.1367 - digit3_loss: 0.9076 - digit4_loss: 0.3400 - digit0_accuracy: 0.8527 - digit1_accuracy: 0.6943 - digit2_accuracy: 0.6639 - digit3_accuracy: 0.7140 - digit4_accuracy: 0.8774 - val_loss: 2.5058 - val_digit0_loss: 0.3077 - val_digit1_loss: 0.6382 - val_digit2_loss: 0.7392 - val_digit3_loss: 0.5807 - val_digit4_loss: 0.2400 - val_digit0_accuracy: 0.9018 - val_digit1_accuracy: 0.8171 - val_digit2_accuracy: 0.8009 - val_digit3_accuracy: 0.8302 - val_digit4_accuracy: 0.9173
# Epoch 491/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7961 - digit0_loss: 0.4309 - digit1_loss: 0.9835 - digit2_loss: 1.1341 - digit3_loss: 0.9043 - digit4_loss: 0.3434 - digit0_accuracy: 0.8523 - digit1_accuracy: 0.6930 - digit2_accuracy: 0.6621 - digit3_accuracy: 0.7136 - digit4_accuracy: 0.8768 - val_loss: 2.8223 - val_digit0_loss: 0.3667 - val_digit1_loss: 0.6978 - val_digit2_loss: 0.8075 - val_digit3_loss: 0.6538 - val_digit4_loss: 0.2965 - val_digit0_accuracy: 0.8810 - val_digit1_accuracy: 0.7996 - val_digit2_accuracy: 0.7797 - val_digit3_accuracy: 0.8057 - val_digit4_accuracy: 0.8983
# Epoch 492/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.8004 - digit0_loss: 0.4256 - digit1_loss: 0.9807 - digit2_loss: 1.1396 - digit3_loss: 0.9127 - digit4_loss: 0.3418 - digit0_accuracy: 0.8560 - digit1_accuracy: 0.6938 - digit2_accuracy: 0.6591 - digit3_accuracy: 0.7113 - digit4_accuracy: 0.8764 - val_loss: 2.6959 - val_digit0_loss: 0.3463 - val_digit1_loss: 0.6777 - val_digit2_loss: 0.7677 - val_digit3_loss: 0.6168 - val_digit4_loss: 0.2875 - val_digit0_accuracy: 0.8875 - val_digit1_accuracy: 0.8048 - val_digit2_accuracy: 0.7870 - val_digit3_accuracy: 0.8162 - val_digit4_accuracy: 0.9022
# Epoch 493/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7832 - digit0_loss: 0.4274 - digit1_loss: 0.9791 - digit2_loss: 1.1393 - digit3_loss: 0.9025 - digit4_loss: 0.3349 - digit0_accuracy: 0.8549 - digit1_accuracy: 0.6938 - digit2_accuracy: 0.6602 - digit3_accuracy: 0.7158 - digit4_accuracy: 0.8792 - val_loss: 2.7162 - val_digit0_loss: 0.3514 - val_digit1_loss: 0.6740 - val_digit2_loss: 0.7792 - val_digit3_loss: 0.6276 - val_digit4_loss: 0.2841 - val_digit0_accuracy: 0.8855 - val_digit1_accuracy: 0.8073 - val_digit2_accuracy: 0.7856 - val_digit3_accuracy: 0.8125 - val_digit4_accuracy: 0.9034
# Epoch 494/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.7960 - digit0_loss: 0.4254 - digit1_loss: 0.9814 - digit2_loss: 1.1344 - digit3_loss: 0.9174 - digit4_loss: 0.3374 - digit0_accuracy: 0.8550 - digit1_accuracy: 0.6936 - digit2_accuracy: 0.6618 - digit3_accuracy: 0.7114 - digit4_accuracy: 0.8784 - val_loss: 2.7532 - val_digit0_loss: 0.3639 - val_digit1_loss: 0.6895 - val_digit2_loss: 0.7803 - val_digit3_loss: 0.6248 - val_digit4_loss: 0.2946 - val_digit0_accuracy: 0.8818 - val_digit1_accuracy: 0.7991 - val_digit2_accuracy: 0.7810 - val_digit3_accuracy: 0.8126 - val_digit4_accuracy: 0.8996
# Epoch 495/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7904 - digit0_loss: 0.4232 - digit1_loss: 0.9818 - digit2_loss: 1.1321 - digit3_loss: 0.9146 - digit4_loss: 0.3386 - digit0_accuracy: 0.8554 - digit1_accuracy: 0.6944 - digit2_accuracy: 0.6627 - digit3_accuracy: 0.7118 - digit4_accuracy: 0.8787 - val_loss: 2.8812 - val_digit0_loss: 0.3847 - val_digit1_loss: 0.7083 - val_digit2_loss: 0.8109 - val_digit3_loss: 0.6676 - val_digit4_loss: 0.3097 - val_digit0_accuracy: 0.8758 - val_digit1_accuracy: 0.7965 - val_digit2_accuracy: 0.7760 - val_digit3_accuracy: 0.8004 - val_digit4_accuracy: 0.8975
# Epoch 496/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7783 - digit0_loss: 0.4226 - digit1_loss: 0.9772 - digit2_loss: 1.1363 - digit3_loss: 0.9066 - digit4_loss: 0.3357 - digit0_accuracy: 0.8556 - digit1_accuracy: 0.6951 - digit2_accuracy: 0.6608 - digit3_accuracy: 0.7130 - digit4_accuracy: 0.8790 - val_loss: 2.6461 - val_digit0_loss: 0.3377 - val_digit1_loss: 0.6714 - val_digit2_loss: 0.7678 - val_digit3_loss: 0.6081 - val_digit4_loss: 0.2611 - val_digit0_accuracy: 0.8911 - val_digit1_accuracy: 0.8069 - val_digit2_accuracy: 0.7871 - val_digit3_accuracy: 0.8200 - val_digit4_accuracy: 0.9089
# Epoch 497/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.7756 - digit0_loss: 0.4260 - digit1_loss: 0.9733 - digit2_loss: 1.1360 - digit3_loss: 0.9018 - digit4_loss: 0.3386 - digit0_accuracy: 0.8549 - digit1_accuracy: 0.6955 - digit2_accuracy: 0.6621 - digit3_accuracy: 0.7138 - digit4_accuracy: 0.8780 - val_loss: 2.5982 - val_digit0_loss: 0.3192 - val_digit1_loss: 0.6620 - val_digit2_loss: 0.7579 - val_digit3_loss: 0.6066 - val_digit4_loss: 0.2525 - val_digit0_accuracy: 0.8970 - val_digit1_accuracy: 0.8099 - val_digit2_accuracy: 0.7934 - val_digit3_accuracy: 0.8199 - val_digit4_accuracy: 0.9136
# Epoch 498/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7760 - digit0_loss: 0.4207 - digit1_loss: 0.9788 - digit2_loss: 1.1340 - digit3_loss: 0.9061 - digit4_loss: 0.3364 - digit0_accuracy: 0.8568 - digit1_accuracy: 0.6943 - digit2_accuracy: 0.6643 - digit3_accuracy: 0.7112 - digit4_accuracy: 0.8779 - val_loss: 2.6267 - val_digit0_loss: 0.3267 - val_digit1_loss: 0.6616 - val_digit2_loss: 0.7618 - val_digit3_loss: 0.6088 - val_digit4_loss: 0.2679 - val_digit0_accuracy: 0.8953 - val_digit1_accuracy: 0.8114 - val_digit2_accuracy: 0.7924 - val_digit3_accuracy: 0.8199 - val_digit4_accuracy: 0.9051
# Epoch 499/500
# 79928/79928 [==============================] - 4s 44us/step - loss: 3.7819 - digit0_loss: 0.4237 - digit1_loss: 0.9840 - digit2_loss: 1.1296 - digit3_loss: 0.9062 - digit4_loss: 0.3383 - digit0_accuracy: 0.8559 - digit1_accuracy: 0.6935 - digit2_accuracy: 0.6650 - digit3_accuracy: 0.7132 - digit4_accuracy: 0.8780 - val_loss: 2.6457 - val_digit0_loss: 0.3328 - val_digit1_loss: 0.6670 - val_digit2_loss: 0.7627 - val_digit3_loss: 0.6139 - val_digit4_loss: 0.2694 - val_digit0_accuracy: 0.8943 - val_digit1_accuracy: 0.8092 - val_digit2_accuracy: 0.7929 - val_digit3_accuracy: 0.8189 - val_digit4_accuracy: 0.9066
# Epoch 500/500
# 79928/79928 [==============================] - 4s 45us/step - loss: 3.7749 - digit0_loss: 0.4219 - digit1_loss: 0.9761 - digit2_loss: 1.1287 - digit3_loss: 0.9095 - digit4_loss: 0.3389 - digit0_accuracy: 0.8570 - digit1_accuracy: 0.6952 - digit2_accuracy: 0.6654 - digit3_accuracy: 0.7122 - digit4_accuracy: 0.8793 - val_loss: 2.6748 - val_digit0_loss: 0.3330 - val_digit1_loss: 0.6722 - val_digit2_loss: 0.7742 - val_digit3_loss: 0.6172 - val_digit4_loss: 0.2783 - val_digit0_accuracy: 0.8914 - val_digit1_accuracy: 0.8084 - val_digit2_accuracy: 0.7877 - val_digit3_accuracy: 0.8139 - val_digit4_accuracy: 0.9040
#
# Epoch 00500: saving model to ./output-captcha/weights-500-3.77.hdf5

# %%
plot_model_history(history_random)

# %% [markdown]
# ## 4.2 - Treino Dataset Permut

# %%
net_perm = create_net();
history_perm = net_perm.fit(X_train_perm, [y_train_perm[0], y_train_perm[1], y_train_perm[2], y_train_perm[3], y_train_perm[4]], epochs=n_epoch, validation_split=validation_split, batch_size=size_batch_train, callbacks=callbacks_list)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 30, 80, 1)    0
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 28, 78, 16)   160         input_2[0][0]
# __________________________________________________________________________________________________
# MaxPool_1 (AveragePooling2D)    (None, 14, 39, 16)   0           Conv_1[0][0]
# __________________________________________________________________________________________________
# Conv_2 (Conv2D)                 (None, 12, 37, 32)   4640        MaxPool_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_2 (AveragePooling2D)    (None, 6, 19, 32)    0           Conv_2[0][0]
# __________________________________________________________________________________________________
# Conv_3 (Conv2D)                 (None, 4, 17, 32)    9248        MaxPool_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 4, 17, 32)    128         Conv_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_3 (MaxPooling2D)        (None, 2, 9, 32)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 576)          0           MaxPool_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           36928       flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# digit0 (Dense)                  (None, 36)           2340        dropout_6[0][0]
# __________________________________________________________________________________________________
# digit1 (Dense)                  (None, 36)           2340        dropout_7[0][0]
# __________________________________________________________________________________________________
# digit2 (Dense)                  (None, 36)           2340        dropout_8[0][0]
# __________________________________________________________________________________________________
# digit3 (Dense)                  (None, 36)           2340        dropout_9[0][0]
# __________________________________________________________________________________________________
# digit4 (Dense)                  (None, 36)           2340        dropout_10[0][0]
# ==================================================================================================
# Total params: 210,516
# Trainable params: 210,452
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Train on 80023 samples, validate on 20006 samples
# Epoch 1/500
# 80023/80023 [==============================] - 5s 57us/step - loss: 17.9399 - digit0_loss: 3.5867 - digit1_loss: 3.5880 - digit2_loss: 3.5824 - digit3_loss: 3.5869 - digit4_loss: 3.5863 - digit0_accuracy: 0.0302 - digit1_accuracy: 0.0285 - digit2_accuracy: 0.0295 - digit3_accuracy: 0.0289 - digit4_accuracy: 0.0296 - val_loss: 17.9166 - val_digit0_loss: 3.5833 - val_digit1_loss: 3.5831 - val_digit2_loss: 3.5821 - val_digit3_loss: 3.5830 - val_digit4_loss: 3.5809 - val_digit0_accuracy: 0.0293 - val_digit1_accuracy: 0.0328 - val_digit2_accuracy: 0.0285 - val_digit3_accuracy: 0.0296 - val_digit4_accuracy: 0.0312
# Epoch 2/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 17.8890 - digit0_loss: 3.5780 - digit1_loss: 3.5787 - digit2_loss: 3.5786 - digit3_loss: 3.5785 - digit4_loss: 3.5772 - digit0_accuracy: 0.0337 - digit1_accuracy: 0.0327 - digit2_accuracy: 0.0334 - digit3_accuracy: 0.0325 - digit4_accuracy: 0.0334 - val_loss: 17.9158 - val_digit0_loss: 3.5837 - val_digit1_loss: 3.5837 - val_digit2_loss: 3.5818 - val_digit3_loss: 3.5856 - val_digit4_loss: 3.5809 - val_digit0_accuracy: 0.0272 - val_digit1_accuracy: 0.0294 - val_digit2_accuracy: 0.0285 - val_digit3_accuracy: 0.0268 - val_digit4_accuracy: 0.0323
# Epoch 3/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.8579 - digit0_loss: 3.5734 - digit1_loss: 3.5775 - digit2_loss: 3.5690 - digit3_loss: 3.5675 - digit4_loss: 3.5728 - digit0_accuracy: 0.0381 - digit1_accuracy: 0.0364 - digit2_accuracy: 0.0374 - digit3_accuracy: 0.0369 - digit4_accuracy: 0.0370 - val_loss: 17.9137 - val_digit0_loss: 3.5846 - val_digit1_loss: 3.5818 - val_digit2_loss: 3.5803 - val_digit3_loss: 3.5840 - val_digit4_loss: 3.5821 - val_digit0_accuracy: 0.0293 - val_digit1_accuracy: 0.0294 - val_digit2_accuracy: 0.0285 - val_digit3_accuracy: 0.0388 - val_digit4_accuracy: 0.0280
# Epoch 4/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.8102 - digit0_loss: 3.5652 - digit1_loss: 3.5672 - digit2_loss: 3.5588 - digit3_loss: 3.5531 - digit4_loss: 3.5632 - digit0_accuracy: 0.0402 - digit1_accuracy: 0.0390 - digit2_accuracy: 0.0397 - digit3_accuracy: 0.0421 - digit4_accuracy: 0.0424 - val_loss: 17.9094 - val_digit0_loss: 3.5842 - val_digit1_loss: 3.5848 - val_digit2_loss: 3.5797 - val_digit3_loss: 3.5836 - val_digit4_loss: 3.5807 - val_digit0_accuracy: 0.0284 - val_digit1_accuracy: 0.0279 - val_digit2_accuracy: 0.0366 - val_digit3_accuracy: 0.0314 - val_digit4_accuracy: 0.0258
# Epoch 5/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.7311 - digit0_loss: 3.5524 - digit1_loss: 3.5610 - digit2_loss: 3.5460 - digit3_loss: 3.5453 - digit4_loss: 3.5309 - digit0_accuracy: 0.0449 - digit1_accuracy: 0.0421 - digit2_accuracy: 0.0462 - digit3_accuracy: 0.0472 - digit4_accuracy: 0.0490 - val_loss: 17.9038 - val_digit0_loss: 3.5814 - val_digit1_loss: 3.5857 - val_digit2_loss: 3.5805 - val_digit3_loss: 3.5946 - val_digit4_loss: 3.5806 - val_digit0_accuracy: 0.0300 - val_digit1_accuracy: 0.0332 - val_digit2_accuracy: 0.0285 - val_digit3_accuracy: 0.0328 - val_digit4_accuracy: 0.0279
# Epoch 6/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 17.6258 - digit0_loss: 3.5310 - digit1_loss: 3.5397 - digit2_loss: 3.5265 - digit3_loss: 3.5316 - digit4_loss: 3.5094 - digit0_accuracy: 0.0515 - digit1_accuracy: 0.0496 - digit2_accuracy: 0.0506 - digit3_accuracy: 0.0531 - digit4_accuracy: 0.0528 - val_loss: 17.8939 - val_digit0_loss: 3.5810 - val_digit1_loss: 3.5816 - val_digit2_loss: 3.5781 - val_digit3_loss: 3.6046 - val_digit4_loss: 3.5815 - val_digit0_accuracy: 0.0364 - val_digit1_accuracy: 0.0334 - val_digit2_accuracy: 0.0283 - val_digit3_accuracy: 0.0307 - val_digit4_accuracy: 0.0247
# Epoch 7/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.5028 - digit0_loss: 3.4970 - digit1_loss: 3.5207 - digit2_loss: 3.5176 - digit3_loss: 3.4889 - digit4_loss: 3.4765 - digit0_accuracy: 0.0574 - digit1_accuracy: 0.0544 - digit2_accuracy: 0.0547 - digit3_accuracy: 0.0555 - digit4_accuracy: 0.0598 - val_loss: 17.8848 - val_digit0_loss: 3.5766 - val_digit1_loss: 3.5791 - val_digit2_loss: 3.5772 - val_digit3_loss: 3.6116 - val_digit4_loss: 3.5698 - val_digit0_accuracy: 0.0373 - val_digit1_accuracy: 0.0313 - val_digit2_accuracy: 0.0282 - val_digit3_accuracy: 0.0337 - val_digit4_accuracy: 0.0301
# Epoch 8/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.3813 - digit0_loss: 3.4895 - digit1_loss: 3.5016 - digit2_loss: 3.4766 - digit3_loss: 3.4634 - digit4_loss: 3.4392 - digit0_accuracy: 0.0622 - digit1_accuracy: 0.0578 - digit2_accuracy: 0.0598 - digit3_accuracy: 0.0598 - digit4_accuracy: 0.0645 - val_loss: 17.8653 - val_digit0_loss: 3.5774 - val_digit1_loss: 3.5920 - val_digit2_loss: 3.5653 - val_digit3_loss: 3.6074 - val_digit4_loss: 3.5628 - val_digit0_accuracy: 0.0304 - val_digit1_accuracy: 0.0283 - val_digit2_accuracy: 0.0400 - val_digit3_accuracy: 0.0281 - val_digit4_accuracy: 0.0306
# Epoch 9/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 17.2341 - digit0_loss: 3.4467 - digit1_loss: 3.4817 - digit2_loss: 3.4596 - digit3_loss: 3.4289 - digit4_loss: 3.4159 - digit0_accuracy: 0.0694 - digit1_accuracy: 0.0616 - digit2_accuracy: 0.0624 - digit3_accuracy: 0.0639 - digit4_accuracy: 0.0724 - val_loss: 17.8287 - val_digit0_loss: 3.5727 - val_digit1_loss: 3.5783 - val_digit2_loss: 3.5605 - val_digit3_loss: 3.6008 - val_digit4_loss: 3.5550 - val_digit0_accuracy: 0.0378 - val_digit1_accuracy: 0.0280 - val_digit2_accuracy: 0.0280 - val_digit3_accuracy: 0.0303 - val_digit4_accuracy: 0.0578
# Epoch 10/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 17.0803 - digit0_loss: 3.4055 - digit1_loss: 3.4633 - digit2_loss: 3.4725 - digit3_loss: 3.4212 - digit4_loss: 3.3505 - digit0_accuracy: 0.0729 - digit1_accuracy: 0.0688 - digit2_accuracy: 0.0673 - digit3_accuracy: 0.0684 - digit4_accuracy: 0.0819 - val_loss: 17.8230 - val_digit0_loss: 3.5565 - val_digit1_loss: 3.5744 - val_digit2_loss: 3.5699 - val_digit3_loss: 3.6108 - val_digit4_loss: 3.5372 - val_digit0_accuracy: 0.0395 - val_digit1_accuracy: 0.0340 - val_digit2_accuracy: 0.0357 - val_digit3_accuracy: 0.0485 - val_digit4_accuracy: 0.0516
# Epoch 11/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 16.9417 - digit0_loss: 3.3491 - digit1_loss: 3.4212 - digit2_loss: 3.4140 - digit3_loss: 3.3987 - digit4_loss: 3.3279 - digit0_accuracy: 0.0784 - digit1_accuracy: 0.0717 - digit2_accuracy: 0.0701 - digit3_accuracy: 0.0717 - digit4_accuracy: 0.0886 - val_loss: 17.8118 - val_digit0_loss: 3.5560 - val_digit1_loss: 3.5745 - val_digit2_loss: 3.5573 - val_digit3_loss: 3.6415 - val_digit4_loss: 3.5479 - val_digit0_accuracy: 0.0393 - val_digit1_accuracy: 0.0438 - val_digit2_accuracy: 0.0358 - val_digit3_accuracy: 0.0345 - val_digit4_accuracy: 0.0473
# Epoch 12/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 16.7925 - digit0_loss: 3.3231 - digit1_loss: 3.3932 - digit2_loss: 3.3965 - digit3_loss: 3.3787 - digit4_loss: 3.2874 - digit0_accuracy: 0.0848 - digit1_accuracy: 0.0776 - digit2_accuracy: 0.0744 - digit3_accuracy: 0.0755 - digit4_accuracy: 0.0938 - val_loss: 17.7275 - val_digit0_loss: 3.5382 - val_digit1_loss: 3.5581 - val_digit2_loss: 3.5587 - val_digit3_loss: 3.5967 - val_digit4_loss: 3.5304 - val_digit0_accuracy: 0.0450 - val_digit1_accuracy: 0.0412 - val_digit2_accuracy: 0.0380 - val_digit3_accuracy: 0.0491 - val_digit4_accuracy: 0.0647
# Epoch 13/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 16.6695 - digit0_loss: 3.2934 - digit1_loss: 3.3890 - digit2_loss: 3.3765 - digit3_loss: 3.3623 - digit4_loss: 3.2690 - digit0_accuracy: 0.0894 - digit1_accuracy: 0.0807 - digit2_accuracy: 0.0765 - digit3_accuracy: 0.0794 - digit4_accuracy: 0.0999 - val_loss: 17.6900 - val_digit0_loss: 3.5332 - val_digit1_loss: 3.5404 - val_digit2_loss: 3.5555 - val_digit3_loss: 3.5856 - val_digit4_loss: 3.5203 - val_digit0_accuracy: 0.0429 - val_digit1_accuracy: 0.0609 - val_digit2_accuracy: 0.0440 - val_digit3_accuracy: 0.0554 - val_digit4_accuracy: 0.0448
# Epoch 14/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 16.5465 - digit0_loss: 3.2506 - digit1_loss: 3.3503 - digit2_loss: 3.3678 - digit3_loss: 3.3525 - digit4_loss: 3.2032 - digit0_accuracy: 0.0934 - digit1_accuracy: 0.0812 - digit2_accuracy: 0.0809 - digit3_accuracy: 0.0827 - digit4_accuracy: 0.1067 - val_loss: 17.7924 - val_digit0_loss: 3.5441 - val_digit1_loss: 3.5700 - val_digit2_loss: 3.5825 - val_digit3_loss: 3.6300 - val_digit4_loss: 3.5618 - val_digit0_accuracy: 0.0599 - val_digit1_accuracy: 0.0314 - val_digit2_accuracy: 0.0320 - val_digit3_accuracy: 0.0395 - val_digit4_accuracy: 0.0278
# Epoch 15/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 16.4012 - digit0_loss: 3.1898 - digit1_loss: 3.3280 - digit2_loss: 3.3285 - digit3_loss: 3.2966 - digit4_loss: 3.1532 - digit0_accuracy: 0.0995 - digit1_accuracy: 0.0889 - digit2_accuracy: 0.0844 - digit3_accuracy: 0.0822 - digit4_accuracy: 0.1122 - val_loss: 17.6588 - val_digit0_loss: 3.5286 - val_digit1_loss: 3.5418 - val_digit2_loss: 3.5440 - val_digit3_loss: 3.6202 - val_digit4_loss: 3.5053 - val_digit0_accuracy: 0.0707 - val_digit1_accuracy: 0.0519 - val_digit2_accuracy: 0.0568 - val_digit3_accuracy: 0.0351 - val_digit4_accuracy: 0.0803
# Epoch 16/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 16.2609 - digit0_loss: 3.1835 - digit1_loss: 3.3120 - digit2_loss: 3.3230 - digit3_loss: 3.2978 - digit4_loss: 3.1387 - digit0_accuracy: 0.1050 - digit1_accuracy: 0.0909 - digit2_accuracy: 0.0897 - digit3_accuracy: 0.0883 - digit4_accuracy: 0.1159 - val_loss: 17.5921 - val_digit0_loss: 3.5109 - val_digit1_loss: 3.5103 - val_digit2_loss: 3.5344 - val_digit3_loss: 3.6318 - val_digit4_loss: 3.4888 - val_digit0_accuracy: 0.0594 - val_digit1_accuracy: 0.0671 - val_digit2_accuracy: 0.0575 - val_digit3_accuracy: 0.0553 - val_digit4_accuracy: 0.0679
# Epoch 17/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 16.1094 - digit0_loss: 3.1378 - digit1_loss: 3.2899 - digit2_loss: 3.2946 - digit3_loss: 3.2604 - digit4_loss: 3.0852 - digit0_accuracy: 0.1141 - digit1_accuracy: 0.0957 - digit2_accuracy: 0.0927 - digit3_accuracy: 0.0917 - digit4_accuracy: 0.1245 - val_loss: 17.6475 - val_digit0_loss: 3.5577 - val_digit1_loss: 3.5586 - val_digit2_loss: 3.5341 - val_digit3_loss: 3.5845 - val_digit4_loss: 3.5189 - val_digit0_accuracy: 0.0499 - val_digit1_accuracy: 0.0488 - val_digit2_accuracy: 0.0341 - val_digit3_accuracy: 0.0525 - val_digit4_accuracy: 0.0401
# Epoch 18/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 15.9819 - digit0_loss: 3.1179 - digit1_loss: 3.2618 - digit2_loss: 3.2923 - digit3_loss: 3.2533 - digit4_loss: 3.0426 - digit0_accuracy: 0.1165 - digit1_accuracy: 0.0983 - digit2_accuracy: 0.0952 - digit3_accuracy: 0.0971 - digit4_accuracy: 0.1318 - val_loss: 17.3391 - val_digit0_loss: 3.4560 - val_digit1_loss: 3.4698 - val_digit2_loss: 3.5090 - val_digit3_loss: 3.5567 - val_digit4_loss: 3.4512 - val_digit0_accuracy: 0.0927 - val_digit1_accuracy: 0.1059 - val_digit2_accuracy: 0.1041 - val_digit3_accuracy: 0.0699 - val_digit4_accuracy: 0.0966
# Epoch 19/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 15.7942 - digit0_loss: 3.0462 - digit1_loss: 3.2080 - digit2_loss: 3.2603 - digit3_loss: 3.2103 - digit4_loss: 2.9832 - digit0_accuracy: 0.1264 - digit1_accuracy: 0.1028 - digit2_accuracy: 0.1008 - digit3_accuracy: 0.1019 - digit4_accuracy: 0.1423 - val_loss: 17.5386 - val_digit0_loss: 3.4975 - val_digit1_loss: 3.5129 - val_digit2_loss: 3.5213 - val_digit3_loss: 3.5979 - val_digit4_loss: 3.4712 - val_digit0_accuracy: 0.0524 - val_digit1_accuracy: 0.0541 - val_digit2_accuracy: 0.0282 - val_digit3_accuracy: 0.0314 - val_digit4_accuracy: 0.0437
# Epoch 20/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 15.6530 - digit0_loss: 3.0287 - digit1_loss: 3.2191 - digit2_loss: 3.2540 - digit3_loss: 3.2027 - digit4_loss: 2.9711 - digit0_accuracy: 0.1308 - digit1_accuracy: 0.1063 - digit2_accuracy: 0.1028 - digit3_accuracy: 0.1076 - digit4_accuracy: 0.1450 - val_loss: 17.2753 - val_digit0_loss: 3.4426 - val_digit1_loss: 3.4655 - val_digit2_loss: 3.4844 - val_digit3_loss: 3.5195 - val_digit4_loss: 3.4236 - val_digit0_accuracy: 0.1221 - val_digit1_accuracy: 0.0990 - val_digit2_accuracy: 0.0795 - val_digit3_accuracy: 0.0899 - val_digit4_accuracy: 0.1628
# Epoch 21/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 15.4717 - digit0_loss: 2.9528 - digit1_loss: 3.1803 - digit2_loss: 3.2208 - digit3_loss: 3.1680 - digit4_loss: 2.9022 - digit0_accuracy: 0.1395 - digit1_accuracy: 0.1106 - digit2_accuracy: 0.1092 - digit3_accuracy: 0.1104 - digit4_accuracy: 0.1572 - val_loss: 17.5973 - val_digit0_loss: 3.4982 - val_digit1_loss: 3.5023 - val_digit2_loss: 3.5437 - val_digit3_loss: 3.5904 - val_digit4_loss: 3.4863 - val_digit0_accuracy: 0.0445 - val_digit1_accuracy: 0.0449 - val_digit2_accuracy: 0.0286 - val_digit3_accuracy: 0.0373 - val_digit4_accuracy: 0.0384
# Epoch 22/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 15.3085 - digit0_loss: 2.9164 - digit1_loss: 3.1711 - digit2_loss: 3.1568 - digit3_loss: 3.1408 - digit4_loss: 2.9224 - digit0_accuracy: 0.1422 - digit1_accuracy: 0.1160 - digit2_accuracy: 0.1121 - digit3_accuracy: 0.1170 - digit4_accuracy: 0.1583 - val_loss: 17.4257 - val_digit0_loss: 3.4680 - val_digit1_loss: 3.4668 - val_digit2_loss: 3.4962 - val_digit3_loss: 3.5750 - val_digit4_loss: 3.4287 - val_digit0_accuracy: 0.0503 - val_digit1_accuracy: 0.0520 - val_digit2_accuracy: 0.0292 - val_digit3_accuracy: 0.0445 - val_digit4_accuracy: 0.0518
# Epoch 23/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 15.1434 - digit0_loss: 2.9020 - digit1_loss: 3.1032 - digit2_loss: 3.1424 - digit3_loss: 3.0933 - digit4_loss: 2.8299 - digit0_accuracy: 0.1482 - digit1_accuracy: 0.1197 - digit2_accuracy: 0.1145 - digit3_accuracy: 0.1199 - digit4_accuracy: 0.1688 - val_loss: 17.4459 - val_digit0_loss: 3.4480 - val_digit1_loss: 3.4825 - val_digit2_loss: 3.5019 - val_digit3_loss: 3.5924 - val_digit4_loss: 3.4366 - val_digit0_accuracy: 0.0470 - val_digit1_accuracy: 0.0431 - val_digit2_accuracy: 0.0280 - val_digit3_accuracy: 0.0311 - val_digit4_accuracy: 0.0432
# Epoch 24/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.9911 - digit0_loss: 2.8428 - digit1_loss: 3.1054 - digit2_loss: 3.1283 - digit3_loss: 3.0666 - digit4_loss: 2.7501 - digit0_accuracy: 0.1553 - digit1_accuracy: 0.1219 - digit2_accuracy: 0.1158 - digit3_accuracy: 0.1273 - digit4_accuracy: 0.1768 - val_loss: 17.6100 - val_digit0_loss: 3.4710 - val_digit1_loss: 3.5220 - val_digit2_loss: 3.5456 - val_digit3_loss: 3.6098 - val_digit4_loss: 3.5044 - val_digit0_accuracy: 0.0423 - val_digit1_accuracy: 0.0436 - val_digit2_accuracy: 0.0277 - val_digit3_accuracy: 0.0288 - val_digit4_accuracy: 0.0467
# Epoch 25/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.9005 - digit0_loss: 2.8325 - digit1_loss: 3.0738 - digit2_loss: 3.1455 - digit3_loss: 3.0575 - digit4_loss: 2.7478 - digit0_accuracy: 0.1605 - digit1_accuracy: 0.1263 - digit2_accuracy: 0.1207 - digit3_accuracy: 0.1286 - digit4_accuracy: 0.1770 - val_loss: 17.6435 - val_digit0_loss: 3.5321 - val_digit1_loss: 3.4126 - val_digit2_loss: 3.4787 - val_digit3_loss: 3.6949 - val_digit4_loss: 3.4697 - val_digit0_accuracy: 0.0392 - val_digit1_accuracy: 0.0534 - val_digit2_accuracy: 0.0725 - val_digit3_accuracy: 0.0768 - val_digit4_accuracy: 0.0456
# Epoch 26/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.7517 - digit0_loss: 2.7872 - digit1_loss: 3.0899 - digit2_loss: 3.0841 - digit3_loss: 3.0119 - digit4_loss: 2.7324 - digit0_accuracy: 0.1659 - digit1_accuracy: 0.1292 - digit2_accuracy: 0.1264 - digit3_accuracy: 0.1335 - digit4_accuracy: 0.1898 - val_loss: 17.3626 - val_digit0_loss: 3.4570 - val_digit1_loss: 3.3814 - val_digit2_loss: 3.4321 - val_digit3_loss: 3.6173 - val_digit4_loss: 3.4173 - val_digit0_accuracy: 0.0572 - val_digit1_accuracy: 0.0736 - val_digit2_accuracy: 0.0623 - val_digit3_accuracy: 0.0547 - val_digit4_accuracy: 0.0784
# Epoch 27/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.6663 - digit0_loss: 2.8066 - digit1_loss: 3.0390 - digit2_loss: 3.0805 - digit3_loss: 3.0227 - digit4_loss: 2.7082 - digit0_accuracy: 0.1674 - digit1_accuracy: 0.1327 - digit2_accuracy: 0.1282 - digit3_accuracy: 0.1366 - digit4_accuracy: 0.1904 - val_loss: 17.0965 - val_digit0_loss: 3.4139 - val_digit1_loss: 3.4025 - val_digit2_loss: 3.3967 - val_digit3_loss: 3.4996 - val_digit4_loss: 3.3881 - val_digit0_accuracy: 0.0833 - val_digit1_accuracy: 0.0611 - val_digit2_accuracy: 0.0791 - val_digit3_accuracy: 0.0742 - val_digit4_accuracy: 0.0551
# Epoch 28/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.6924 - digit0_loss: 2.7581 - digit1_loss: 3.0651 - digit2_loss: 3.0902 - digit3_loss: 3.0127 - digit4_loss: 2.7447 - digit0_accuracy: 0.1680 - digit1_accuracy: 0.1271 - digit2_accuracy: 0.1249 - digit3_accuracy: 0.1350 - digit4_accuracy: 0.1909 - val_loss: 16.7830 - val_digit0_loss: 3.3709 - val_digit1_loss: 3.3928 - val_digit2_loss: 3.3530 - val_digit3_loss: 3.5115 - val_digit4_loss: 3.2952 - val_digit0_accuracy: 0.0707 - val_digit1_accuracy: 0.0466 - val_digit2_accuracy: 0.0806 - val_digit3_accuracy: 0.0438 - val_digit4_accuracy: 0.1464
# Epoch 29/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.5013 - digit0_loss: 2.7523 - digit1_loss: 3.0487 - digit2_loss: 3.0985 - digit3_loss: 2.9685 - digit4_loss: 2.6561 - digit0_accuracy: 0.1746 - digit1_accuracy: 0.1331 - digit2_accuracy: 0.1306 - digit3_accuracy: 0.1397 - digit4_accuracy: 0.1977 - val_loss: 17.0241 - val_digit0_loss: 3.4169 - val_digit1_loss: 3.3332 - val_digit2_loss: 3.4135 - val_digit3_loss: 3.6154 - val_digit4_loss: 3.3974 - val_digit0_accuracy: 0.0654 - val_digit1_accuracy: 0.0701 - val_digit2_accuracy: 0.0658 - val_digit3_accuracy: 0.0674 - val_digit4_accuracy: 0.0804
# Epoch 30/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 14.3591 - digit0_loss: 2.6972 - digit1_loss: 2.9959 - digit2_loss: 3.0375 - digit3_loss: 2.9945 - digit4_loss: 2.6833 - digit0_accuracy: 0.1821 - digit1_accuracy: 0.1371 - digit2_accuracy: 0.1370 - digit3_accuracy: 0.1465 - digit4_accuracy: 0.2081 - val_loss: 16.7308 - val_digit0_loss: 3.3643 - val_digit1_loss: 3.3442 - val_digit2_loss: 3.4648 - val_digit3_loss: 3.4500 - val_digit4_loss: 3.3822 - val_digit0_accuracy: 0.1046 - val_digit1_accuracy: 0.0758 - val_digit2_accuracy: 0.0532 - val_digit3_accuracy: 0.0685 - val_digit4_accuracy: 0.0833
# Epoch 31/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 14.2459 - digit0_loss: 2.6239 - digit1_loss: 2.9720 - digit2_loss: 3.0120 - digit3_loss: 2.9279 - digit4_loss: 2.5670 - digit0_accuracy: 0.1876 - digit1_accuracy: 0.1395 - digit2_accuracy: 0.1401 - digit3_accuracy: 0.1492 - digit4_accuracy: 0.2146 - val_loss: 16.7984 - val_digit0_loss: 3.3281 - val_digit1_loss: 3.3440 - val_digit2_loss: 3.4499 - val_digit3_loss: 3.4379 - val_digit4_loss: 3.3805 - val_digit0_accuracy: 0.0759 - val_digit1_accuracy: 0.0497 - val_digit2_accuracy: 0.0399 - val_digit3_accuracy: 0.0729 - val_digit4_accuracy: 0.0602
# Epoch 32/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 14.1160 - digit0_loss: 2.6162 - digit1_loss: 2.9624 - digit2_loss: 3.0061 - digit3_loss: 2.9508 - digit4_loss: 2.5648 - digit0_accuracy: 0.1913 - digit1_accuracy: 0.1458 - digit2_accuracy: 0.1405 - digit3_accuracy: 0.1532 - digit4_accuracy: 0.2234 - val_loss: 17.2317 - val_digit0_loss: 3.4219 - val_digit1_loss: 3.4180 - val_digit2_loss: 3.4752 - val_digit3_loss: 3.4974 - val_digit4_loss: 3.4467 - val_digit0_accuracy: 0.0474 - val_digit1_accuracy: 0.0441 - val_digit2_accuracy: 0.0423 - val_digit3_accuracy: 0.0666 - val_digit4_accuracy: 0.0348
# Epoch 33/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 13.9681 - digit0_loss: 2.5374 - digit1_loss: 2.9670 - digit2_loss: 2.9645 - digit3_loss: 2.9328 - digit4_loss: 2.5155 - digit0_accuracy: 0.1995 - digit1_accuracy: 0.1526 - digit2_accuracy: 0.1456 - digit3_accuracy: 0.1604 - digit4_accuracy: 0.2298 - val_loss: 16.6349 - val_digit0_loss: 3.2073 - val_digit1_loss: 3.2768 - val_digit2_loss: 3.4177 - val_digit3_loss: 3.4631 - val_digit4_loss: 3.3018 - val_digit0_accuracy: 0.1147 - val_digit1_accuracy: 0.1125 - val_digit2_accuracy: 0.0877 - val_digit3_accuracy: 0.0878 - val_digit4_accuracy: 0.1224
# Epoch 34/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 13.9036 - digit0_loss: 2.5464 - digit1_loss: 2.9346 - digit2_loss: 2.9929 - digit3_loss: 2.9077 - digit4_loss: 2.5029 - digit0_accuracy: 0.2045 - digit1_accuracy: 0.1544 - digit2_accuracy: 0.1466 - digit3_accuracy: 0.1598 - digit4_accuracy: 0.2336 - val_loss: 16.4031 - val_digit0_loss: 3.1590 - val_digit1_loss: 3.2688 - val_digit2_loss: 3.3581 - val_digit3_loss: 3.4646 - val_digit4_loss: 3.3701 - val_digit0_accuracy: 0.1142 - val_digit1_accuracy: 0.0858 - val_digit2_accuracy: 0.0971 - val_digit3_accuracy: 0.0651 - val_digit4_accuracy: 0.1195
# Epoch 35/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 13.7795 - digit0_loss: 2.5649 - digit1_loss: 2.9138 - digit2_loss: 2.9271 - digit3_loss: 2.8681 - digit4_loss: 2.4149 - digit0_accuracy: 0.2093 - digit1_accuracy: 0.1565 - digit2_accuracy: 0.1510 - digit3_accuracy: 0.1650 - digit4_accuracy: 0.2415 - val_loss: 18.1615 - val_digit0_loss: 3.4995 - val_digit1_loss: 3.4858 - val_digit2_loss: 3.4575 - val_digit3_loss: 3.8286 - val_digit4_loss: 3.8302 - val_digit0_accuracy: 0.0377 - val_digit1_accuracy: 0.0314 - val_digit2_accuracy: 0.0507 - val_digit3_accuracy: 0.0285 - val_digit4_accuracy: 0.0380
# Epoch 36/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 13.7134 - digit0_loss: 2.5370 - digit1_loss: 2.9041 - digit2_loss: 2.9209 - digit3_loss: 2.8449 - digit4_loss: 2.4363 - digit0_accuracy: 0.2150 - digit1_accuracy: 0.1631 - digit2_accuracy: 0.1540 - digit3_accuracy: 0.1675 - digit4_accuracy: 0.2430 - val_loss: 19.2802 - val_digit0_loss: 3.9987 - val_digit1_loss: 3.6973 - val_digit2_loss: 3.6506 - val_digit3_loss: 3.8619 - val_digit4_loss: 3.9099 - val_digit0_accuracy: 0.0711 - val_digit1_accuracy: 0.0407 - val_digit2_accuracy: 0.0315 - val_digit3_accuracy: 0.0429 - val_digit4_accuracy: 0.0356
# Epoch 37/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 13.5664 - digit0_loss: 2.4955 - digit1_loss: 2.9369 - digit2_loss: 2.9555 - digit3_loss: 2.8141 - digit4_loss: 2.3679 - digit0_accuracy: 0.2202 - digit1_accuracy: 0.1644 - digit2_accuracy: 0.1562 - digit3_accuracy: 0.1729 - digit4_accuracy: 0.2573 - val_loss: 16.2690 - val_digit0_loss: 3.1123 - val_digit1_loss: 3.2581 - val_digit2_loss: 3.6201 - val_digit3_loss: 3.4061 - val_digit4_loss: 3.0119 - val_digit0_accuracy: 0.1624 - val_digit1_accuracy: 0.0967 - val_digit2_accuracy: 0.0474 - val_digit3_accuracy: 0.0709 - val_digit4_accuracy: 0.1440
# Epoch 38/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.8971 - digit0_loss: 2.6227 - digit1_loss: 2.8899 - digit2_loss: 2.9778 - digit3_loss: 2.9507 - digit4_loss: 2.5296 - digit0_accuracy: 0.2038 - digit1_accuracy: 0.1592 - digit2_accuracy: 0.1520 - digit3_accuracy: 0.1637 - digit4_accuracy: 0.2322 - val_loss: 17.1032 - val_digit0_loss: 3.2980 - val_digit1_loss: 3.5626 - val_digit2_loss: 3.6668 - val_digit3_loss: 3.4547 - val_digit4_loss: 3.4956 - val_digit0_accuracy: 0.0945 - val_digit1_accuracy: 0.0704 - val_digit2_accuracy: 0.0426 - val_digit3_accuracy: 0.0517 - val_digit4_accuracy: 0.0584
# Epoch 39/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.7662 - digit0_loss: 2.5365 - digit1_loss: 2.9421 - digit2_loss: 2.9670 - digit3_loss: 2.8556 - digit4_loss: 2.4410 - digit0_accuracy: 0.2109 - digit1_accuracy: 0.1568 - digit2_accuracy: 0.1558 - digit3_accuracy: 0.1677 - digit4_accuracy: 0.2441 - val_loss: 16.1236 - val_digit0_loss: 3.2677 - val_digit1_loss: 3.3650 - val_digit2_loss: 3.2729 - val_digit3_loss: 3.3795 - val_digit4_loss: 3.2408 - val_digit0_accuracy: 0.0821 - val_digit1_accuracy: 0.0787 - val_digit2_accuracy: 0.0762 - val_digit3_accuracy: 0.0786 - val_digit4_accuracy: 0.0808
# Epoch 40/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.6051 - digit0_loss: 2.5224 - digit1_loss: 2.8615 - digit2_loss: 2.9536 - digit3_loss: 2.8068 - digit4_loss: 2.4082 - digit0_accuracy: 0.2228 - digit1_accuracy: 0.1643 - digit2_accuracy: 0.1582 - digit3_accuracy: 0.1748 - digit4_accuracy: 0.2556 - val_loss: 22.4313 - val_digit0_loss: 4.4020 - val_digit1_loss: 4.9948 - val_digit2_loss: 4.4639 - val_digit3_loss: 4.3130 - val_digit4_loss: 5.2071 - val_digit0_accuracy: 0.0511 - val_digit1_accuracy: 0.0306 - val_digit2_accuracy: 0.0291 - val_digit3_accuracy: 0.0483 - val_digit4_accuracy: 0.0512
# Epoch 41/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.4649 - digit0_loss: 2.4559 - digit1_loss: 2.8412 - digit2_loss: 2.9024 - digit3_loss: 2.8216 - digit4_loss: 2.4078 - digit0_accuracy: 0.2313 - digit1_accuracy: 0.1679 - digit2_accuracy: 0.1600 - digit3_accuracy: 0.1775 - digit4_accuracy: 0.2636 - val_loss: 20.4489 - val_digit0_loss: 4.0594 - val_digit1_loss: 3.9972 - val_digit2_loss: 3.9334 - val_digit3_loss: 4.2388 - val_digit4_loss: 4.5293 - val_digit0_accuracy: 0.0525 - val_digit1_accuracy: 0.0430 - val_digit2_accuracy: 0.0325 - val_digit3_accuracy: 0.0589 - val_digit4_accuracy: 0.0326
# Epoch 42/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.3538 - digit0_loss: 2.4847 - digit1_loss: 2.8679 - digit2_loss: 2.8955 - digit3_loss: 2.7596 - digit4_loss: 2.3359 - digit0_accuracy: 0.2354 - digit1_accuracy: 0.1719 - digit2_accuracy: 0.1643 - digit3_accuracy: 0.1835 - digit4_accuracy: 0.2708 - val_loss: 18.2799 - val_digit0_loss: 3.5487 - val_digit1_loss: 3.7422 - val_digit2_loss: 3.6665 - val_digit3_loss: 3.7653 - val_digit4_loss: 3.9953 - val_digit0_accuracy: 0.0854 - val_digit1_accuracy: 0.0646 - val_digit2_accuracy: 0.0475 - val_digit3_accuracy: 0.0372 - val_digit4_accuracy: 0.0720
# Epoch 43/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 13.2394 - digit0_loss: 2.4064 - digit1_loss: 2.8310 - digit2_loss: 2.8881 - digit3_loss: 2.7913 - digit4_loss: 2.3692 - digit0_accuracy: 0.2415 - digit1_accuracy: 0.1759 - digit2_accuracy: 0.1696 - digit3_accuracy: 0.1859 - digit4_accuracy: 0.2768 - val_loss: 17.2882 - val_digit0_loss: 3.4176 - val_digit1_loss: 3.5115 - val_digit2_loss: 3.4698 - val_digit3_loss: 3.4282 - val_digit4_loss: 3.7528 - val_digit0_accuracy: 0.1006 - val_digit1_accuracy: 0.0744 - val_digit2_accuracy: 0.0879 - val_digit3_accuracy: 0.0827 - val_digit4_accuracy: 0.0928
# Epoch 44/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 13.1322 - digit0_loss: 2.3708 - digit1_loss: 2.7875 - digit2_loss: 2.8543 - digit3_loss: 2.7485 - digit4_loss: 2.3065 - digit0_accuracy: 0.2445 - digit1_accuracy: 0.1786 - digit2_accuracy: 0.1726 - digit3_accuracy: 0.1906 - digit4_accuracy: 0.2846 - val_loss: 15.7031 - val_digit0_loss: 2.9774 - val_digit1_loss: 3.1077 - val_digit2_loss: 3.2478 - val_digit3_loss: 3.3455 - val_digit4_loss: 3.0089 - val_digit0_accuracy: 0.1407 - val_digit1_accuracy: 0.0999 - val_digit2_accuracy: 0.0916 - val_digit3_accuracy: 0.0803 - val_digit4_accuracy: 0.0956
# Epoch 45/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 13.0267 - digit0_loss: 2.4108 - digit1_loss: 2.7916 - digit2_loss: 2.8649 - digit3_loss: 2.7826 - digit4_loss: 2.2590 - digit0_accuracy: 0.2482 - digit1_accuracy: 0.1821 - digit2_accuracy: 0.1750 - digit3_accuracy: 0.1935 - digit4_accuracy: 0.2961 - val_loss: 15.9207 - val_digit0_loss: 2.8923 - val_digit1_loss: 3.1584 - val_digit2_loss: 3.2788 - val_digit3_loss: 3.4388 - val_digit4_loss: 3.1168 - val_digit0_accuracy: 0.1357 - val_digit1_accuracy: 0.0772 - val_digit2_accuracy: 0.1061 - val_digit3_accuracy: 0.0991 - val_digit4_accuracy: 0.1176
# Epoch 46/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 12.9473 - digit0_loss: 2.3645 - digit1_loss: 2.7958 - digit2_loss: 2.8239 - digit3_loss: 2.7289 - digit4_loss: 2.2143 - digit0_accuracy: 0.2554 - digit1_accuracy: 0.1862 - digit2_accuracy: 0.1770 - digit3_accuracy: 0.1942 - digit4_accuracy: 0.2978 - val_loss: 16.7944 - val_digit0_loss: 3.0970 - val_digit1_loss: 3.2658 - val_digit2_loss: 3.5540 - val_digit3_loss: 3.7008 - val_digit4_loss: 3.3486 - val_digit0_accuracy: 0.1172 - val_digit1_accuracy: 0.0673 - val_digit2_accuracy: 0.0967 - val_digit3_accuracy: 0.0754 - val_digit4_accuracy: 0.1107
# Epoch 47/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.8439 - digit0_loss: 2.3498 - digit1_loss: 2.8053 - digit2_loss: 2.8299 - digit3_loss: 2.7175 - digit4_loss: 2.1886 - digit0_accuracy: 0.2637 - digit1_accuracy: 0.1896 - digit2_accuracy: 0.1767 - digit3_accuracy: 0.1979 - digit4_accuracy: 0.3073 - val_loss: 16.4702 - val_digit0_loss: 3.1772 - val_digit1_loss: 3.2205 - val_digit2_loss: 3.2608 - val_digit3_loss: 3.5382 - val_digit4_loss: 3.4545 - val_digit0_accuracy: 0.0810 - val_digit1_accuracy: 0.0447 - val_digit2_accuracy: 0.0714 - val_digit3_accuracy: 0.0494 - val_digit4_accuracy: 0.0468
# Epoch 48/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.7777 - digit0_loss: 2.2648 - digit1_loss: 2.7854 - digit2_loss: 2.8094 - digit3_loss: 2.7820 - digit4_loss: 2.2271 - digit0_accuracy: 0.2618 - digit1_accuracy: 0.1927 - digit2_accuracy: 0.1831 - digit3_accuracy: 0.2036 - digit4_accuracy: 0.3103 - val_loss: 16.9903 - val_digit0_loss: 2.9432 - val_digit1_loss: 3.2305 - val_digit2_loss: 3.6322 - val_digit3_loss: 3.7272 - val_digit4_loss: 3.5601 - val_digit0_accuracy: 0.1353 - val_digit1_accuracy: 0.0956 - val_digit2_accuracy: 0.0751 - val_digit3_accuracy: 0.0759 - val_digit4_accuracy: 0.0973
# Epoch 49/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.7609 - digit0_loss: 2.2971 - digit1_loss: 2.7247 - digit2_loss: 2.7610 - digit3_loss: 2.6920 - digit4_loss: 2.2228 - digit0_accuracy: 0.2643 - digit1_accuracy: 0.1936 - digit2_accuracy: 0.1848 - digit3_accuracy: 0.2021 - digit4_accuracy: 0.3159 - val_loss: 17.8147 - val_digit0_loss: 3.3293 - val_digit1_loss: 3.2605 - val_digit2_loss: 3.3636 - val_digit3_loss: 3.7141 - val_digit4_loss: 4.2641 - val_digit0_accuracy: 0.0718 - val_digit1_accuracy: 0.0545 - val_digit2_accuracy: 0.0689 - val_digit3_accuracy: 0.0596 - val_digit4_accuracy: 0.0353
# Epoch 50/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.6948 - digit0_loss: 2.2719 - digit1_loss: 2.7402 - digit2_loss: 2.8017 - digit3_loss: 2.6734 - digit4_loss: 2.1670 - digit0_accuracy: 0.2705 - digit1_accuracy: 0.1977 - digit2_accuracy: 0.1885 - digit3_accuracy: 0.2072 - digit4_accuracy: 0.3179 - val_loss: 23.5804 - val_digit0_loss: 4.6368 - val_digit1_loss: 4.1651 - val_digit2_loss: 4.2999 - val_digit3_loss: 4.7511 - val_digit4_loss: 5.7602 - val_digit0_accuracy: 0.0431 - val_digit1_accuracy: 0.0306 - val_digit2_accuracy: 0.0302 - val_digit3_accuracy: 0.0326 - val_digit4_accuracy: 0.0293
# Epoch 51/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.5859 - digit0_loss: 2.2530 - digit1_loss: 2.7569 - digit2_loss: 2.8067 - digit3_loss: 2.6706 - digit4_loss: 2.1365 - digit0_accuracy: 0.2789 - digit1_accuracy: 0.2018 - digit2_accuracy: 0.1915 - digit3_accuracy: 0.2120 - digit4_accuracy: 0.3264 - val_loss: 15.5323 - val_digit0_loss: 2.8081 - val_digit1_loss: 3.0585 - val_digit2_loss: 3.4288 - val_digit3_loss: 3.2419 - val_digit4_loss: 3.4436 - val_digit0_accuracy: 0.1443 - val_digit1_accuracy: 0.0938 - val_digit2_accuracy: 0.0878 - val_digit3_accuracy: 0.1020 - val_digit4_accuracy: 0.1000
# Epoch 52/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.4789 - digit0_loss: 2.2241 - digit1_loss: 2.6944 - digit2_loss: 2.7536 - digit3_loss: 2.6266 - digit4_loss: 2.0956 - digit0_accuracy: 0.2899 - digit1_accuracy: 0.2047 - digit2_accuracy: 0.1973 - digit3_accuracy: 0.2123 - digit4_accuracy: 0.3355 - val_loss: 15.8753 - val_digit0_loss: 2.8131 - val_digit1_loss: 3.0856 - val_digit2_loss: 3.4260 - val_digit3_loss: 3.3548 - val_digit4_loss: 3.3553 - val_digit0_accuracy: 0.1421 - val_digit1_accuracy: 0.1035 - val_digit2_accuracy: 0.0917 - val_digit3_accuracy: 0.1057 - val_digit4_accuracy: 0.0854
# Epoch 53/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.4196 - digit0_loss: 2.3120 - digit1_loss: 2.7133 - digit2_loss: 2.7227 - digit3_loss: 2.6713 - digit4_loss: 2.0829 - digit0_accuracy: 0.2884 - digit1_accuracy: 0.2091 - digit2_accuracy: 0.1999 - digit3_accuracy: 0.2160 - digit4_accuracy: 0.3389 - val_loss: 18.8316 - val_digit0_loss: 3.3410 - val_digit1_loss: 3.4186 - val_digit2_loss: 3.9756 - val_digit3_loss: 3.7888 - val_digit4_loss: 4.6616 - val_digit0_accuracy: 0.0807 - val_digit1_accuracy: 0.0432 - val_digit2_accuracy: 0.0485 - val_digit3_accuracy: 0.0427 - val_digit4_accuracy: 0.0371
# Epoch 54/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.3779 - digit0_loss: 2.1873 - digit1_loss: 2.6864 - digit2_loss: 2.7555 - digit3_loss: 2.6710 - digit4_loss: 2.0458 - digit0_accuracy: 0.2926 - digit1_accuracy: 0.2090 - digit2_accuracy: 0.2000 - digit3_accuracy: 0.2198 - digit4_accuracy: 0.3383 - val_loss: 25.5061 - val_digit0_loss: 4.7302 - val_digit1_loss: 4.4478 - val_digit2_loss: 4.5666 - val_digit3_loss: 4.9863 - val_digit4_loss: 6.9184 - val_digit0_accuracy: 0.0415 - val_digit1_accuracy: 0.0309 - val_digit2_accuracy: 0.0309 - val_digit3_accuracy: 0.0282 - val_digit4_accuracy: 0.0304
# Epoch 55/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 12.4477 - digit0_loss: 2.2282 - digit1_loss: 2.6913 - digit2_loss: 2.7517 - digit3_loss: 2.6057 - digit4_loss: 2.0908 - digit0_accuracy: 0.2927 - digit1_accuracy: 0.2088 - digit2_accuracy: 0.2009 - digit3_accuracy: 0.2211 - digit4_accuracy: 0.3345 - val_loss: 18.1964 - val_digit0_loss: 4.2901 - val_digit1_loss: 3.5402 - val_digit2_loss: 4.0237 - val_digit3_loss: 3.5527 - val_digit4_loss: 3.7443 - val_digit0_accuracy: 0.0650 - val_digit1_accuracy: 0.0838 - val_digit2_accuracy: 0.0806 - val_digit3_accuracy: 0.0640 - val_digit4_accuracy: 0.1457
# Epoch 56/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.2725 - digit0_loss: 2.1740 - digit1_loss: 2.6842 - digit2_loss: 2.7309 - digit3_loss: 2.6255 - digit4_loss: 2.0429 - digit0_accuracy: 0.2994 - digit1_accuracy: 0.2140 - digit2_accuracy: 0.2010 - digit3_accuracy: 0.2294 - digit4_accuracy: 0.3516 - val_loss: 16.0710 - val_digit0_loss: 3.3991 - val_digit1_loss: 3.1406 - val_digit2_loss: 3.1144 - val_digit3_loss: 3.4111 - val_digit4_loss: 2.9177 - val_digit0_accuracy: 0.0979 - val_digit1_accuracy: 0.1135 - val_digit2_accuracy: 0.1064 - val_digit3_accuracy: 0.0917 - val_digit4_accuracy: 0.1568
# Epoch 57/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 12.1526 - digit0_loss: 2.1613 - digit1_loss: 2.6495 - digit2_loss: 2.7495 - digit3_loss: 2.5858 - digit4_loss: 2.0119 - digit0_accuracy: 0.3062 - digit1_accuracy: 0.2215 - digit2_accuracy: 0.2060 - digit3_accuracy: 0.2323 - digit4_accuracy: 0.3589 - val_loss: 13.3822 - val_digit0_loss: 2.3311 - val_digit1_loss: 2.7749 - val_digit2_loss: 2.9506 - val_digit3_loss: 2.9244 - val_digit4_loss: 2.6256 - val_digit0_accuracy: 0.2845 - val_digit1_accuracy: 0.1953 - val_digit2_accuracy: 0.1826 - val_digit3_accuracy: 0.1700 - val_digit4_accuracy: 0.2317
# Epoch 58/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 12.0830 - digit0_loss: 2.1196 - digit1_loss: 2.6245 - digit2_loss: 2.7106 - digit3_loss: 2.5941 - digit4_loss: 2.0011 - digit0_accuracy: 0.3120 - digit1_accuracy: 0.2257 - digit2_accuracy: 0.2097 - digit3_accuracy: 0.2309 - digit4_accuracy: 0.3620 - val_loss: 13.8881 - val_digit0_loss: 2.5211 - val_digit1_loss: 2.8811 - val_digit2_loss: 3.1855 - val_digit3_loss: 2.8232 - val_digit4_loss: 3.0465 - val_digit0_accuracy: 0.2423 - val_digit1_accuracy: 0.1711 - val_digit2_accuracy: 0.1416 - val_digit3_accuracy: 0.1987 - val_digit4_accuracy: 0.2013
# Epoch 59/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.9813 - digit0_loss: 2.1183 - digit1_loss: 2.6163 - digit2_loss: 2.6835 - digit3_loss: 2.5312 - digit4_loss: 1.9375 - digit0_accuracy: 0.3188 - digit1_accuracy: 0.2268 - digit2_accuracy: 0.2152 - digit3_accuracy: 0.2364 - digit4_accuracy: 0.3674 - val_loss: 13.3802 - val_digit0_loss: 2.3118 - val_digit1_loss: 2.7556 - val_digit2_loss: 2.9710 - val_digit3_loss: 2.9360 - val_digit4_loss: 2.7454 - val_digit0_accuracy: 0.2366 - val_digit1_accuracy: 0.1826 - val_digit2_accuracy: 0.1501 - val_digit3_accuracy: 0.1758 - val_digit4_accuracy: 0.2268
# Epoch 60/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 11.9166 - digit0_loss: 2.1152 - digit1_loss: 2.6883 - digit2_loss: 2.7182 - digit3_loss: 2.5346 - digit4_loss: 1.9091 - digit0_accuracy: 0.3236 - digit1_accuracy: 0.2278 - digit2_accuracy: 0.2158 - digit3_accuracy: 0.2406 - digit4_accuracy: 0.3758 - val_loss: 14.4396 - val_digit0_loss: 2.5741 - val_digit1_loss: 3.0041 - val_digit2_loss: 3.4385 - val_digit3_loss: 2.8751 - val_digit4_loss: 3.5120 - val_digit0_accuracy: 0.2051 - val_digit1_accuracy: 0.0974 - val_digit2_accuracy: 0.0755 - val_digit3_accuracy: 0.1519 - val_digit4_accuracy: 0.2263
# Epoch 61/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.9033 - digit0_loss: 2.0729 - digit1_loss: 2.6410 - digit2_loss: 2.6770 - digit3_loss: 2.5392 - digit4_loss: 1.9244 - digit0_accuracy: 0.3227 - digit1_accuracy: 0.2295 - digit2_accuracy: 0.2165 - digit3_accuracy: 0.2454 - digit4_accuracy: 0.3760 - val_loss: 12.9927 - val_digit0_loss: 2.2920 - val_digit1_loss: 2.8058 - val_digit2_loss: 3.0535 - val_digit3_loss: 2.7934 - val_digit4_loss: 2.5222 - val_digit0_accuracy: 0.2738 - val_digit1_accuracy: 0.1581 - val_digit2_accuracy: 0.1440 - val_digit3_accuracy: 0.2065 - val_digit4_accuracy: 0.2863
# Epoch 62/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.8341 - digit0_loss: 2.1054 - digit1_loss: 2.6439 - digit2_loss: 2.6827 - digit3_loss: 2.6175 - digit4_loss: 1.9735 - digit0_accuracy: 0.3270 - digit1_accuracy: 0.2337 - digit2_accuracy: 0.2225 - digit3_accuracy: 0.2468 - digit4_accuracy: 0.3799 - val_loss: 16.2446 - val_digit0_loss: 2.7401 - val_digit1_loss: 3.1289 - val_digit2_loss: 3.3870 - val_digit3_loss: 3.4663 - val_digit4_loss: 4.0066 - val_digit0_accuracy: 0.1614 - val_digit1_accuracy: 0.0919 - val_digit2_accuracy: 0.1351 - val_digit3_accuracy: 0.1046 - val_digit4_accuracy: 0.1188
# Epoch 63/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.8053 - digit0_loss: 2.0971 - digit1_loss: 2.6231 - digit2_loss: 2.6904 - digit3_loss: 2.5471 - digit4_loss: 1.9414 - digit0_accuracy: 0.3305 - digit1_accuracy: 0.2346 - digit2_accuracy: 0.2219 - digit3_accuracy: 0.2505 - digit4_accuracy: 0.3843 - val_loss: 15.3591 - val_digit0_loss: 2.5393 - val_digit1_loss: 2.9512 - val_digit2_loss: 3.4386 - val_digit3_loss: 3.2514 - val_digit4_loss: 3.8046 - val_digit0_accuracy: 0.1749 - val_digit1_accuracy: 0.1108 - val_digit2_accuracy: 0.1437 - val_digit3_accuracy: 0.1545 - val_digit4_accuracy: 0.1286
# Epoch 64/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.7228 - digit0_loss: 2.0423 - digit1_loss: 2.6143 - digit2_loss: 2.7052 - digit3_loss: 2.4949 - digit4_loss: 1.9028 - digit0_accuracy: 0.3371 - digit1_accuracy: 0.2345 - digit2_accuracy: 0.2247 - digit3_accuracy: 0.2543 - digit4_accuracy: 0.3946 - val_loss: 18.6545 - val_digit0_loss: 3.4177 - val_digit1_loss: 3.4682 - val_digit2_loss: 4.1683 - val_digit3_loss: 3.6344 - val_digit4_loss: 4.8181 - val_digit0_accuracy: 0.1340 - val_digit1_accuracy: 0.0790 - val_digit2_accuracy: 0.1006 - val_digit3_accuracy: 0.1223 - val_digit4_accuracy: 0.1123
# Epoch 65/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.6317 - digit0_loss: 2.0131 - digit1_loss: 2.5479 - digit2_loss: 2.6627 - digit3_loss: 2.5319 - digit4_loss: 1.8327 - digit0_accuracy: 0.3414 - digit1_accuracy: 0.2415 - digit2_accuracy: 0.2309 - digit3_accuracy: 0.2540 - digit4_accuracy: 0.3997 - val_loss: 18.6805 - val_digit0_loss: 3.1476 - val_digit1_loss: 3.2958 - val_digit2_loss: 4.0235 - val_digit3_loss: 3.5628 - val_digit4_loss: 5.2454 - val_digit0_accuracy: 0.1473 - val_digit1_accuracy: 0.0970 - val_digit2_accuracy: 0.1007 - val_digit3_accuracy: 0.1179 - val_digit4_accuracy: 0.1279
# Epoch 66/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 11.5560 - digit0_loss: 2.0255 - digit1_loss: 2.5470 - digit2_loss: 2.6353 - digit3_loss: 2.5075 - digit4_loss: 1.8498 - digit0_accuracy: 0.3478 - digit1_accuracy: 0.2451 - digit2_accuracy: 0.2319 - digit3_accuracy: 0.2564 - digit4_accuracy: 0.4025 - val_loss: 24.9260 - val_digit0_loss: 4.1873 - val_digit1_loss: 4.0658 - val_digit2_loss: 4.7801 - val_digit3_loss: 4.9586 - val_digit4_loss: 7.6136 - val_digit0_accuracy: 0.0878 - val_digit1_accuracy: 0.0478 - val_digit2_accuracy: 0.0826 - val_digit3_accuracy: 0.0480 - val_digit4_accuracy: 0.0591
# Epoch 67/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 11.5029 - digit0_loss: 2.0058 - digit1_loss: 2.5463 - digit2_loss: 2.6352 - digit3_loss: 2.5249 - digit4_loss: 1.8439 - digit0_accuracy: 0.3543 - digit1_accuracy: 0.2481 - digit2_accuracy: 0.2338 - digit3_accuracy: 0.2610 - digit4_accuracy: 0.4065 - val_loss: 20.8136 - val_digit0_loss: 4.5682 - val_digit1_loss: 3.6437 - val_digit2_loss: 4.4662 - val_digit3_loss: 3.9290 - val_digit4_loss: 5.4050 - val_digit0_accuracy: 0.1375 - val_digit1_accuracy: 0.1167 - val_digit2_accuracy: 0.0950 - val_digit3_accuracy: 0.1072 - val_digit4_accuracy: 0.1249
# Epoch 68/500
# ...
# Epoch 476/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 6.6468 - digit0_loss: 0.9207 - digit1_loss: 1.5700 - digit2_loss: 1.7469 - digit3_loss: 1.4962 - digit4_loss: 0.8542 - digit0_accuracy: 0.6829 - digit1_accuracy: 0.5101 - digit2_accuracy: 0.4910 - digit3_accuracy: 0.5329 - digit4_accuracy: 0.7073 - val_loss: 5.4845 - val_digit0_loss: 0.7196 - val_digit1_loss: 1.4462 - val_digit2_loss: 1.5841 - val_digit3_loss: 1.1841 - val_digit4_loss: 0.7229 - val_digit0_accuracy: 0.7192 - val_digit1_accuracy: 0.6059 - val_digit2_accuracy: 0.5818 - val_digit3_accuracy: 0.6146 - val_digit4_accuracy: 0.7648
# Epoch 477/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.6181 - digit0_loss: 0.9143 - digit1_loss: 1.6071 - digit2_loss: 1.7325 - digit3_loss: 1.5299 - digit4_loss: 0.8378 - digit0_accuracy: 0.6883 - digit1_accuracy: 0.5141 - digit2_accuracy: 0.4932 - digit3_accuracy: 0.5334 - digit4_accuracy: 0.7145 - val_loss: 5.4918 - val_digit0_loss: 0.7662 - val_digit1_loss: 1.5511 - val_digit2_loss: 1.5328 - val_digit3_loss: 1.1676 - val_digit4_loss: 0.7061 - val_digit0_accuracy: 0.7449 - val_digit1_accuracy: 0.6134 - val_digit2_accuracy: 0.5958 - val_digit3_accuracy: 0.6432 - val_digit4_accuracy: 0.7632
# Epoch 478/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.6256 - digit0_loss: 0.9728 - digit1_loss: 1.5944 - digit2_loss: 1.6908 - digit3_loss: 1.5502 - digit4_loss: 0.8429 - digit0_accuracy: 0.6858 - digit1_accuracy: 0.5104 - digit2_accuracy: 0.4871 - digit3_accuracy: 0.5323 - digit4_accuracy: 0.7118 - val_loss: 5.8166 - val_digit0_loss: 0.8611 - val_digit1_loss: 1.5814 - val_digit2_loss: 1.5868 - val_digit3_loss: 1.2094 - val_digit4_loss: 0.8306 - val_digit0_accuracy: 0.7188 - val_digit1_accuracy: 0.5997 - val_digit2_accuracy: 0.5883 - val_digit3_accuracy: 0.6201 - val_digit4_accuracy: 0.7379
# Epoch 479/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.6171 - digit0_loss: 0.9591 - digit1_loss: 1.6369 - digit2_loss: 1.7960 - digit3_loss: 1.5408 - digit4_loss: 0.8067 - digit0_accuracy: 0.6872 - digit1_accuracy: 0.5123 - digit2_accuracy: 0.4871 - digit3_accuracy: 0.5353 - digit4_accuracy: 0.7137 - val_loss: 9.3929 - val_digit0_loss: 1.8971 - val_digit1_loss: 2.1990 - val_digit2_loss: 2.1464 - val_digit3_loss: 1.5038 - val_digit4_loss: 2.8111 - val_digit0_accuracy: 0.5312 - val_digit1_accuracy: 0.4288 - val_digit2_accuracy: 0.3942 - val_digit3_accuracy: 0.4824 - val_digit4_accuracy: 0.5286
# Epoch 480/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.6645 - digit0_loss: 0.9896 - digit1_loss: 1.6866 - digit2_loss: 1.6923 - digit3_loss: 1.5075 - digit4_loss: 0.8488 - digit0_accuracy: 0.6834 - digit1_accuracy: 0.5097 - digit2_accuracy: 0.4873 - digit3_accuracy: 0.5314 - digit4_accuracy: 0.7082 - val_loss: 7.9773 - val_digit0_loss: 1.8578 - val_digit1_loss: 1.9371 - val_digit2_loss: 1.7803 - val_digit3_loss: 1.4682 - val_digit4_loss: 1.6262 - val_digit0_accuracy: 0.6047 - val_digit1_accuracy: 0.5099 - val_digit2_accuracy: 0.4967 - val_digit3_accuracy: 0.5075 - val_digit4_accuracy: 0.5604
# Epoch 481/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.7093 - digit0_loss: 0.9387 - digit1_loss: 1.6881 - digit2_loss: 1.8324 - digit3_loss: 1.5766 - digit4_loss: 0.9085 - digit0_accuracy: 0.6800 - digit1_accuracy: 0.5097 - digit2_accuracy: 0.4865 - digit3_accuracy: 0.5307 - digit4_accuracy: 0.7032 - val_loss: 7.3303 - val_digit0_loss: 0.9788 - val_digit1_loss: 1.5164 - val_digit2_loss: 1.8527 - val_digit3_loss: 1.3869 - val_digit4_loss: 1.8541 - val_digit0_accuracy: 0.6466 - val_digit1_accuracy: 0.5337 - val_digit2_accuracy: 0.5188 - val_digit3_accuracy: 0.5440 - val_digit4_accuracy: 0.6106
# Epoch 482/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.6388 - digit0_loss: 0.9452 - digit1_loss: 1.5979 - digit2_loss: 1.7735 - digit3_loss: 1.4665 - digit4_loss: 0.8497 - digit0_accuracy: 0.6847 - digit1_accuracy: 0.5132 - digit2_accuracy: 0.4900 - digit3_accuracy: 0.5341 - digit4_accuracy: 0.7094 - val_loss: 5.4829 - val_digit0_loss: 0.8297 - val_digit1_loss: 1.4571 - val_digit2_loss: 1.5655 - val_digit3_loss: 1.0925 - val_digit4_loss: 0.6529 - val_digit0_accuracy: 0.7311 - val_digit1_accuracy: 0.6180 - val_digit2_accuracy: 0.5857 - val_digit3_accuracy: 0.6302 - val_digit4_accuracy: 0.7469
# Epoch 483/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5890 - digit0_loss: 0.8835 - digit1_loss: 1.5586 - digit2_loss: 1.7212 - digit3_loss: 1.5073 - digit4_loss: 0.8921 - digit0_accuracy: 0.6890 - digit1_accuracy: 0.5185 - digit2_accuracy: 0.4927 - digit3_accuracy: 0.5337 - digit4_accuracy: 0.7146 - val_loss: 5.1677 - val_digit0_loss: 0.6699 - val_digit1_loss: 1.3129 - val_digit2_loss: 1.5113 - val_digit3_loss: 1.1284 - val_digit4_loss: 0.6295 - val_digit0_accuracy: 0.7609 - val_digit1_accuracy: 0.6397 - val_digit2_accuracy: 0.6119 - val_digit3_accuracy: 0.6358 - val_digit4_accuracy: 0.7817
# Epoch 484/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5781 - digit0_loss: 0.9127 - digit1_loss: 1.5529 - digit2_loss: 1.7599 - digit3_loss: 1.5164 - digit4_loss: 0.8377 - digit0_accuracy: 0.6887 - digit1_accuracy: 0.5174 - digit2_accuracy: 0.4902 - digit3_accuracy: 0.5351 - digit4_accuracy: 0.7177 - val_loss: 7.5547 - val_digit0_loss: 1.0374 - val_digit1_loss: 1.5548 - val_digit2_loss: 2.0035 - val_digit3_loss: 1.6666 - val_digit4_loss: 1.5810 - val_digit0_accuracy: 0.6281 - val_digit1_accuracy: 0.5419 - val_digit2_accuracy: 0.5085 - val_digit3_accuracy: 0.5626 - val_digit4_accuracy: 0.6534
# Epoch 485/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5879 - digit0_loss: 0.9055 - digit1_loss: 1.6446 - digit2_loss: 1.7939 - digit3_loss: 1.4621 - digit4_loss: 0.9115 - digit0_accuracy: 0.6902 - digit1_accuracy: 0.5161 - digit2_accuracy: 0.4882 - digit3_accuracy: 0.5352 - digit4_accuracy: 0.7118 - val_loss: 9.6791 - val_digit0_loss: 1.4054 - val_digit1_loss: 1.7694 - val_digit2_loss: 2.3056 - val_digit3_loss: 1.8449 - val_digit4_loss: 3.1648 - val_digit0_accuracy: 0.5533 - val_digit1_accuracy: 0.4813 - val_digit2_accuracy: 0.4468 - val_digit3_accuracy: 0.5086 - val_digit4_accuracy: 0.5211
# Epoch 486/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5972 - digit0_loss: 0.9130 - digit1_loss: 1.6629 - digit2_loss: 1.7148 - digit3_loss: 1.5046 - digit4_loss: 0.8283 - digit0_accuracy: 0.6896 - digit1_accuracy: 0.5155 - digit2_accuracy: 0.4912 - digit3_accuracy: 0.5363 - digit4_accuracy: 0.7129 - val_loss: 6.2168 - val_digit0_loss: 0.8671 - val_digit1_loss: 1.4820 - val_digit2_loss: 1.7412 - val_digit3_loss: 1.2858 - val_digit4_loss: 1.1441 - val_digit0_accuracy: 0.6782 - val_digit1_accuracy: 0.5725 - val_digit2_accuracy: 0.5246 - val_digit3_accuracy: 0.5987 - val_digit4_accuracy: 0.7012
# Epoch 487/500
# 80023/80023 [==============================] - 4s 45us/step - loss: 6.5887 - digit0_loss: 0.9069 - digit1_loss: 1.5912 - digit2_loss: 1.6725 - digit3_loss: 1.4741 - digit4_loss: 0.8427 - digit0_accuracy: 0.6882 - digit1_accuracy: 0.5112 - digit2_accuracy: 0.4921 - digit3_accuracy: 0.5348 - digit4_accuracy: 0.7125 - val_loss: 5.7600 - val_digit0_loss: 0.7397 - val_digit1_loss: 1.4244 - val_digit2_loss: 1.6548 - val_digit3_loss: 1.2679 - val_digit4_loss: 0.9064 - val_digit0_accuracy: 0.7024 - val_digit1_accuracy: 0.5896 - val_digit2_accuracy: 0.5651 - val_digit3_accuracy: 0.6113 - val_digit4_accuracy: 0.7298
# Epoch 488/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5440 - digit0_loss: 0.9054 - digit1_loss: 1.5986 - digit2_loss: 1.6805 - digit3_loss: 1.5332 - digit4_loss: 0.8724 - digit0_accuracy: 0.6929 - digit1_accuracy: 0.5173 - digit2_accuracy: 0.4903 - digit3_accuracy: 0.5360 - digit4_accuracy: 0.7172 - val_loss: 5.6632 - val_digit0_loss: 0.7163 - val_digit1_loss: 1.4646 - val_digit2_loss: 1.6143 - val_digit3_loss: 1.2174 - val_digit4_loss: 0.7913 - val_digit0_accuracy: 0.7335 - val_digit1_accuracy: 0.5970 - val_digit2_accuracy: 0.5783 - val_digit3_accuracy: 0.6068 - val_digit4_accuracy: 0.7348
# Epoch 489/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5625 - digit0_loss: 0.9307 - digit1_loss: 1.6104 - digit2_loss: 1.7284 - digit3_loss: 1.4402 - digit4_loss: 0.8324 - digit0_accuracy: 0.6898 - digit1_accuracy: 0.5128 - digit2_accuracy: 0.4902 - digit3_accuracy: 0.5363 - digit4_accuracy: 0.7148 - val_loss: 6.0307 - val_digit0_loss: 0.8558 - val_digit1_loss: 1.4797 - val_digit2_loss: 1.6258 - val_digit3_loss: 1.2832 - val_digit4_loss: 0.9547 - val_digit0_accuracy: 0.6880 - val_digit1_accuracy: 0.5972 - val_digit2_accuracy: 0.5818 - val_digit3_accuracy: 0.6127 - val_digit4_accuracy: 0.7111
# Epoch 490/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5982 - digit0_loss: 0.9378 - digit1_loss: 1.5387 - digit2_loss: 1.7030 - digit3_loss: 1.5335 - digit4_loss: 0.8400 - digit0_accuracy: 0.6873 - digit1_accuracy: 0.5157 - digit2_accuracy: 0.4896 - digit3_accuracy: 0.5371 - digit4_accuracy: 0.7092 - val_loss: 5.4606 - val_digit0_loss: 0.7604 - val_digit1_loss: 1.5508 - val_digit2_loss: 1.5953 - val_digit3_loss: 1.2285 - val_digit4_loss: 0.6183 - val_digit0_accuracy: 0.7451 - val_digit1_accuracy: 0.6036 - val_digit2_accuracy: 0.5908 - val_digit3_accuracy: 0.6282 - val_digit4_accuracy: 0.7652
# Epoch 491/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5612 - digit0_loss: 0.8986 - digit1_loss: 1.5157 - digit2_loss: 1.7071 - digit3_loss: 1.4741 - digit4_loss: 0.8646 - digit0_accuracy: 0.6880 - digit1_accuracy: 0.5154 - digit2_accuracy: 0.4934 - digit3_accuracy: 0.5369 - digit4_accuracy: 0.7162 - val_loss: 6.0712 - val_digit0_loss: 0.8240 - val_digit1_loss: 1.4860 - val_digit2_loss: 1.6729 - val_digit3_loss: 1.2728 - val_digit4_loss: 1.1107 - val_digit0_accuracy: 0.6801 - val_digit1_accuracy: 0.5643 - val_digit2_accuracy: 0.5542 - val_digit3_accuracy: 0.5988 - val_digit4_accuracy: 0.7034
# Epoch 492/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5346 - digit0_loss: 0.9183 - digit1_loss: 1.5803 - digit2_loss: 1.7799 - digit3_loss: 1.5406 - digit4_loss: 0.8614 - digit0_accuracy: 0.6915 - digit1_accuracy: 0.5173 - digit2_accuracy: 0.4957 - digit3_accuracy: 0.5379 - digit4_accuracy: 0.7176 - val_loss: 5.4833 - val_digit0_loss: 0.7027 - val_digit1_loss: 1.4330 - val_digit2_loss: 1.5869 - val_digit3_loss: 1.2488 - val_digit4_loss: 0.7344 - val_digit0_accuracy: 0.7308 - val_digit1_accuracy: 0.6139 - val_digit2_accuracy: 0.5945 - val_digit3_accuracy: 0.6299 - val_digit4_accuracy: 0.7487
# Epoch 493/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5450 - digit0_loss: 0.9021 - digit1_loss: 1.5830 - digit2_loss: 1.6680 - digit3_loss: 1.4662 - digit4_loss: 0.8322 - digit0_accuracy: 0.6903 - digit1_accuracy: 0.5170 - digit2_accuracy: 0.4977 - digit3_accuracy: 0.5400 - digit4_accuracy: 0.7133 - val_loss: 8.6285 - val_digit0_loss: 1.5965 - val_digit1_loss: 1.6274 - val_digit2_loss: 1.9238 - val_digit3_loss: 1.5908 - val_digit4_loss: 2.4160 - val_digit0_accuracy: 0.5430 - val_digit1_accuracy: 0.5166 - val_digit2_accuracy: 0.4980 - val_digit3_accuracy: 0.5475 - val_digit4_accuracy: 0.5755
# Epoch 494/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5688 - digit0_loss: 0.9944 - digit1_loss: 1.5571 - digit2_loss: 1.7095 - digit3_loss: 1.4549 - digit4_loss: 0.8659 - digit0_accuracy: 0.6909 - digit1_accuracy: 0.5182 - digit2_accuracy: 0.4919 - digit3_accuracy: 0.5387 - digit4_accuracy: 0.7132 - val_loss: 5.0196 - val_digit0_loss: 0.6411 - val_digit1_loss: 1.4443 - val_digit2_loss: 1.5197 - val_digit3_loss: 1.0376 - val_digit4_loss: 0.5876 - val_digit0_accuracy: 0.7766 - val_digit1_accuracy: 0.6399 - val_digit2_accuracy: 0.6318 - val_digit3_accuracy: 0.6649 - val_digit4_accuracy: 0.8012
# Epoch 495/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5068 - digit0_loss: 0.9134 - digit1_loss: 1.5543 - digit2_loss: 1.7605 - digit3_loss: 1.5178 - digit4_loss: 0.8022 - digit0_accuracy: 0.6913 - digit1_accuracy: 0.5183 - digit2_accuracy: 0.4983 - digit3_accuracy: 0.5397 - digit4_accuracy: 0.7179 - val_loss: 5.3423 - val_digit0_loss: 0.6696 - val_digit1_loss: 1.5171 - val_digit2_loss: 1.6473 - val_digit3_loss: 1.1925 - val_digit4_loss: 0.6616 - val_digit0_accuracy: 0.7564 - val_digit1_accuracy: 0.6197 - val_digit2_accuracy: 0.6106 - val_digit3_accuracy: 0.6378 - val_digit4_accuracy: 0.7731
# Epoch 496/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5553 - digit0_loss: 0.8867 - digit1_loss: 1.5436 - digit2_loss: 1.6988 - digit3_loss: 1.5461 - digit4_loss: 0.8708 - digit0_accuracy: 0.6890 - digit1_accuracy: 0.5170 - digit2_accuracy: 0.4912 - digit3_accuracy: 0.5391 - digit4_accuracy: 0.7147 - val_loss: 5.4956 - val_digit0_loss: 0.7817 - val_digit1_loss: 1.4976 - val_digit2_loss: 1.6220 - val_digit3_loss: 1.1089 - val_digit4_loss: 0.6466 - val_digit0_accuracy: 0.7351 - val_digit1_accuracy: 0.6042 - val_digit2_accuracy: 0.5966 - val_digit3_accuracy: 0.6382 - val_digit4_accuracy: 0.7695
# Epoch 497/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5041 - digit0_loss: 0.9464 - digit1_loss: 1.5558 - digit2_loss: 1.6660 - digit3_loss: 1.4843 - digit4_loss: 0.8221 - digit0_accuracy: 0.6936 - digit1_accuracy: 0.5189 - digit2_accuracy: 0.4944 - digit3_accuracy: 0.5423 - digit4_accuracy: 0.7189 - val_loss: 5.4845 - val_digit0_loss: 0.8251 - val_digit1_loss: 1.5244 - val_digit2_loss: 1.6166 - val_digit3_loss: 1.0920 - val_digit4_loss: 0.6704 - val_digit0_accuracy: 0.7172 - val_digit1_accuracy: 0.6011 - val_digit2_accuracy: 0.5884 - val_digit3_accuracy: 0.6453 - val_digit4_accuracy: 0.7569
# Epoch 498/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5106 - digit0_loss: 0.9819 - digit1_loss: 1.6397 - digit2_loss: 1.6873 - digit3_loss: 1.4892 - digit4_loss: 0.8834 - digit0_accuracy: 0.6956 - digit1_accuracy: 0.5189 - digit2_accuracy: 0.4954 - digit3_accuracy: 0.5401 - digit4_accuracy: 0.7182 - val_loss: 5.3580 - val_digit0_loss: 0.6665 - val_digit1_loss: 1.5347 - val_digit2_loss: 1.5985 - val_digit3_loss: 1.2018 - val_digit4_loss: 0.6950 - val_digit0_accuracy: 0.7353 - val_digit1_accuracy: 0.6130 - val_digit2_accuracy: 0.5932 - val_digit3_accuracy: 0.6231 - val_digit4_accuracy: 0.7603
# Epoch 499/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5480 - digit0_loss: 0.9460 - digit1_loss: 1.5055 - digit2_loss: 1.7600 - digit3_loss: 1.5392 - digit4_loss: 0.9183 - digit0_accuracy: 0.6918 - digit1_accuracy: 0.5213 - digit2_accuracy: 0.4931 - digit3_accuracy: 0.5428 - digit4_accuracy: 0.7137 - val_loss: 7.0533 - val_digit0_loss: 0.9851 - val_digit1_loss: 1.6973 - val_digit2_loss: 1.8195 - val_digit3_loss: 1.3897 - val_digit4_loss: 1.5043 - val_digit0_accuracy: 0.6541 - val_digit1_accuracy: 0.5460 - val_digit2_accuracy: 0.5333 - val_digit3_accuracy: 0.5749 - val_digit4_accuracy: 0.6340
# Epoch 500/500
# 80023/80023 [==============================] - 4s 44us/step - loss: 6.5189 - digit0_loss: 0.9858 - digit1_loss: 1.5873 - digit2_loss: 1.7708 - digit3_loss: 1.5482 - digit4_loss: 0.8269 - digit0_accuracy: 0.6915 - digit1_accuracy: 0.5214 - digit2_accuracy: 0.4965 - digit3_accuracy: 0.5425 - digit4_accuracy: 0.7170 - val_loss: 5.9838 - val_digit0_loss: 1.0727 - val_digit1_loss: 1.6386 - val_digit2_loss: 1.5978 - val_digit3_loss: 1.1736 - val_digit4_loss: 0.7902 - val_digit0_accuracy: 0.6934 - val_digit1_accuracy: 0.5962 - val_digit2_accuracy: 0.5839 - val_digit3_accuracy: 0.6320 - val_digit4_accuracy: 0.7139
#
# Epoch 00500: saving model to ./output-captcha/weights-500-6.52.hdf5

# %%
plot_model_history(history_perm)

# %% [markdown]
# # 5 - Teste

# %% [markdown]
# ## 5.1 - Funções auxiliares

# %%
################################################################################################################
#
# Predição
#
#    Função que recebe um modelo e uma imagem captcha e retorna a string contida nela conforme determinado pelo
#    modelo.
#
################################################################################################################

def predict(net, img):
    
    word_predicted = np.array(net.predict(img[np.newaxis, :, :, np.newaxis]))
    word_predicted = np.reshape(word_predicted, (size_word, num_symbols))
    
    capt = ''
    for symbol in word_predicted:
        idx_symbol = np.argmax(symbol)
        capt += symbols[idx_symbol]
    
    return capt

# %%
################################################################################################################
#
# Plota Matriz de Confusão
#
#    Plota a Matriz de confunsão das classes reais vs as preditas
#
################################################################################################################

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
        
    #print(cm)

    plt.figure(figsize = (15,15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    
    plt.xticks(tick_marks, classes, rotation=45)    
    plt.yticks(tick_marks, classes)

    plt.tick_params(axis='both', which='major')
    plt.tick_params(axis='both', which='minor')
    
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
################################################################################################################
#
# Métricas
#
#    Plota a Matriz de confunsão e retorna as métricas de acurácia.
#
################################################################################################################

def metrics(x, y, model):
    
    # Estatísticas
    # index 5 = matriz total, de todos os digitos.
    confusion_digit_predict = [[] for _ in range(6)]
    confusion_digit_true = [[] for _ in range(6)]

    y_d = np.array(y)    
    y_d = np.argmax(y, axis=2);    
    d_num_correct = [0, 0, 0, 0, 0]
    #print(x.shape);
    #print(x[0].shape);
    for i in range(x.shape[0]):
        capt = predict(model, x[i,:,:,0])        
        
        for j in range(size_word):
            d_num_correct[j] = d_num_correct[j] + np.sum(capt[j] == symbols[y_d[j][i]])
            confusion_digit_predict[j].extend(capt[j]);
            confusion_digit_true[j].extend(symbols[y_d[j][i]]);
            #Geral
            confusion_digit_predict[5].extend(capt[j]);
            confusion_digit_true[5].extend(symbols[y_d[j][i]]);
    
    # Plota matizes de confusion:
    for j in range(size_word):
        plot_confusion_matrix(confusion_matrix(confusion_digit_predict[j], confusion_digit_true[j]), symbols, title='Confusion matrix D'+str(j))
    
    # Matrix geral
    plot_confusion_matrix(confusion_matrix(confusion_digit_predict[5], confusion_digit_true[5]), symbols, title='Confusion matrix Geral')
    
    num_samples = x.shape[0];
    num_caracteres = len(capt)*num_samples;
    num_correct = np.sum(d_num_correct);
    
    d_accuracy = np.array(d_num_correct)/num_samples
    accuracy = float(num_correct)/num_caracteres
    
    #plot_confusion_matrix(confusion_matrix(true_class, predicted_class), className)
    
    return accuracy, d_accuracy

# %%
################################################################################################################
#
# Amostras de Predição
#
################################################################################################################
def predict_sample(net):
    
    fig, axs = plt.subplots(2,2,figsize=(10,10))
    
    j = 0
    k = 0
    for i in (10, 100, 1000, 10000):        
        img = X_test[i,:,:]
        img.shape = (30,80)    
        axs[j%2][k%3].imshow(img, cmap='gray')
        
        word = predict(net,img)
        axs[j%2][k%2].set_title(word)
        
        k = (j - 1 < 1)
        j = j + 1
    
    plt.axis('off')    
    plt.show()

# %% [markdown]
# ## 5.2 - Experimentos

# %% [markdown]
# ### 5.2.1 - Modelo randômico

# %%
################################################################################################################
#
# Avalia modelo randomico
#
################################################################################################################

net_random.evaluate(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]])
# Out:
# 19976/19976 [==============================] - 3s 152us/step
# [2.6419810673022774,
#  0.33535099029541016,
#  0.6575552225112915,
#  0.763484537601471,
#  0.6042479276657104,
#  0.2807222306728363,
#  0.8904685378074646,
#  0.8070183992385864,
#  0.788345992565155,
#  0.8175811171531677,
#  0.9021826386451721]

# %%
accuracy, d_accuracy = metrics(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]], net_random)

# %%
print ("Accuracy on test data is: %0.2f, acc_d1= %0.2f, acc_d2= %0.2f, acc_d3= %0.2f, acc_d4= %0.2f, acc_d5= %0.2f"%(accuracy, d_accuracy[0], d_accuracy[1], d_accuracy[2], d_accuracy[3], d_accuracy[4]))
# Out:
# Accuracy on test data is: 0.84, acc_d1= 0.89, acc_d2= 0.81, acc_d3= 0.79, acc_d4= 0.82, acc_d5= 0.90

# %%
# Exemplo de predição
predict_sample(net_random);

# %%
# Saída por camada
# Get Output Layers
# MaxPool_1
#layer_name = 'MaxPool_1'
def plot_layers_output(model):
  layer_name = ['Conv_1','Conv_2','Conv_3']
  fig = plt.figure(figsize=(30,60))

  num_filtros = 5;
  idx_plot = 0
  for layer in layer_name:
      
      intermediate_layer_model = Model(inputs=model.input, outputs=model.get_layer(layer).output)
      features = intermediate_output = intermediate_layer_model.predict(img[np.newaxis, :, :, np.newaxis])
      num_filtros = features.shape[3]
      for i in range(num_filtros):
      
          ax = fig.add_subplot(20, 5, idx_plot+1, xticks=[], yticks=[])   
          ax.set_title(layer + '_' + str(i))
          plt.imshow(features[0,:,:,i], cmap="gray")
          idx_plot = idx_plot + 1
      
  plt.show()

# %%
plot_layers_output(net_random)

# %% [markdown]
# ### 5.2.2 - Modelo permutação

# %%
################################################################################################################
#
# Avalia modelo Permutação
#
################################################################################################################

net_perm.evaluate(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]])
# Out:
# 19976/19976 [==============================] - 3s 159us/step
# [6.038857664353475,
#  0.9526420831680298,
#  1.395874261856079,
#  1.4821888208389282,
#  1.2718802690505981,
#  0.9364824295043945,
#  0.6960352659225464,
#  0.5907589197158813,
#  0.5824990272521973,
#  0.6280536651611328,
#  0.7083500027656555]

# %%
accuracy, d_accuracy = metrics(X_test, [y_test[0], y_test[1], y_test[2], y_test[3], y_test[4]], net_perm)

# %%
print ("Accuracy on test data is: %0.2f, acc_d1= %0.2f, acc_d2= %0.2f, acc_d3= %0.2f, acc_d4= %0.2f, acc_d5= %0.2f"%(accuracy, d_accuracy[0], d_accuracy[1], d_accuracy[2], d_accuracy[3], d_accuracy[4]))
# Out:
# Accuracy on test data is: 0.64, acc_d1= 0.70, acc_d2= 0.59, acc_d3= 0.58, acc_d4= 0.63, acc_d5= 0.71

# %%
# Exemplo de predição
predict_sample(net_perm);

# %%
plot_layers_output(net_perm)
